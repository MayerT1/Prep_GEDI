# %% [markdown]
# <a href="https://colab.research.google.com/github/MayerT1/Prep_GEDI/blob/main/Move_Export_To_Train_Test_Val_Feed_Folder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil

# src = "/content/drive/MyDrive/GEDI_native_resolution_patches_32x32_11_6"
src = "/content/drive/MyDrive/GEDI_L2B_X_X_X_X_X_X_X_X_GEDI_native_resolution_patches_32x32_11_6"
# dst = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25"
dst = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25_GEDI_L2B"

# Create destination directory if it doesn't exist
os.makedirs(dst, exist_ok=True)

# Loop through files in the source directory
for file_name in os.listdir(src):
    if file_name.lower().endswith(".tif"):
        src_path = os.path.join(src, file_name)
        dst_path = os.path.join(dst, file_name)

        if not os.path.exists(dst_path):
            shutil.move(src_path, dst_path)
            print(f"Moved: {file_name}")
        else:
            print(f"Skipped (duplicate): {file_name}")

print("Done!")
# Out:
# Streaming output truncated to the last 5000 lines.
# Moved: s2_idx_train_GEDI_L2B_2021135083748_2131_block_5953897.tif
# Moved: s2_idx_train_GEDI_L2B_2020196021509_2249_block_5923895.tif
# Moved: s2_idx_train_GEDI_L2B_2021135083748_2193_block_6013892.tif
# Moved: s2_idx_train_GEDI_L2B_2022139064237_2326_block_5923888.tif
# Moved: s2_idx_train_GEDI_L2B_2020196021509_2734_block_5943899.tif
# Moved: s2_idx_train_GEDI_L2B_2021135083748_2190_block_6003892.tif
# Moved: s2_idx_train_GEDI_L2B_2020196021509_2013_block_5923894.tif
# Moved: s2_idx_train_GEDI_L2B_2020196021509_2096_block_5963898.tif
# Moved: s2_idx_train_GEDI_L2B_2021135083748_2168_block_5973895.tif
# Moved: s2_idx_test_GEDI_L2B_2022139064237_2570_block_5923889.tif
# Moved: s2_idx_val_GEDI_L2B_2021135083748_2220_block_6023891.tif
# Moved: s2_idx_test_GEDI_L2B_2021135083748_2683_block_6033892.tif
# Moved: s2_idx_train_GEDI_L2B_2021135083748_2133_block_5953897.tif
# ...

# %%
# import os
# from collections import Counter

# #folder = "/content/drive/MyDrive/GEDI_L2B_X_X_X_X_X_X_X_X_GEDI_native_resolution_patches_32x32_11_6" #"/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25"
# folder = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25_GEDI_L2B"

# # List only files (exclude subfolders)
# files = [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]

# # Define known multi-token prefixes
# compound_prefixes = ["landsat_idx", "s2_idx"]

# def extract_prefix(filename):
#     """
#     Extract prefix based on:
#     1. Known compound prefixes (e.g., 'landsat_idx', 's2_idx')
#     2. Otherwise, prefix before the first underscore
#     """
#     for cp in compound_prefixes:
#         if filename.startswith(cp + "_") or filename == cp:
#             return cp
#     # Default: the original method
#     return filename.split("_")[0]

# # Extract prefixes
# prefixes = [extract_prefix(f) for f in files]

# # Count occurrences
# prefix_counts = Counter(prefixes)

# print("Total files:", len(files))
# print("\nCounts by prefix:")
# for prefix, count in sorted(prefix_counts.items()):
#     print(f"{prefix}: {count}")
# Out:
# Total files: 5758
#
# Counts by prefix:
# dem: 750
# hls: 750
# landsat: 750
# landsat_idx: 750
# s1: 750
# s2: 629
# s2_idx: 629
# tcap: 750

# %%
import os
from collections import Counter
#"/content/drive/MyDrive/GEDI_L2B_X_X_X_X_X_X_X_X_GEDI_native_resolution_patches_32x32_11_6"#
# folder = "/content/drive/MyDrive/GEDI_L2B_X_X_X_X_X_X_X_X_GEDI_native_resolution_patches_32x32_11_6"##"/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25"
folder = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25_GEDI_L2B"

# List only files (not subfolders)
files = [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]

# Total file count
total_files = len(files)

# Extract prefixes (before first underscore)
prefixes = [f.split("_")[0] for f in files]

# Count occurrences of each prefix
prefix_counts = Counter(prefixes)

print("Total files:", total_files)
print("\nCounts by prefix:")
for prefix, count in sorted(prefix_counts.items()):
    print(f"{prefix}: {count}")
# Out:
# Total files: 5758
#
# Counts by prefix:
# dem: 750
# hls: 750
# landsat: 750
# landsatidx: 750
# s1: 750
# s2: 629
# s2idx: 629
# tcap: 750

# %%
import os
from collections import defaultdict

# folder = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25"

folder = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25_GEDI_L2B"

# Dictionary: filename -> list of full paths
name_map = defaultdict(list)

for root, dirs, files in os.walk(folder):
    for f in files:
        name_map[f].append(os.path.join(root, f))

# Find duplicates
duplicates = {name: paths for name, paths in name_map.items() if len(paths) > 1}

# Print results
if duplicates:
    print("Duplicate file names found:\n")
    for name, paths in duplicates.items():
        print(f"File name: {name}")
        for p in paths:
            print(f"  - {p}")
        print()
else:
    print("No duplicate filenames found.")
# Out:
# No duplicate filenames found.

# %%
import os

# folder = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25"

folder = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25_GEDI_L2B"

# List files only
files = [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]

# Count occurrences
count_s2_idx = sum("s2_idx" in f for f in files)
count_s2idx = sum("s2idx" in f for f in files)

print("Count of files containing 's2_idx':", count_s2_idx)
print("Count of files containing 's2idx':", count_s2idx)
# Out:
# Count of files containing 's2_idx': 629
# Count of files containing 's2idx': 0

# %%
import os

# folder = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25"
folder = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25_GEDI_L2B"
# patterns to replace
replacements = {
    # "landsat_idx": "landsatidx",
    "s2_idx": "s2idx"
}

for fname in os.listdir(folder):

    for old, new in replacements.items():
        if old in fname:
            old_path = os.path.join(folder, fname)
            new_fname = fname.replace(old, new)
            new_path = os.path.join(folder, new_fname)

            if not os.path.exists(new_path):
                os.rename(old_path, new_path)
                print(f"Renamed: {fname} → {new_fname}")
            else:
                print(f"Skipped (target exists): {new_fname}")

print("Done!")
# Out:
# Renamed: s2_idx_train_GEDI_L2B_2021135083748_2617_block_5963898.tif → s2idx_train_GEDI_L2B_2021135083748_2617_block_5963898.tif
# Renamed: s2_idx_train_GEDI_L2B_2021135083748_2428_block_6003894.tif → s2idx_train_GEDI_L2B_2021135083748_2428_block_6003894.tif
# Renamed: s2_idx_val_GEDI_L2B_2021135083748_2218_block_6023891.tif → s2idx_val_GEDI_L2B_2021135083748_2218_block_6023891.tif
# Renamed: s2_idx_train_GEDI_L2B_2020196021509_2104_block_5963899.tif → s2idx_train_GEDI_L2B_2020196021509_2104_block_5963899.tif
# Renamed: s2_idx_test_GEDI_L2B_2021135083748_2691_block_6033892.tif → s2idx_test_GEDI_L2B_2021135083748_2691_block_6033892.tif
# Renamed: s2_idx_train_GEDI_L2B_2021135083748_2667_block_6003895.tif → s2idx_train_GEDI_L2B_2021135083748_2667_block_6003895.tif
# Renamed: s2_idx_train_GEDI_L2B_2021135083748_1947_block_5993892.tif → s2idx_train_GEDI_L2B_2021135083748_1947_block_5993892.tif
# ...

# %%
import os

# folder = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25"
folder = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25_GEDI_L2B"
for fname in os.listdir(folder):
    if "landsat_idx" in fname:
        old_path = os.path.join(folder, fname)
        new_fname = fname.replace("landsat_idx", "landsatidx")
        new_path = os.path.join(folder, new_fname)

        # Avoid overwriting existing files
        if not os.path.exists(new_path):
            os.rename(old_path, new_path)
            print(f"Renamed: {fname} → {new_fname}")
        else:
            print(f"Skipped (target exists): {new_fname}")

print("Done!")
# Out:
# Renamed: landsat_idx_train_GEDI_L2B_2020196021509_2024_block_5923895.tif → landsatidx_train_GEDI_L2B_2020196021509_2024_block_5923895.tif
# Renamed: landsat_idx_train_GEDI_L2B_2021135083748_2229_block_6023890.tif → landsatidx_train_GEDI_L2B_2021135083748_2229_block_6023890.tif
# Renamed: landsat_idx_train_GEDI_L2B_2021135083748_2204_block_6013891.tif → landsatidx_train_GEDI_L2B_2021135083748_2204_block_6013891.tif
# Renamed: landsat_idx_train_GEDI_L2B_2021135083748_2201_block_6013892.tif → landsatidx_train_GEDI_L2B_2021135083748_2201_block_6013892.tif
# Renamed: landsat_idx_val_GEDI_L2B_2021135083748_1930_block_5973894.tif → landsatidx_val_GEDI_L2B_2021135083748_1930_block_5973894.tif
# Renamed: landsat_idx_train_GEDI_L2B_2021135083748_1891_block_5943898.tif → landsatidx_train_GEDI_L2B_2021135083748_1891_block_5943898.tif
# Renamed: landsat_idx_train_GEDI_L2B_2021135083748_2171_block_5973895.tif → landsatidx_train_GEDI_L2B_2021135083748_2171_block_5973895.tif
# ...

# %%
import os

# folder = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25"
folder = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25_GEDI_L2B"

# List files only
files = [f for f in os.listdir(folder) if os.path.isfile(os.path.join(folder, f))]

# Count occurrences
count_landsat_idx = sum("landsat_idx" in f for f in files)
count_landsatidx = sum("landsatidx" in f for f in files)

print("Count of files containing 'landsat_idx':", count_landsat_idx)
print("Count of files containing 'landsatidx':", count_landsatidx)
# Out:
# Count of files containing 'landsat_idx': 0
# Count of files containing 'landsatidx': 750

# %%
import os

folder = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25"

remaining = [f for f in os.listdir(folder) if "s2_idx" in f]

print("Files still containing 's2_idx':", len(remaining))
for f in remaining:
    print(f)
# Out:
# Files still containing 's2_idx': 519
# s2_idx_train_GEDI_L2A_2021135083748_106_block_5983896.tif
# s2_idx_train_GEDI_L2A_2022358084911_769_block_5963892.tif
# s2_idx_val_GEDI_L2A_2021135083748_83_block_5973897.tif
# s2_idx_train_GEDI_L2A_2022358084911_1340_block_6023897.tif
# s2_idx_train_GEDI_L2A_2021135083748_1180_block_6043889.tif
# s2_idx_train_GEDI_L2A_2021135083748_549_block_5973896.tif
# s2_idx_train_GEDI_L2A_2022358084911_848_block_6003896.tif
# s2_idx_train_GEDI_L2A_2021135083748_565_block_5983896.tif
# s2_idx_train_GEDI_L2A_2022358084911_1766_block_5983893.tif
# s2_idx_train_GEDI_L2A_2021135083748_102_block_5983896.tif
# s2_idx_train_GEDI_L2A_2021135083748_1056_block_5973896.tif
# s2_idx_train_GEDI_L2A_2020196021509_429_block_5923896.tif
# s2_idx_train_GEDI_L2A_2022358084911_1196_block_5923888.tif
# s2_idx_train_GEDI_L2A_2022358084911_1362_block_6033898.tif
# s2_idx_train_GEDI_L2A_2021135083748_552_block_5973896.tif
# ...

# %%
import os

folder = "/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data_32_32_patches_11_4_25"

for fname in os.listdir(folder):
    if "s2_idx" in fname:
        old_path = os.path.join(folder, fname)
        new_fname = fname.replace("s2_idx", "s2idx")
        new_path = os.path.join(folder, new_fname)

        # If the target name exists, add a numeric suffix to avoid collision
        if os.path.exists(new_path):
            base, ext = os.path.splitext(new_fname)
            counter = 1
            while True:
                new_fname2 = f"{base}_{counter}{ext}"
                new_path2 = os.path.join(folder, new_fname2)
                if not os.path.exists(new_path2):
                    new_fname = new_fname2
                    new_path = new_path2
                    break
                counter += 1

        os.rename(old_path, new_path)
        print(f"Renamed: {fname} → {new_fname}")

print("Done!")
# Out:
# Renamed: s2_idx_train_GEDI_L2A_2021135083748_106_block_5983896.tif → s2idx_train_GEDI_L2A_2021135083748_106_block_5983896_1.tif
# Renamed: s2_idx_train_GEDI_L2A_2022358084911_769_block_5963892.tif → s2idx_train_GEDI_L2A_2022358084911_769_block_5963892_1.tif
# Renamed: s2_idx_val_GEDI_L2A_2021135083748_83_block_5973897.tif → s2idx_val_GEDI_L2A_2021135083748_83_block_5973897_1.tif
# Renamed: s2_idx_train_GEDI_L2A_2022358084911_1340_block_6023897.tif → s2idx_train_GEDI_L2A_2022358084911_1340_block_6023897_1.tif
# Renamed: s2_idx_train_GEDI_L2A_2021135083748_1180_block_6043889.tif → s2idx_train_GEDI_L2A_2021135083748_1180_block_6043889_1.tif
# Renamed: s2_idx_train_GEDI_L2A_2021135083748_549_block_5973896.tif → s2idx_train_GEDI_L2A_2021135083748_549_block_5973896_1.tif
# Renamed: s2_idx_train_GEDI_L2A_2022358084911_848_block_6003896.tif → s2idx_train_GEDI_L2A_2022358084911_848_block_6003896_1.tif
# ...
