# %% [markdown]
# <a href="https://colab.research.google.com/github/MayerT1/Prep_GEDI/blob/main/GEDI_L2B_Target_fetch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install earthaccess harmony-py hvplot folium geopandas geoviews
# Out:
# Collecting earthaccess
#   Downloading earthaccess-0.15.1-py3-none-any.whl.metadata (9.6 kB)
# Collecting harmony-py
#   Downloading harmony_py-1.3.2-py3-none-any.whl.metadata (17 kB)
# Collecting hvplot
#   Downloading hvplot-0.12.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (0.20.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Collecting geoviews
#   Downloading geoviews-1.14.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: fsspec>=2025.2 in /usr/local/lib/python3.12/dist-packages (from earthaccess) (2025.3.0)
# Requirement already satisfied: importlib-resources>=6.3.2 in /usr/local/lib/python3.12/dist-packages (from earthaccess) (6.5.2)
# Collecting multimethod>=1.8 (from earthaccess)
#   Downloading multimethod-2.0.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting pqdm>=0.1 (from earthaccess)
#   Downloading pqdm-0.2.0-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting python-cmr>=0.10.0 (from earthaccess)
#   Downloading python_cmr-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.12/dist-packages (from earthaccess) (2.32.4)
# Collecting s3fs>=2025.2 (from earthaccess)
#   Downloading s3fs-2025.10.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting tenacity>=9.0 (from earthaccess)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting tinynetrc>=1.3.1 (from earthaccess)
#   Downloading tinynetrc-1.3.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from earthaccess) (4.15.0)
# Requirement already satisfied: python-dateutil~=2.9 in /usr/local/lib/python3.12/dist-packages (from harmony-py) (2.9.0.post0)
# Collecting python-dotenv~=1.1.0 (from harmony-py)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting progressbar2~=4.2.0 (from harmony-py)
#   Downloading progressbar2-4.2.0-py2.py3-none-any.whl.metadata (12 kB)
# Collecting sphinxcontrib-napoleon~=0.7 (from harmony-py)
#   Downloading sphinxcontrib_napoleon-0.7-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting curlify~=2.2.1 (from harmony-py)
#   Downloading curlify-2.2.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting shapely~=2.0.4 (from harmony-py)
#   Downloading shapely-2.0.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: bokeh>=3.1 in /usr/local/lib/python3.12/dist-packages (from hvplot) (3.7.3)
# Requirement already satisfied: colorcet>=2 in /usr/local/lib/python3.12/dist-packages (from hvplot) (3.1.0)
# Requirement already satisfied: holoviews>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from hvplot) (1.21.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from hvplot) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from hvplot) (25.0)
# Requirement already satisfied: pandas>=1.3 in /usr/local/lib/python3.12/dist-packages (from hvplot) (2.2.2)
# Requirement already satisfied: panel>=1.0 in /usr/local/lib/python3.12/dist-packages (from hvplot) (1.8.2)
# Requirement already satisfied: param<3.0,>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from hvplot) (2.2.1)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas) (0.11.1)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (3.7.2)
# Collecting cartopy>=0.18.0 (from geoviews)
#   Downloading cartopy-0.25.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: contourpy>=1.2 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1->hvplot) (1.3.3)
# Requirement already satisfied: narwhals>=1.13 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1->hvplot) (2.10.0)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1->hvplot) (11.3.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1->hvplot) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.12/dist-packages (from bokeh>=3.1->hvplot) (6.5.1)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.12/dist-packages (from cartopy>=0.18.0->geoviews) (3.10.0)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.12/dist-packages (from cartopy>=0.18.0->geoviews) (3.0.2.post1)
# Requirement already satisfied: pyviz-comms>=2.1 in /usr/local/lib/python3.12/dist-packages (from holoviews>=1.19.0->hvplot) (3.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3->hvplot) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3->hvplot) (2025.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from panel>=1.0->hvplot) (6.3.0)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.12/dist-packages (from panel>=1.0->hvplot) (2.0.3)
# Requirement already satisfied: markdown in /usr/local/lib/python3.12/dist-packages (from panel>=1.0->hvplot) (3.9)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.12/dist-packages (from panel>=1.0->hvplot) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.12/dist-packages (from panel>=1.0->hvplot) (0.5.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from panel>=1.0->hvplot) (4.67.1)
# Collecting bounded-pool-executor (from pqdm>=0.1->earthaccess)
#   Downloading bounded_pool_executor-0.0.3-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: python-utils>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from progressbar2~=4.2.0->harmony-py) (3.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil~=2.9->harmony-py) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26->earthaccess) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26->earthaccess) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26->earthaccess) (2.5.0)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs>=2025.2->earthaccess)
#   Downloading aiobotocore-2.25.1-py3-none-any.whl.metadata (25 kB)
# Collecting fsspec>=2025.2 (from earthaccess)
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from s3fs>=2025.2->earthaccess) (3.13.1)
# Collecting pockets>=0.3 (from sphinxcontrib-napoleon~=0.7->harmony-py)
#   Downloading pockets-0.9.1-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2025.2->earthaccess)
#   Downloading aioitertools-0.12.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting botocore<1.40.62,>=1.40.46 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2025.2->earthaccess)
#   Downloading botocore-1.40.61-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2025.2->earthaccess)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2025.2->earthaccess) (6.7.0)
# Collecting wrapt<2.0.0,>=1.10.10 (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2025.2->earthaccess)
#   Downloading wrapt-1.17.3-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess) (1.8.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=2025.2->earthaccess) (1.22.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy>=0.18.0->geoviews) (3.2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->panel>=1.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.12/dist-packages (from linkify-it-py->panel>=1.0->hvplot) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py->panel>=1.0->hvplot) (0.1.2)
# Downloading earthaccess-0.15.1-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.5/70.5 kB 3.4 MB/s eta 0:00:00
# Downloading harmony_py-1.3.2-py3-none-any.whl (35 kB)
# Downloading hvplot-0.12.1-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 kB 7.5 MB/s eta 0:00:00
# Downloading geoviews-1.14.1-py3-none-any.whl (548 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.7/548.7 kB 17.4 MB/s eta 0:00:00
# Downloading cartopy-0.25.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 71.3 MB/s eta 0:00:00
# Downloading multimethod-2.0.1-py3-none-any.whl (9.5 kB)
# Downloading pqdm-0.2.0-py2.py3-none-any.whl (6.8 kB)
# Downloading progressbar2-4.2.0-py2.py3-none-any.whl (27 kB)
# Downloading python_cmr-0.13.0-py3-none-any.whl (14 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading s3fs-2025.10.0-py3-none-any.whl (30 kB)
# Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.0/201.0 kB 17.4 MB/s eta 0:00:00
# Downloading shapely-2.0.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 69.3 MB/s eta 0:00:00
# Downloading sphinxcontrib_napoleon-0.7-py2.py3-none-any.whl (17 kB)
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading tinynetrc-1.3.1-py2.py3-none-any.whl (3.9 kB)
# Downloading aiobotocore-2.25.1-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 9.0 MB/s eta 0:00:00
# Downloading pockets-0.9.1-py2.py3-none-any.whl (26 kB)
# Downloading bounded_pool_executor-0.0.3-py3-none-any.whl (3.4 kB)
# Downloading aioitertools-0.12.0-py3-none-any.whl (24 kB)
# Downloading botocore-1.40.61-py3-none-any.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 75.7 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading wrapt-1.17.3-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 6.6 MB/s eta 0:00:00
# Building wheels for collected packages: curlify
#   Building wheel for curlify (setup.py) ... done
#   Created wheel for curlify: filename=curlify-2.2.1-py3-none-any.whl size=2667 sha256=ea17464431af575b808f10d3810fcb4c19945a934de18fcd5d397fc86a4d297d
#   Stored in directory: /root/.cache/pip/wheels/de/b1/32/218427ea0fc33dda6ec9259a8dbc440c6a04bd2f37c1d67a68
# Successfully built curlify
# Installing collected packages: tinynetrc, bounded-pool-executor, wrapt, tenacity, shapely, python-dotenv, pqdm, pockets, multimethod, jmespath, fsspec, aioitertools, sphinxcontrib-napoleon, python-cmr, progressbar2, curlify, botocore, harmony-py, cartopy, aiobotocore, s3fs, earthaccess, hvplot, geoviews
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 2.0.0
#     Uninstalling wrapt-2.0.0:
#       Successfully uninstalled wrapt-2.0.0
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.5.0
#     Uninstalling tenacity-8.5.0:
#       Successfully uninstalled tenacity-8.5.0
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.1.2
#     Uninstalling shapely-2.1.2:
#       Successfully uninstalled shapely-2.1.2
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.2.1
#     Uninstalling python-dotenv-1.2.1:
#       Successfully uninstalled python-dotenv-1.2.1
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: progressbar2
#     Found existing installation: progressbar2 4.5.0
#     Uninstalling progressbar2-4.5.0:
#       Successfully uninstalled progressbar2-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.10.0 which is incompatible.
# google-adk 1.17.0 requires tenacity<9.0.0,>=8.0.0, but you have tenacity 9.1.2 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# Successfully installed aiobotocore-2.25.1 aioitertools-0.12.0 botocore-1.40.61 bounded-pool-executor-0.0.3 cartopy-0.25.0 curlify-2.2.1 earthaccess-0.15.1 fsspec-2025.10.0 geoviews-1.14.1 harmony-py-1.3.2 hvplot-0.12.1 jmespath-1.0.1 multimethod-2.0.1 pockets-0.9.1 pqdm-0.2.0 progressbar2-4.2.0 python-cmr-0.13.0 python-dotenv-1.1.1 s3fs-2025.10.0 shapely-2.0.7 sphinxcontrib-napoleon-0.7 tenacity-9.1.2 tinynetrc-1.3.1 wrapt-1.17.3

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os

# Define the base project folder and subdirectories
base_dir = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project'
subdirs = [
    'target_data',
    'GEDI_target',
    'data',
    'models',
    'scripts',
    'notebooks',
    'config',
    'results'
]

# Create each subdirectory
for subdir in subdirs:
    path = os.path.join(base_dir, subdir)
    os.makedirs(path, exist_ok=True)
    print(f"Created: {path}")
# Out:
# Created: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/target_data
# Created: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target
# Created: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/data
# Created: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/models
# Created: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/scripts
# Created: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/notebooks
# Created: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/config
# Created: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/results

# %%
# !pwd

# %%
# %cd /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project
# Out:
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project

# %% [markdown]
# Make a new folder to work in and change directory to that location

# %%
# !mkdir Module_2_GEDI_L2b

# !mkdir Module_2_GEDI_L2b/SPB_AOI
# !mkdir Module_2_GEDI_L2b/Prescribed_Burn_AOI
# !mkdir Module_2_GEDI_L2b/Sewanee_Domain
# !mkdir Module_2_GEDI_L2b/PaintRock_AOI

# %% [markdown]
# Change directory to that new folder

# %%
# %cd /content/Module_2_GEDI_L2b

# %% [markdown]
# ![Module_II_Workflow_x.png](data:image/png;base64,...)

# %% [markdown]
# Link to editable workflow (to be removed at the end) https://docs.google.com/drawings/d/1q49Oa-y9W5X25_Qijg0IuSczzcVrcOX5mVfiyIO_UmE/edit

# %% [markdown]
# Load the needed packages

# %%
from harmony import BBox, Client, Collection, Request, CapabilitiesRequest
import h5py
from datetime import datetime
import json
import earthaccess
import geopandas as gp
import pandas as pd
import numpy as np
import os
from IPython.display import JSON
from shapely.geometry import Point
import hvplot.pandas
import folium
from folium import GeoJson
from IPython.display import display, HTML
import requests
from io import StringIO
from datetime import datetime
import seaborn as sns
from matplotlib import cm, colors
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable, get_cmap
import textwrap
from mpl_toolkits.mplot3d import Axes3D
# gv.extension('bokeh', 'matplotlib')
from holoviews import opts
import shapely
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.colors as colors

os.chdir('../../')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2467327789.py in <cell line: 0>()
# ----> 1 from harmony import BBox, Client, Collection, Request, CapabilitiesRequest
#       2 import h5py
#       3 from datetime import datetime
#       4 import json
#       5 import earthaccess
#
# ModuleNotFoundError: No module named 'harmony'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Authenticate

# %% [markdown]
# Pause here and set up your arorund and have your username and password ready for this next section. See the [EarthData Login](https://urs.earthdata.nasa.gov/) if you dont have an account yet.
#
# `earthaccess.login()` is used here to access NASA Earthdata Login (EDL) credentials stored in a .netrc file and allows users to type their credentials and persist them to a .netrc file if one does not exist.

# %%
auth = earthaccess.login(persist=True)
# auth.token
# Out:
# Enter your Earthdata Login username: tjm0042
# Enter your Earthdata password: ··········

# %% [markdown]
# To access data through Harmony service, we need to create a Harmony Client object using either your EDL token or your Earthdata Login credentials. Below, `username` and `password` are directly provided to `Client` function. See [here](https://github.com/nasa/harmony-py/blob/main/examples/intro_tutorial.ipynb) for other options you can create Harmony Client object.

# %%
harmony_client = Client(auth=(auth.username, auth.password))

# %% [markdown]
# # Visualize our Areas of intres (AOI)

# %% [markdown]
# Add relivant biophysical and forest informaiton regarind these sites see  the folder here with the docs to support this: https://drive.google.com/drive/folders/1WvBSUIHy6I05j8s1ZZRarho5qnG2wdnb

# %%
# Bring in aois
geojson_urls = {
    # "SPB_AOI": "https://raw.githubusercontent.com/SERVIR/GEDI_Earthhub_ARSET_Training/main/AOIs/SPB_AOI.geojson",
    # "Prescribed_Burn_AOI": "https://raw.githubusercontent.com/SERVIR/GEDI_Earthhub_ARSET_Training/main/AOIs/prescribed_burn_aoi.geojson",
    "Sewanee_Domain": "https://raw.githubusercontent.com/MayerT1/Prep_GEDI/main/AOI/Sewanee_DL_project_bounds.geojson",
    # "PaintRockAOI": "https://raw.githubusercontent.com/SERVIR/GEDI_Earthhub_ARSET_Training/main/AOIs/PaintRockAOI.geojson"
}

# %%
# Load GeoJSONs into GeoDataFrames and store map HTML
geojson_gdfs = {}
maps_html = []

def create_map_and_gdf(name, url):
    # Get GeoJSON from URL
    geojson_data = requests.get(url).json()

    # Create GeoDataFrame
    gdf = gp.GeoDataFrame.from_features(geojson_data["features"])
    geojson_gdfs[name] = gdf

    # Determine map center
    coords = geojson_data['features'][0]['geometry']['coordinates']
    geom_type = geojson_data['features'][0]['geometry']['type']

    if geom_type == "Polygon":
        coords = coords[0]
    elif geom_type == "MultiPolygon":
        coords = coords[0][0]
    else:
        raise ValueError(f"Unsupported geometry type: {geom_type}")

    lat = sum(pt[1] for pt in coords) / len(coords)
    lon = sum(pt[0] for pt in coords) / len(coords)

    # Create map
    fmap = folium.Map(location=[lat, lon], zoom_start=13, tiles="OpenStreetMap")
    folium.GeoJson(geojson_data, name=name).add_to(fmap)

    # Return rendered HTML
    return fmap._repr_html_()

# Generate maps and GeoDataFrames
for name, url in geojson_urls.items():
    html_map = create_map_and_gdf(name, url)
    maps_html.append(html_map)

# %%
# Display maps side by side
html = f"""
<div style="display: flex; flex-wrap: wrap;">
    {''.join([f'<div style="flex: 1; min-width: 400px; margin: 5px;">{m}</div>' for m in maps_html])}
</div>
"""
display(HTML(html))
# Out:
# <div style="display: flex; flex-wrap: wrap;">
#     <div style="flex: 1; min-width: 400px; margin: 5px;"><div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7ab2d57281cb08bd6e5d479f47c31b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7ab2d57281cb08bd6e5d479f47c31b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7ab2d57281cb08bd6e5d479f47c31b8 = L.map(
#                 &quot;map_c7ab2d57281cb08bd6e5d479f47c31b8&quot;,
#                 {
#                     center: [35.172822622074406, -85.9199994573308],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0c598871d2a08be41036d628e6a3d7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0c598871d2a08be41036d628e6a3d7d.addTo(map_c7ab2d57281cb08bd6e5d479f47c31b8);
#
#
#
#         function geo_json_fa10cf1db63d61ca9b9b4f66eff041cd_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_fa10cf1db63d61ca9b9b4f66eff041cd = L.geoJson(null, {
#                 onEachFeature: geo_json_fa10cf1db63d61ca9b9b4f66eff041cd_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_fa10cf1db63d61ca9b9b4f66eff041cd_add (data) {
#             geo_json_fa10cf1db63d61ca9b9b4f66eff041cd
#                 .addData(data);
#         }
#             geo_json_fa10cf1db63d61ca9b9b4f66eff041cd_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-85.85713766027291, 35.12712567903646], [-85.85713680129864, 35.1271369617766], [-85.85713664512146, 35.235653455060785], [-85.85718138985497, 35.235694899375645], [-85.85721941894398, 35.235740633343134], [-85.85723761354969, 35.23574343013795], [-85.98974845934751, 35.23574346765027], [-85.98979916577917, 35.23570689530353], [-85.9898550907876, 35.23567576795453], [-85.98985851794494, 35.2356609838801], [-85.98985836216507, 35.12713692722979], [-85.98981365332196, 35.12709547871676], [-85.98977556509595, 35.12704980709349], [-85.98976209011359, 35.127047686487664], [-85.98974830356731, 35.127046980234375], [-85.85724690607121, 35.12704695073614], [-85.85719614858068, 35.12708351392015], [-85.85714023719572, 35.12711462243987], [-85.85713766027291, 35.12712567903646]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_fa10cf1db63d61ca9b9b4f66eff041cd.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_fa10cf1db63d61ca9b9b4f66eff041cd.addTo(map_c7ab2d57281cb08bd6e5d479f47c31b8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div></div>
# </div>

# %%
##Pull out the geopanda dataframes
# SPB_AOI = geojson_gdfs["SPB_AOI"]
# Prescribed_Burn_AOI = geojson_gdfs["Prescribed_Burn_AOI"]
Sewanee_Domain = geojson_gdfs["Sewanee_Domain"]
# PaintRock_AOI = geojson_gdfs["PaintRockAOI"]

# %%
# Store all bbox objects in a dictionary for later use
bbox_dict = {}

for name, url in geojson_urls.items():
    gdf = gp.read_file(url)
    minx, miny, maxx, maxy = gdf.total_bounds
    bbox = BBox(minx, miny, maxx, maxy)
    bbox_dict[f"{name}_roi"] = bbox

bbox_dict
# Out:
# {'Sewanee_Domain_roi': BBox: West:-85.98985851794494, South:35.12704695073614, East:-85.85713664512146, North:35.23574346765027}

# %% [markdown]
# ## Get the GEDI Collections Harmony Capabilities

# %% [markdown]
# First lets investigate what capabilites Harmony has to request data. Using hte short name `'GEDI02_B'`
# ('GEDI02_A', 'GEDI02_B', 'GEDI01_B')
#
# view informaiton such as `conceptId` such as variable subsetting, bounding box subsetting, shapefile subsetting, concatenation and reprojection, etc.

# %% [markdown]
# products of intrest: https://docs.google.com/spreadsheets/d/1Uvls3Oxn_jSmTyaSoWadQrS8tZSWyUGYai7etUoALLc/edit?gid=0#gid=0

# %%
capabilities = harmony_client.submit(CapabilitiesRequest(short_name='GEDI02_B'))
print(json.dumps(capabilities, indent=2))
# Out:
# {
#   "conceptId": "C2142776747-LPCLOUD",
#   "shortName": "GEDI02_B",
#   "variableSubset": true,
#   "bboxSubset": true,
#   "shapeSubset": true,
#   "temporalSubset": true,
#   "concatenate": false,
#   "reproject": false,
#   "outputFormats": [
#     "application/x-hdf"
#   ],
#   "services": [
#     {
#       "name": "sds/trajectory-subsetter",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/S2836723123-XYZ_PROV",
#       "capabilities": {
#         "subsetting": {
#           "temporal": true,
#           "bbox": true,
#           "shape": true,
#           "variable": true
#         },
#         "output_formats": [
#           "application/x-hdf"
#         ]
#       }
#     }
#   ],
#   "variables": [
#     {
#       "name": "/BEAM0000/algorithmrun_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647264-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/ancillary/dz",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647474-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/ancillary/l2a_alg_count",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647478-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/ancillary/maxheight_cuttoff",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647481-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/ancillary/rg_eg_constraint_center_buffer",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647485-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/ancillary/rg_eg_mpfit_max_func_evals",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647489-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/ancillary/rg_eg_mpfit_maxiters",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647492-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/ancillary/rg_eg_mpfit_tolerance",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647495-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/ancillary/signal_search_buff",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647499-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/ancillary/tx_noise_stddev_multiplier",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647502-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/beam",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647271-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/channel",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647276-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/cover",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647281-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/cover_z",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647286-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/delta_time",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647291-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/fhd_normal",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647295-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/degrade_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647506-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/delta_time",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647509-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/digital_elevation_model",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647512-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/elev_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647516-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/elev_lowestmode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647519-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/elevation_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647523-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/elevation_bin0_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647527-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/elevation_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647531-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/elevation_lastbin_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647534-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/height_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647538-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/height_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647541-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/lat_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647545-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/lat_lowestmode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647550-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/latitude_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647554-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/latitude_bin0_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647557-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/latitude_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647561-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/latitude_lastbin_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647565-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/local_beam_azimuth",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647568-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/local_beam_elevation",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647572-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/lon_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647575-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/lon_lowestmode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647578-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/longitude_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647582-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/longitude_bin0_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647585-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/longitude_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647591-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/longitude_lastbin_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647594-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/shot_number",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647600-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/solar_azimuth",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647604-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/geolocation/solar_elevation",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647607-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/l2a_quality_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647299-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/l2b_quality_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647303-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/land_cover_data/landsat_treecover",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647611-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/land_cover_data/landsat_water_persistence",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647614-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/land_cover_data/leaf_off_doy",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647619-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/land_cover_data/leaf_off_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647622-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/land_cover_data/leaf_on_cycle",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647625-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/land_cover_data/leaf_on_doy",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647629-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/land_cover_data/modis_nonvegetated",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647632-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/land_cover_data/modis_nonvegetated_sd",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647638-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/land_cover_data/modis_treecover",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647647-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/land_cover_data/modis_treecover_sd",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647651-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/land_cover_data/pft_class",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647655-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/land_cover_data/region_class",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647658-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/land_cover_data/urban_focal_window_size",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647663-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/land_cover_data/urban_proportion",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647667-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/master_frac",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647311-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/master_int",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647321-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/num_detectedmodes",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647330-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/omega",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647339-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/pai",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647350-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/pai_z",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647357-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/pavd_z",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647362-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/pgap_theta",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647367-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/pgap_theta_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647371-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/pgap_theta_z",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647375-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rg",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647378-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rh100",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647383-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rhog",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647388-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rhog_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647392-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rhov",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647396-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rhov_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647400-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rossg",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647404-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rv",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647407-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/algorithmrun_flag_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647671-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/algorithmrun_flag_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647675-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/algorithmrun_flag_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647680-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/algorithmrun_flag_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647686-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/algorithmrun_flag_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647691-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/algorithmrun_flag_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647698-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/pgap_theta_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647704-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/pgap_theta_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647710-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/pgap_theta_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647716-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/pgap_theta_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647721-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/pgap_theta_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647742-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/pgap_theta_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647764-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/pgap_theta_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647777-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/pgap_theta_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647783-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/pgap_theta_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647788-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/pgap_theta_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647794-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/pgap_theta_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647799-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/pgap_theta_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647802-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647804-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647807-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647809-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647811-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647813-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647815-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_amplitude_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647817-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_amplitude_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647819-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_amplitude_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647821-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_amplitude_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647823-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_amplitude_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647825-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_amplitude_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647827-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_amplitude_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647829-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_amplitude_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647832-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_amplitude_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647834-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_amplitude_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647836-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_amplitude_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647838-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_amplitude_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647840-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_center_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647842-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_center_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647844-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_center_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647846-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_center_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647848-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_center_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647850-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_center_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647852-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_center_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647855-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_center_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647857-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_center_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647859-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_center_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647861-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_center_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647863-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_center_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647865-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_chisq_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647867-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_chisq_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647869-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_chisq_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647871-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_chisq_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647874-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_chisq_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647876-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_chisq_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647878-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_flag_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647880-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_flag_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647882-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_flag_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647884-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_flag_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647886-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_flag_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647888-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_flag_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647890-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_gamma_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647893-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_gamma_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647895-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_gamma_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647898-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_gamma_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647900-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_gamma_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647904-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_gamma_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647907-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_gamma_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647909-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_gamma_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647911-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_gamma_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647913-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_gamma_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647916-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_gamma_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647918-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_gamma_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647926-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_niter_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647933-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_niter_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647939-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_niter_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647945-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_niter_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647955-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_niter_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647963-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_niter_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647975-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_sigma_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647985-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_sigma_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647992-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_sigma_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647995-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_sigma_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647998-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_sigma_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648003-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_sigma_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648006-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_sigma_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648012-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_sigma_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648016-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_sigma_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648020-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_sigma_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648028-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_sigma_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648035-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_eg_sigma_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648040-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648046-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648050-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648052-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648055-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648057-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rg_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648059-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rv_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648061-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rv_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648063-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rv_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648065-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rv_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648067-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rv_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648069-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rv_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648071-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rx_energy_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648073-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rx_energy_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648075-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rx_energy_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648077-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rx_energy_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648079-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rx_energy_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648081-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/rx_energy_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648083-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_processing/shot_number",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648085-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_range_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647411-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_sample_count",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647415-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/rx_sample_start_index",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647421-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/selected_l2a_algorithm",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647426-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/selected_mode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647431-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/selected_mode_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647436-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/selected_rg_algorithm",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647443-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/sensitivity",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647449-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/shot_number",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647455-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/stale_return_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647463-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0000/surface_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837647471-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/algorithmrun_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648087-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/ancillary/dz",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648187-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/ancillary/l2a_alg_count",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648189-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/ancillary/maxheight_cuttoff",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648191-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/ancillary/rg_eg_constraint_center_buffer",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648193-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/ancillary/rg_eg_mpfit_max_func_evals",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648195-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/ancillary/rg_eg_mpfit_maxiters",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648197-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/ancillary/rg_eg_mpfit_tolerance",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648201-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/ancillary/signal_search_buff",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648203-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/ancillary/tx_noise_stddev_multiplier",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648205-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/beam",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648090-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/channel",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648094-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/cover",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648097-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/cover_z",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648099-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/delta_time",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648102-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/fhd_normal",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648108-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/degrade_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648207-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/delta_time",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648209-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/digital_elevation_model",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648211-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/elev_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648213-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/elev_lowestmode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648215-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/elevation_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648217-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/elevation_bin0_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648219-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/elevation_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648221-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/elevation_lastbin_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648223-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/height_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648225-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/height_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648227-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/lat_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648229-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/lat_lowestmode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648231-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/latitude_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648233-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/latitude_bin0_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648235-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/latitude_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648237-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/latitude_lastbin_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648239-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/local_beam_azimuth",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648242-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/local_beam_elevation",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648244-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/lon_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648246-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/lon_lowestmode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648248-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/longitude_bin0",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648250-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/longitude_bin0_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648252-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/longitude_lastbin",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648254-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/longitude_lastbin_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648256-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/shot_number",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648258-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/solar_azimuth",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648260-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/geolocation/solar_elevation",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648262-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/l2a_quality_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648110-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/l2b_quality_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648112-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/land_cover_data/landsat_treecover",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648265-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/land_cover_data/landsat_water_persistence",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648267-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/land_cover_data/leaf_off_doy",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648269-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/land_cover_data/leaf_off_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648271-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/land_cover_data/leaf_on_cycle",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648273-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/land_cover_data/leaf_on_doy",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648276-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/land_cover_data/modis_nonvegetated",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648280-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/land_cover_data/modis_nonvegetated_sd",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648282-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/land_cover_data/modis_treecover",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648284-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/land_cover_data/modis_treecover_sd",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648286-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/land_cover_data/pft_class",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648289-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/land_cover_data/region_class",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648291-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/land_cover_data/urban_focal_window_size",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648293-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/land_cover_data/urban_proportion",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648296-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/master_frac",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648116-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/master_int",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648118-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/num_detectedmodes",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648120-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/omega",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648122-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/pai",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648124-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/pai_z",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648126-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/pavd_z",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648129-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/pgap_theta",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648132-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/pgap_theta_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648134-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/pgap_theta_z",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648136-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rg",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648138-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rh100",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648140-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rhog",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648142-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rhog_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648144-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rhov",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648146-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rhov_error",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648148-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rossg",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648151-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rv",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648154-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/algorithmrun_flag_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648298-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/algorithmrun_flag_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648300-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/algorithmrun_flag_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648302-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/algorithmrun_flag_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648304-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/algorithmrun_flag_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648306-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/algorithmrun_flag_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648308-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/pgap_theta_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648310-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/pgap_theta_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648312-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/pgap_theta_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648314-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/pgap_theta_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648316-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/pgap_theta_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648318-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/pgap_theta_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648320-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/pgap_theta_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648322-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/pgap_theta_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648324-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/pgap_theta_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648326-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/pgap_theta_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648329-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/pgap_theta_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648331-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/pgap_theta_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648333-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648335-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648337-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648340-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648343-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648345-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648347-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_amplitude_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648350-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_amplitude_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648352-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_amplitude_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648355-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_amplitude_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648357-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_amplitude_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648359-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_amplitude_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648361-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_amplitude_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648363-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_amplitude_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648366-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_amplitude_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648369-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_amplitude_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648371-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_amplitude_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648374-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_amplitude_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648376-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_center_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648378-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_center_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648380-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_center_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648383-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_center_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837648388-LPCLOUD"
#     },
#     {
#       "name": "/BEAM0001/rx_processing/rg_eg_center_a5",
# ...
#     },
#     {
#       "name": "/BEAM1011/rx_processing/pgap_theta_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653182-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/pgap_theta_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653184-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/pgap_theta_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653187-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653189-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653191-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653193-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653195-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653197-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653200-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653202-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653204-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653206-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653208-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653210-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653212-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653214-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653216-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653218-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653220-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653222-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_amplitude_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653224-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653226-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653229-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653232-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653235-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653237-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653240-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653242-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653244-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653246-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653248-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653250-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_center_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653252-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_chisq_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653254-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_chisq_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653256-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_chisq_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653258-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_chisq_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653260-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_chisq_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653262-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_chisq_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653264-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_flag_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653266-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_flag_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653268-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_flag_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653273-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_flag_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653275-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_flag_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653277-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_flag_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653279-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653281-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653283-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653285-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653287-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653289-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653291-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653293-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653295-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653297-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653299-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653301-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_gamma_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653304-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_niter_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653306-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_niter_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653308-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_niter_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653310-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_niter_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653312-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_niter_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653318-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_niter_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653327-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653341-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653356-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653370-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653375-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653381-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653383-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653385-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653387-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653389-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653391-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653393-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_eg_sigma_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653395-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_error_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653397-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_error_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653399-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_error_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653401-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_error_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653403-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_error_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653405-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rg_error_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653407-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rv_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653409-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rv_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653411-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rv_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653413-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rv_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653416-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rv_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653418-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rv_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653420-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rx_energy_a1",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653423-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rx_energy_a2",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653425-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rx_energy_a3",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653428-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rx_energy_a4",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653431-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rx_energy_a5",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653433-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/rx_energy_a6",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653435-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_processing/shot_number",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837653437-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_range_highestreturn",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652968-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_sample_count",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652970-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/rx_sample_start_index",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652972-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/selected_l2a_algorithm",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652974-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/selected_mode",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652976-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/selected_mode_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652978-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/selected_rg_algorithm",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652980-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/sensitivity",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652982-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/shot_number",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652985-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/stale_return_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652988-LPCLOUD"
#     },
#     {
#       "name": "/BEAM1011/surface_flag",
#       "href": "https://cmr.earthdata.nasa.gov/search/concepts/V2837652990-LPCLOUD"
#     }
#   ],
#   "capabilitiesVersion": "2"
# }

# %% [markdown]
# ## Create a Harmony Request
#
# There are several parameters that can be used for the Harmony request. See [the documentation](https://harmony-py.readthedocs.io/en/latest/) and [the introductory Harmony tutorial ](https://github.com/nasa/harmony-py/blob/main/examples/intro_tutorial.ipynb) for more details.

# %% [markdown]
# Harmony provides access to services that can transform data from NASA's [Earth Observing Systems Data and Information System (EOSDIS)](https://www.earthdata.nasa.gov/eosdis) Distributed Active Archive Centers (DAAC). [`harmony-py`](https://github.com/nasa/harmony-py) Python package is the recommended way of interacting with Harmony service. This notebook shows how to query and access customized [NASA's LP DAAC](https://lpdaac.usgs.gov/)  GEDI data outputs using [NASA's Harmony Services](https://harmony.earthdata.nasa.gov/).

# %% [markdown]
# ### GEDI Collection Concept ID
#
# `collection` is a Required parameter. The concept ID, which is the NASA EOSDIS collection ID provided in the Common Metadata Repository [(CMR)](https://cmr.earthdata.nasa.gov/search/site/docs/search/api.html) metadata **OR** Product short name (e.g. 'C2142776747-LPCLOUD') can be provided to search for collections.
#
# Below, `concept_id` is saved to a variable.

# %%
print(capabilities['shortName'], ',', capabilities['conceptId'])

concept_id = capabilities['conceptId']
print("concept_id:", concept_id)
# Out:
# GEDI02_B , C2142776747-LPCLOUD
# concept_id: C2142776747-LPCLOUD

# %% [markdown]
# ### GEDI Variable Subset

# %% [markdown]
# Take time to explore GEDI variables of importance via the [GEDI l2b dictionary](https://lpdaac.usgs.gov/documents/980/gedi_l2b_dictionary_P003_v2.html)

# %%
#See the append_field.txt which hasd a long dictionary of the fields and products of GEDI
#This ictionary will be used to subset our variables of intrest
#Notice this includes'GEDI01_B','GEDI02_A', and 'GEDI02_B'

append_url = "https://raw.githubusercontent.com/MayerT1/Prep_GEDI/main/append_field.txt"
append_text = requests.get(append_url).text

start_index = append_text.find("{")
end_index = append_text.rfind("}") + 1
dict_str = append_text[start_index:end_index]

append_dict = eval(dict_str)

# %%
#Display the dictionary we will use to subset later
append_dict
# Out:
# {'GEDI_L1B': ['geolocation/altitude_instrument',
#   'geolocation/local_beam_elevation',
#   'tx_sample_start_index',
#   'nsemean_odd',
#   'ancillary/master_time_epoch',
#   'noise_stddev_corrected',
#   'tx_pulseflag',
#   'geolocation/longitude_bin0_error',
#   'selection_stretchers_x',
#   'nsemean_even',
#   'geolocation/latitude_instrument',
#   'geolocation/digital_elevation_model',
#   'geolocation/longitude_instrument_error',
#   'geolocation/longitude_lastbin_error',
#   'tx_egsigma',
#   'geolocation/neutat_delay_total_bin0',
#   'rx_energy',
#   'master_frac',
#   'rx_sample_count',
#   'rxwaveform',
#   'tx_gloc',
#   'ancillary/mean_samples',
#   'geolocation/longitude_instrument',
#   'tx_eggamma_error',
#   'rx_offset',
#   'tx_egbias_error',
#   'geolocation/bounce_time_offset_lastbin',
#   'all_samples_sum',
#   'geophys_corr/tide_load',
#   'geolocation/solar_azimuth',
#   'geolocation/mean_sea_surface',
#   'geolocation/neutat_delay_total_lastbin',
#   'th_left_used',
#   'rx_sample_start_index',
#   'geophys_corr/tide_ocean',
#   'geophys_corr/tide_ocean_pole',
#   'tx_eggamma',
#   'geophys_corr/tide_pole',
#   'tx_sample_count',
#   'geolocation/surface_type',
#   'geolocation/neutat_delay_derivative_bin0',
#   'geolocation/digital_elevation_model_srtm',
#   'shot_number',
#   'txwaveform',
#   'geolocation/latitude_bin0_error',
#   'geolocation/altitude_instrument_error',
#   'channel',
#   'geolocation/longitude_lastbin',
#   'geolocation/latitude_lastbin',
#   'geolocation/elevation_bin0_error',
#   'geolocation/shot_number',
#   'geolocation/solar_elevation',
#   'geolocation/local_beam_elevation_error',
#   'tx_egamplitude',
#   'geolocation/latitude_bin0',
#   'geolocation/elevation_lastbin_error',
#   'ancillary/smoothing_width',
#   'geolocation/latitude_instrument_error',
#   'tx_egbias',
#   'geolocation/bounce_time_offset_bin0_error',
#   'geolocation/bounce_time_offset_bin0',
#   'rx_open',
#   'beam',
#   'geolocation/local_beam_azimuth',
#   'tx_egflag',
#   'tx_egsigma_error',
#   'geolocation/bounce_time_offset_lastbin_error',
#   'tx_gloc_error',
#   'geophys_corr/geoid',
#   'selection_stretchers_y',
#   'geolocation/latitude_lastbin_error',
#   'master_int',
#   'geolocation/range_bias_correction',
#   'geolocation/elevation_lastbin',
#   'geolocation/longitude_bin0',
#   'stale_return_flag',
#   'geolocation/delta_time',
#   'noise_mean_corrected',
#   'geolocation/local_beam_azimuth_error',
#   'geophys_corr/dynamic_atmosphere_correction',
#   'geophys_corr/delta_time',
#   'tx_egamplitude_error',
#   'geolocation/elevation_bin0',
#   'geolocation/neutat_delay_derivative_lastbin',
#   'geolocation/degrade',
#   'geophys_corr/tide_earth'],
#  'GEDI_L2A': ['rx_processing_a4/ancillary/rx_subbin_resolution',
#   'rx_processing_a6/ancillary/rx_use_fixed_thresholds',
#   'rx_processing_a1/rx_iwaveamps',
#   'rx_processing_a1/selected_mode_flag',
#   'rx_processing_a2/sd_sm',
#   'geolocation/elev_highestreturn_a2',
#   'rx_processing_a2/zcross0',
#   'geolocation/rh_a6',
#   'rx_processing_a2/ancillary/preprocessor_threshold',
#   'rx_processing_a4/ancillary/rx_max_mode_count',
#   'geolocation/elevs_allmodes_a3',
#   'rx_processing_a1/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a6/sd_sm',
#   'rx_processing_a3/rx_cumulative',
#   'geolocation/quality_flag_a6',
#   'lat_highestreturn',
#   'rx_1gaussfit/ancillary/rx_constraint_gloc_upper',
#   'rx_assess/ancillary/rx_pulsethresh',
#   'rx_processing_a3/selected_mode',
#   'rx_processing_a5/ancillary/enable_select_mode',
#   'geolocation/elev_highestreturn_a1',
#   'rx_processing_a1/toploc',
#   'rx_1gaussfit/ancillary/rx_estimate_bias',
#   'rx_processing_a1/search_start',
#   'rx_processing_a6/ancillary/rx_subbin_resolution',
#   'rx_processing_a6/zcross_localenergy',
#   'geolocation/energy_lowestmode_a6',
#   'master_frac',
#   'rx_processing_a4/ancillary/ampval_limit3',
#   'rx_processing_a6/selected_mode',
#   'geolocation/lat_highestreturn_a4',
#   'rx_processing_a1/ancillary/botlocdist_limit2',
#   'rx_processing_a3/min_detection_energy',
#   'rx_processing_a6/peak',
#   'rx_processing_a5/rx_modelocalslope',
#   'rx_processing_a6/ancillary/cumulative_energy_thresh',
#   'geolocation/lon_lowestmode_a6',
#   'rx_processing_a6/ancillary/pulse_sep_thresh',
#   'rx_processing_a5/lastmodeenergy',
#   'rx_1gaussfit/ancillary/rx_constraint_gamplitude_upper',
#   'geolocation/elevs_allmodes_a5',
#   'rx_assess/rx_energy',
#   'rx_processing_a6/rx_cumulative',
#   'delta_time',
#   'rx_processing_a2/rx_modelocs',
#   'rx_processing_a6/ancillary/rx_searchsize',
#   'elev_lowestmode',
#   'rx_processing_a3/selected_mode_flag',
#   'rx_processing_a5/pk_sm',
#   'rx_processing_a2/ancillary/rx_subbin_resolution',
#   'rx_processing_a5/ancillary/botlocdist_limit2',
#   'geolocation/lats_allmodes_a3',
#   'geolocation/lat_highestreturn_a5',
#   'geolocation/lon_lowestreturn_a6',
#   'rx_processing_a1/energy_sm',
#   'rx_processing_a5/stddev',
#   'rx_processing_a2/ancillary/rx_use_fixed_thresholds',
#   'geolocation/lon_lowestmode_a4',
#   'rx_processing_a3/ancillary/rx_back_threshold',
#   'geolocation/num_detectedmodes_a1',
#   'rx_processing_a3/ancillary/botlocdist_limit3',
#   'rx_processing_a1/ancillary/rx_searchsize',
#   'rx_processing_a2/toploc_miss',
#   'geolocation/lat_highestreturn_a6',
#   'rx_processing_a3/ancillary/botlocdist_limit1',
#   'rx_processing_a5/rx_modelocs',
#   'rx_processing_a6/ancillary/botlocdist_limit3',
#   'geolocation/lon_lowestreturn_a1',
#   'geolocation/rh_a1',
#   'land_cover_data/modis_nonvegetated_sd',
#   'rx_processing_a1/rx_modeenergytobotloc',
#   'rx_processing_a3/ancillary/pulse_sep_thresh',
#   'rx_processing_a2/toploc',
#   'rx_processing_a4/ancillary/rx_use_fixed_thresholds',
#   'geolocation/sensitivity_a2',
#   'rx_processing_a1/ancillary/energy_thresh',
#   'rx_processing_a5/rx_modeenergytobotloc',
#   'geolocation/lon_highestreturn_a6',
#   'rx_processing_a1/min_detection_threshold',
#   'rx_processing_a1/ancillary/rx_sentinel_location',
#   'rx_processing_a1/rx_nummodes',
#   'rx_processing_a6/zcross',
#   'rx_processing_a4/rx_modeenergytobotloc',
#   'selected_mode',
#   'rx_processing_a5/botloc',
#   'latitude_bin0_error',
#   'rx_processing_a3/search_start',
#   'rx_processing_a5/rx_modelocalenergyabovemean',
#   'rx_1gaussfit/ancillary/mpfit_tolerance',
#   'geolocation/lons_allmodes_a4',
#   'rx_1gaussfit/rx_gwidth',
#   'land_cover_data/pft_class',
#   'rx_processing_a4/rx_cumulative',
#   'geolocation/lat_lowestmode_a5',
#   'rx_processing_a3/rx_algrunflag',
#   'rx_processing_a3/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a4/toploc',
#   'rx_processing_a6/stddev',
#   'rx_processing_a1/ancillary/ampval_limit2',
#   'rx_assess/mean',
#   'rx_processing_a4/botloc_amp',
#   'geolocation/elev_lowestmode_a2',
#   'rx_processing_a1/ancillary/preprocessor_threshold',
#   'rx_processing_a5/smoothwidth_zcross',
#   'rx_processing_a1/zcross',
#   'rx_processing_a1/back_threshold',
#   'rx_processing_a6/smoothwidth',
#   'geolocation/lon_lowestmode_a2',
#   'rx_processing_a4/ancillary/rx_sentinel_location',
#   'geolocation/lat_lowestmode_a3',
#   'rx_processing_a1/ancillary/rx_front_threshold',
#   'rx_processing_a2/smoothwidth_zcross',
#   'rx_processing_a6/ancillary/ampval_limit3',
#   'rx_processing_a2/search_end',
#   'rx_processing_a4/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a3/zcross',
#   'rx_processing_a4/rx_modelocalenergyabovemean',
#   'rx_processing_a2/botloc',
#   'ancillary/l2a_alg_count',
#   'rx_processing_a6/energy_sm',
#   'rx_processing_a2/front_threshold',
#   'land_cover_data/urban_proportion',
#   'rx_processing_a6/search_start',
#   'rx_processing_a2/ancillary/rx_searchsize',
#   'sensitivity',
#   'rx_processing_a5/ancillary/rx_front_threshold',
#   'geolocation/num_detectedmodes_a4',
#   'geolocation/sensitivity_a6',
#   'geolocation/lats_allmodes_a5',
#   'geolocation/lon_lowestmode_a3',
#   'rx_processing_a6/ancillary/rx_front_threshold',
#   'rx_processing_a3/botloc_amp',
#   'rx_processing_a4/back_threshold',
#   'rx_processing_a3/rx_modelocalenergy',
#   'geolocation/quality_flag_a5',
#   'rx_processing_a3/ancillary/rx_use_fixed_thresholds',
#   'rx_processing_a6/rx_modewidths',
#   'rx_processing_a2/min_detection_threshold',
#   'geolocation/elev_highestreturn_a3',
#   'geolocation/lon_highestreturn_a2',
#   'rx_processing_a6/zcross0',
#   'rx_processing_a1/rx_modelocalenergy',
#   'rx_processing_a4/rx_iwaveamps',
#   'rx_processing_a3/ancillary/rx_subbin_resolution',
#   'rx_processing_a3/mean',
#   'lon_highestreturn',
#   'rx_processing_a3/smoothwidth_zcross',
#   'rx_processing_a4/peak',
#   'geolocation/num_detectedmodes_a6',
#   'rx_processing_a2/zcross',
#   'rx_processing_a6/ancillary/preprocessor_threshold',
#   'rx_processing_a3/mean_sm',
#   'rx_processing_a2/rx_modewidths',
#   'digital_elevation_model',
#   'land_cover_data/landsat_water_persistence',
#   'geolocation/lat_lowestmode_a4',
#   'rx_processing_a5/selected_mode',
#   'rx_1gaussfit/ancillary/rx_constraint_gamplitude_lower',
#   'rx_1gaussfit/rx_gflag',
#   'rx_processing_a6/botloc',
#   'rx_processing_a5/rx_iwaveamps',
#   'rx_processing_a4/ancillary/cumulative_energy_minimum',
#   'rx_processing_a4/ancillary/pulse_sep_thresh',
#   'rx_assess/quality_flag',
#   'rx_processing_a4/rx_modewidths',
#   'rx_processing_a3/ancillary/botlocdist_limit2',
#   'rx_processing_a3/ancillary/enable_select_mode',
#   'rx_processing_a6/search_end',
#   'rx_processing_a6/rx_modelocalenergyabovemean',
#   'geolocation/elev_highestreturn_a4',
#   'rx_processing_a2/ancillary/cumulative_energy_minimum',
#   'rx_processing_a5/search_end',
#   'geolocation/lats_allmodes_a2',
#   'geolocation/quality_flag_a2',
#   'rx_1gaussfit/ancillary/rx_constraint_gwidth_lower',
#   'rx_processing_a6/rx_nummodes',
#   'rx_processing_a5/rx_modelocalenergy',
#   'rx_processing_a2/ancillary/rx_sentinel_location',
#   'rx_processing_a3/zcross0',
#   'rx_processing_a3/sd_sm',
#   'land_cover_data/leaf_on_cycle',
#   'rx_processing_a3/front_threshold',
#   'rx_1gaussfit/ancillary/mpfit_max_func_evals',
#   'rx_processing_a3/ancillary/ampval_limit3',
#   'rx_processing_a1/zcross0',
#   'rx_processing_a5/ancillary/rx_sentinel_location',
#   'rx_assess/rx_clipbin0',
#   'rx_processing_a1/botloc',
#   'shot_number',
#   'rx_processing_a5/sd_sm',
#   'rx_processing_a6/botloc_amp',
#   'geolocation/elev_highestreturn_a6',
#   'digital_elevation_model_srtm',
#   'rx_1gaussfit/ancillary/rx_mean_noise_level',
#   'rx_processing_a2/rx_iwaveamps',
#   'rx_processing_a6/ancillary/amp_thresh',
#   'rx_processing_a6/ancillary/ampval_limit2',
#   'channel',
#   'rx_processing_a2/ancillary/enable_select_mode',
#   'rx_processing_a3/pk_sm',
#   'rx_assess/rx_maxamp',
#   'rx_assess/ancillary/rx_ampbounds_ul',
#   'rx_processing_a6/rx_modelocalenergy',
#   'land_cover_data/landsat_treecover',
#   'rx_assess/rx_clipbin_count',
#   'rx_processing_a6/lastmodeenergy',
#   'geolocation/latitude_1gfit',
#   'geolocation/elevation_1gfit',
#   'rx_processing_a3/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a1/smoothwidth',
#   'rx_processing_a6/rx_modeamps',
#   'rx_processing_a2/ancillary/cumulative_energy_thresh',
#   'rx_processing_a1/botloc_amp',
#   'rx_processing_a3/energy_sm',
#   'rx_processing_a2/search_start',
#   'rx_processing_a4/ancillary/botlocdist_limit1',
#   'rx_processing_a3/smoothwidth',
#   'rx_processing_a6/min_detection_threshold',
#   'geolocation/lat_lowestmode_a6',
#   'rh',
#   'rx_processing_a4/ancillary/enable_select_mode',
#   'rx_processing_a4/mean',
#   'rx_processing_a4/zcross_localenergy',
#   'geolocation/elev_highestreturn_a5',
#   'rx_processing_a1/selected_mode',
#   'rx_processing_a4/ancillary/ampval_limit2',
#   'geolocation/lon_highestreturn_a5',
#   'rx_processing_a2/rx_modelocalslope',
#   'rx_processing_a5/selected_mode_flag',
#   'geolocation/lon_highestreturn_a4',
#   'mean_sea_surface',
#   'geolocation/lat_lowestreturn_a2',
#   'surface_flag',
#   'rx_processing_a5/ancillary/rx_back_threshold',
#   'rx_processing_a5/peak',
#   'rx_processing_a2/back_threshold',
#   'geolocation/sensitivity_a4',
#   'geolocation/lat_lowestreturn_a3',
#   'rx_processing_a3/zcross_localenergy',
#   'rx_processing_a2/min_detection_energy',
#   'geolocation/energy_lowestmode_a5',
#   'rx_processing_a3/ancillary/rx_front_threshold',
#   'rx_processing_a4/energy_sm',
#   'rx_processing_a5/ancillary/botlocdist_limit3',
#   'geolocation/stale_return_flag',
#   'geolocation/lats_allmodes_a4',
#   'rx_processing_a3/ancillary/amp_thresh',
#   'rx_processing_a5/zcross_localenergy',
#   'rx_processing_a4/selected_mode_flag',
#   'geolocation/lat_highestreturn_a1',
#   'master_int',
#   'rx_processing_a2/zcross_amp',
#   'geolocation/lat_highestreturn_a3',
#   'rx_assess/ancillary/rx_ampbounds_ll',
#   'rx_processing_a3/ancillary/preprocessor_threshold',
#   'rx_processing_a6/ancillary/rx_max_mode_count',
#   'rx_processing_a5/ancillary/amp_thresh',
#   'rx_1gaussfit/rx_gloc_error',
#   'rx_processing_a2/ancillary/rx_max_mode_count',
#   'geolocation/lat_highestreturn_a2',
#   'land_cover_data/urban_focal_window_size',
#   'rx_processing_a2/smoothwidth',
#   'rx_processing_a3/ancillary/cumulative_energy_minimum',
#   'rx_1gaussfit/ancillary/rx_smoothwidth',
#   'rx_processing_a4/zcross0',
#   'rx_processing_a3/rx_modelocalslope',
#   'rx_processing_a6/ancillary/rx_back_threshold',
#   'geolocation/lats_allmodes_a1',
#   'geolocation/lons_allmodes_a1',
#   'geolocation/lon_lowestreturn_a3',
#   'rx_processing_a1/zcross_amp',
#   'lat_lowestmode',
#   'geolocation/lat_lowestreturn_a4',
#   'rx_processing_a5/front_threshold',
#   'geolocation/lon_highestreturn_a1',
#   'rx_processing_a2/ancillary/pulse_sep_thresh',
#   'rx_processing_a1/ancillary/botlocdist_limit1',
#   'geolocation/sensitivity_a3',
#   'rx_assess/rx_maxpeakloc',
#   'rx_processing_a5/ancillary/preprocessor_threshold',
#   'geolocation/rh_a5',
#   'rx_1gaussfit/ancillary/rx_constraint_gwidth_upper',
#   'geolocation/elev_lowestmode_a4',
#   'rx_processing_a1/mean',
#   'geolocation/lat_lowestmode_a1',
#   'land_cover_data/leaf_on_doy',
#   'geolocation/lon_lowestreturn_a5',
#   'longitude_bin0_error',
#   'geolocation/elev_lowestreturn_a1',
#   'rx_processing_a2/ancillary/botlocdist_limit2',
#   'geolocation/energy_lowestmode_a1',
#   'geolocation/elev_lowestmode_a6',
#   'rx_processing_a1/ancillary/botlocdist_limit3',
#   'rx_processing_a5/min_detection_energy',
#   'rx_processing_a6/min_detection_energy',
#   'rx_processing_a4/ancillary/amp_thresh',
#   'rx_1gaussfit/rx_gloc',
#   'rx_processing_a6/mean_sm',
#   'rx_assess/ancillary/rx_clipamp',
#   'rx_processing_a1/rx_modelocalenergyabovemean',
#   'rx_processing_a3/peak',
#   'rx_processing_a1/rx_modewidths',
#   'geolocation/num_detectedmodes_a3',
#   'geolocation/elev_lowestreturn_a4',
#   'rx_processing_a3/rx_modewidths',
#   'rx_processing_a4/ancillary/cumulative_energy_thresh',
#   'geolocation/lat_lowestreturn_a1',
#   'rx_processing_a1/rx_modelocs',
#   'rx_processing_a4/smoothwidth_zcross',
#   'rx_processing_a6/selected_mode_flag',
#   'rx_processing_a1/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a4/rx_algrunflag',
#   'rx_1gaussfit/rx_gamplitude',
#   'rx_processing_a1/ancillary/rx_subbin_resolution',
#   'rx_processing_a6/rx_modeenergytobotloc',
#   'rx_processing_a2/ancillary/ampval_limit3',
#   'rx_processing_a6/mean',
#   'geolocation/elevs_allmodes_a6',
#   'rx_1gaussfit/rx_gchisq',
#   'geolocation/elev_lowestmode_a3',
#   'geolocation/energy_lowestmode_a4',
#   'rx_processing_a3/rx_modelocalenergyabovemean',
#   'geolocation/elev_lowestreturn_a5',
#   'rx_processing_a5/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a2/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a1/pk_sm',
#   'geolocation/lons_allmodes_a3',
#   'geolocation/num_detectedmodes_a5',
#   'rx_processing_a2/energy_sm',
#   'land_cover_data/modis_treecover',
#   'rx_1gaussfit/rx_gbias_error',
#   'rx_processing_a4/botloc',
#   'rx_processing_a1/ancillary/cumulative_energy_thresh',
#   'geolocation/lat_lowestmode_a2',
#   'geolocation/rh_a2',
#   'rx_processing_a2/ancillary/amp_thresh',
#   'rx_processing_a2/ancillary/botlocdist_limit3',
#   'rx_processing_a2/lastmodeenergy',
#   'rx_processing_a3/ancillary/energy_thresh',
#   'rx_processing_a1/ancillary/rx_max_mode_count',
#   'geolocation/elevs_allmodes_a1',
#   'rx_processing_a6/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a4/stddev',
#   'rx_processing_a5/toploc',
#   'rx_processing_a5/ancillary/rx_use_fixed_thresholds',
#   'rx_assess/ancillary/smoothing_width_locs',
#   'geolocation/longitude_1gfit',
#   'geolocation/lons_allmodes_a6',
#   'rx_1gaussfit/rx_gwidth_error',
#   'rx_processing_a5/ancillary/ampval_limit3',
#   'rx_processing_a5/toploc_miss',
#   'rx_processing_a1/min_detection_energy',
#   'rx_processing_a3/lastmodeenergy',
#   'rx_processing_a3/rx_iwaveamps',
#   'rx_processing_a3/ancillary/ampval_limit2',
#   'geolocation/sensitivity_a5',
#   'rx_processing_a4/selected_mode',
#   'rx_processing_a4/search_end',
#   'rx_processing_a2/ancillary/rx_front_threshold',
#   'rx_processing_a4/search_start',
#   'geolocation/elev_lowestmode_a1',
#   'rx_processing_a5/rx_modeamps',
#   'rx_processing_a6/ancillary/energy_thresh',
#   'rx_processing_a2/ancillary/rx_smoothing_width_zcross',
#   'rx_processing_a6/ancillary/botlocdist_limit2',
#   'rx_processing_a4/ancillary/botlocdist_limit3',
#   'rx_1gaussfit/rx_gbias',
#   'rx_processing_a5/mean_sm',
#   'rx_processing_a6/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a1/ancillary/rx_use_fixed_thresholds',
#   'rx_processing_a4/rx_modelocalslope',
#   'beam',
#   'rx_processing_a6/front_threshold',
#   'rx_processing_a3/toploc_miss',
#   'rx_processing_a5/rx_modewidths',
#   'rx_processing_a3/ancillary/rx_searchsize',
#   'rx_processing_a4/ancillary/rx_back_threshold',
#   'rx_processing_a1/ancillary/ampval_limit3',
#   'rx_processing_a5/ancillary/pulse_sep_thresh',
#   'rx_processing_a4/ancillary/preprocessor_threshold',
#   'rx_processing_a2/zcross_localenergy',
#   'rx_processing_a4/rx_modeamps',
#   'rx_processing_a2/selected_mode_flag',
#   'rx_processing_a4/ancillary/energy_thresh',
#   'rx_processing_a2/rx_modelocalenergyabovemean',
#   'geolocation/elev_lowestreturn_a3',
#   'rx_processing_a6/rx_algrunflag',
#   'rx_processing_a3/ancillary/rx_sentinel_location',
#   'rx_processing_a5/ancillary/rx_subbin_resolution',
#   'rx_processing_a6/pk_sm',
#   'rx_processing_a4/pk_sm',
#   'geolocation/rh_a3',
#   'rx_processing_a4/min_detection_energy',
#   'rx_processing_a4/zcross',
#   'rx_processing_a4/smoothwidth',
#   'rx_processing_a2/ancillary/rx_back_threshold',
#   'rx_processing_a3/rx_modeamps',
#   'rx_processing_a5/energy_sm',
#   'lon_lowestmode',
#   'rx_processing_a6/rx_iwaveamps',
#   'rx_processing_a5/zcross_amp',
#   'rx_processing_a1/ancillary/pulse_sep_thresh',
#   'rx_processing_a6/ancillary/rx_sentinel_location',
#   'rx_processing_a3/ancillary/cumulative_energy_thresh',
#   'rx_processing_a1/smoothwidth_zcross',
#   'degrade_flag',
#   'geolocation/lons_allmodes_a5',
#   'rx_processing_a5/rx_cumulative',
#   'rx_processing_a4/ancillary/rx_front_threshold',
#   'rx_processing_a1/front_threshold',
#   'geolocation/quality_flag_a3',
#   'rx_processing_a1/stddev',
#   'rx_processing_a3/rx_modelocs',
#   'rx_processing_a2/stddev',
#   'rx_processing_a6/smoothwidth_zcross',
#   'rx_processing_a3/botloc',
#   'rx_processing_a5/ancillary/cumulative_energy_minimum',
#   'rx_processing_a3/rx_nummodes',
#   'rx_processing_a2/mean_sm',
#   'rx_processing_a1/rx_modelocalslope',
#   'geolocation/lats_allmodes_a6',
#   'rx_processing_a1/sd_sm',
#   'geolocation/lon_lowestreturn_a2',
#   'geolocation/lon_lowestreturn_a4',
#   'rx_processing_a2/mean',
#   'rx_processing_a6/toploc',
#   'elevation_bin0_error',
#   'rx_processing_a5/ancillary/rx_max_mode_count',
#   'land_cover_data/modis_nonvegetated',
#   'rx_processing_a1/mean_sm',
#   'geolocation/lat_lowestreturn_a6',
#   'rx_processing_a5/zcross',
#   'rx_processing_a4/front_threshold',
#   'rx_processing_a1/toploc_miss',
#   'rx_processing_a1/ancillary/cumulative_energy_minimum',
#   'rx_processing_a1/rx_cumulative',
#   'elevation_bias_flag',
#   'rx_processing_a2/rx_modeamps',
#   'rx_processing_a6/ancillary/botlocdist_limit1',
#   'geolocation/rh_a4',
#   'rx_processing_a5/search_start',
#   'rx_processing_a1/peak',
#   'rx_processing_a5/ancillary/cumulative_energy_thresh',
#   'energy_total',
#   'land_cover_data/leaf_off_flag',
#   'rx_processing_a5/mean',
#   'rx_processing_a6/ancillary/enable_select_mode',
#   'rx_processing_a6/rx_modelocalslope',
#   'rx_processing_a5/ancillary/rx_smoothing_width_locs',
#   'rx_processing_a5/back_threshold',
#   'rx_processing_a2/botloc_amp',
#   'land_cover_data/modis_treecover_sd',
#   'geolocation/elevs_allmodes_a4',
#   'geolocation/lon_lowestmode_a5',
#   'geolocation/quality_flag_a1',
#   'rx_processing_a6/ancillary/cumulative_energy_minimum',
#   'rx_processing_a2/pk_sm',
#   'rx_processing_a5/ancillary/rx_searchsize',
#   'rx_processing_a3/rx_modeenergytobotloc',
#   'rx_assess/ocean_calibration_shot_flag',
#   'rx_processing_a3/ancillary/rx_max_mode_count',
#   'geolocation/elev_lowestreturn_a2',
#   'rx_processing_a4/rx_nummodes',
#   'rx_processing_a2/rx_nummodes',
#   'num_detectedmodes',
#   'geolocation/energy_lowestmode_a2',
#   'rx_processing_a5/botloc_amp',
#   'rx_processing_a2/rx_modeenergytobotloc',
#   'rx_processing_a4/sd_sm',
#   'geolocation/elev_lowestmode_a5',
#   'rx_processing_a2/rx_modelocalenergy',
#   'rx_processing_a2/rx_cumulative',
#   'rx_assess/rx_assess_flag',
#   'rx_processing_a5/ancillary/ampval_limit2',
#   'geolocation/lat_lowestreturn_a5',
#   'rx_processing_a5/rx_algrunflag',
#   'rx_processing_a2/ancillary/energy_thresh',
#   'rx_processing_a1/rx_algrunflag',
#   'rx_processing_a4/zcross_amp',
#   'rx_processing_a5/min_detection_threshold',
#   'rx_processing_a2/ancillary/ampval_limit2',
#   'rx_processing_a6/rx_modelocs',
#   'rx_1gaussfit/rx_gamplitude_error',
#   'geolocation/sensitivity_a1',
#   'land_cover_data/leaf_off_doy',
#   'rx_processing_a1/ancillary/enable_select_mode',
#   'rx_processing_a4/ancillary/botlocdist_limit2',
#   'solar_elevation',
#   'land_cover_data/region_class',
#   'geolocation/elevs_allmodes_a2',
#   'rx_processing_a1/rx_modeamps',
#   'rx_processing_a4/lastmodeenergy',
#   'rx_1gaussfit/rx_giters',
#   'rx_processing_a4/rx_modelocalenergy',
#   'rx_processing_a1/search_end',
#   'geolocation/energy_lowestmode_a3',
#   'rx_processing_a1/zcross_localenergy',
#   'rx_processing_a3/back_threshold',
#   'rx_processing_a5/rx_nummodes',
#   'geolocation/elev_lowestreturn_a6',
#   'selected_mode_flag',
#   'elev_highestreturn',
#   'rx_processing_a4/rx_modelocs',
#   'solar_azimuth',
#   'rx_processing_a6/toploc_miss',
#   'rx_processing_a1/ancillary/rx_back_threshold',
#   'geolocation/num_detectedmodes_a2',
#   'rx_processing_a4/min_detection_threshold',
#   'rx_processing_a3/zcross_amp',
#   'selected_algorithm',
#   'geolocation/lon_highestreturn_a3',
#   'rx_processing_a5/ancillary/botlocdist_limit1',
#   'rx_processing_a3/stddev',
#   'geolocation/lon_lowestmode_a1',
#   'rx_processing_a3/min_detection_threshold',
#   'rx_processing_a5/smoothwidth',
#   'rx_1gaussfit/ancillary/rx_constraint_gloc_lower',
#   'rx_processing_a2/rx_algrunflag',
#   'rx_processing_a4/ancillary/rx_searchsize',
#   'rx_assess/sd_corrected',
#   'rx_processing_a6/zcross_amp',
#   'rx_processing_a3/search_end',
#   'quality_flag',
#   'rx_assess/ancillary/rx_ringthresh',
#   'rx_processing_a2/selected_mode',
#   'geolocation/lons_allmodes_a2',
#   'rx_processing_a1/ancillary/amp_thresh',
#   'rx_processing_a5/ancillary/energy_thresh',
#   'rx_processing_a4/toploc_miss',
#   'rx_processing_a3/toploc',
#   'rx_processing_a2/ancillary/botlocdist_limit1',
#   'rx_processing_a2/peak',
#   'rx_processing_a1/lastmodeenergy',
#   'rx_processing_a4/ancillary/rx_smoothing_width_zcross',
#   'geolocation/quality_flag_a4',
#   'rx_processing_a5/zcross0',
#   'rx_processing_a4/mean_sm',
#   'rx_processing_a6/back_threshold',
#   'rx_1gaussfit/ancillary/mpfit_maxiters',
#   'rx_assess/mean_64kadjusted'],
#  'GEDI_L2B': ['rx_processing/rg_eg_flag_a4',
#   'rx_processing/rg_eg_gamma_error_a5',
#   'rx_processing/rg_eg_gamma_error_a1',
#   'rx_processing/rg_error_a3',
#   'rx_processing/rg_eg_amplitude_a2',
#   'geolocation/local_beam_elevation',
#   'ancillary/rg_eg_constraint_center_buffer',
#   'rx_processing/rx_energy_a6',
#   'ancillary/tx_noise_stddev_multiplier',
#   'pgap_theta_z',
#   'rx_processing/rg_eg_center_error_a5',
#   'rx_processing/pgap_theta_a4',
#   'land_cover_data/modis_nonvegetated',
#   'geolocation/longitude_bin0_error',
#   'rx_processing/rg_error_a1',
#   'geolocation/elev_highestreturn',
#   'land_cover_data/landsat_water_persistence',
#   'land_cover_data/leaf_on_doy',
#   'rx_processing/algorithmrun_flag_a5',
#   'geolocation/lon_lowestmode',
#   'rx_processing/rx_energy_a4',
#   'geolocation/digital_elevation_model',
#   'rhov',
#   'rx_processing/rg_a5',
#   'rx_processing/rg_error_a2',
#   'geolocation/longitude_lastbin_error',
#   'rx_processing/rg_a6',
#   'rx_processing/rg_eg_gamma_a1',
#   'l2b_quality_flag',
#   'rx_processing/rg_eg_amplitude_error_a4',
#   'rx_processing/rg_eg_amplitude_a3',
#   'rx_processing/pgap_theta_error_a3',
#   'land_cover_data/leaf_off_flag',
#   'rx_processing/rv_a2',
#   'geolocation/lon_highestreturn',
#   'ancillary/dz',
#   'master_frac',
#   'rx_processing/rg_eg_niter_a1',
#   'l2a_quality_flag',
#   'rx_sample_count',
#   'rx_processing/rg_a4',
#   'pavd_z',
#   'geolocation/lat_highestreturn',
#   'land_cover_data/modis_treecover_sd',
#   'rx_processing/rg_eg_amplitude_error_a2',
#   'rx_processing/rg_eg_center_a2',
#   'rx_processing/rg_eg_center_error_a6',
#   'geolocation/solar_azimuth',
#   'rv',
#   'rx_processing/shot_number',
#   'rx_processing/rg_eg_sigma_a3',
#   'rx_processing/rg_eg_center_a1',
#   'rx_processing/rg_eg_sigma_error_a5',
#   'rx_processing/rg_eg_flag_a6',
#   'rx_processing/rg_eg_flag_a1',
#   'rx_sample_start_index',
#   'rx_processing/pgap_theta_a1',
#   'rx_processing/rg_a2',
#   'omega',
#   'rx_processing/pgap_theta_error_a5',
#   'rx_processing/pgap_theta_error_a4',
#   'land_cover_data/leaf_on_cycle',
#   'rx_processing/rg_eg_niter_a5',
#   'ancillary/rg_eg_mpfit_max_func_evals',
#   'rx_processing/rg_eg_center_error_a4',
#   'rx_processing/rg_eg_gamma_a2',
#   'num_detectedmodes',
#   'rhov_error',
#   'rx_processing/pgap_theta_error_a6',
#   'rx_processing/rg_eg_center_error_a3',
#   'rhog_error',
#   'rx_processing/rg_eg_gamma_a5',
#   'shot_number',
#   'geolocation/latitude_bin0_error',
#   'rx_processing/rg_eg_center_a5',
#   'rx_processing/rg_eg_flag_a3',
#   'fhd_normal',
#   'rx_processing/rg_error_a4',
#   'rx_processing/rg_eg_sigma_error_a2',
#   'rx_processing/algorithmrun_flag_a3',
#   'land_cover_data/modis_treecover',
#   'channel',
#   'rx_processing/rg_eg_gamma_error_a2',
#   'cover',
#   'geolocation/lat_lowestmode',
#   'rx_processing/rg_eg_chisq_a4',
#   'rx_processing/rg_eg_flag_a5',
#   'rx_range_highestreturn',
#   'geolocation/longitude_lastbin',
#   'rx_processing/rg_eg_sigma_a1',
#   'land_cover_data/modis_nonvegetated_sd',
#   'land_cover_data/landsat_treecover',
#   'rx_processing/rg_eg_gamma_error_a4',
#   'rx_processing/rg_eg_amplitude_error_a5',
#   'rx_processing/rg_eg_gamma_a3',
#   'rx_processing/algorithmrun_flag_a2',
#   'geolocation/latitude_lastbin',
#   'rx_processing/rg_error_a5',
#   'geolocation/elevation_bin0_error',
#   'land_cover_data/leaf_off_doy',
#   'rx_processing/rv_a4',
#   'rx_processing/rv_a6',
#   'rx_processing/rx_energy_a1',
#   'rhog',
#   'geolocation/shot_number',
#   'geolocation/solar_elevation',
#   'land_cover_data/region_class',
#   'rx_processing/rv_a3',
#   'rx_processing/rg_eg_amplitude_a4',
#   'rx_processing/rg_eg_gamma_a6',
#   'rx_processing/rx_energy_a5',
#   'rx_processing/algorithmrun_flag_a4',
#   'rx_processing/rg_eg_gamma_a4',
#   'geolocation/latitude_bin0',
#   'selected_mode',
#   'geolocation/elevation_lastbin_error',
#   'rx_processing/rv_a5',
#   'rx_processing/pgap_theta_error_a2',
#   'rx_processing/rv_a1',
#   'rx_processing/rg_eg_niter_a3',
#   'rx_processing/rg_eg_flag_a2',
#   'selected_mode_flag',
#   'land_cover_data/pft_class',
#   'rx_processing/rg_eg_chisq_a1',
#   'rx_processing/rg_eg_center_a3',
#   'rx_processing/rg_eg_center_a6',
#   'ancillary/rg_eg_mpfit_tolerance',
#   'rx_processing/rg_eg_amplitude_a6',
#   'rx_processing/rg_eg_center_error_a1',
#   'algorithmrun_flag',
#   'rx_processing/rg_eg_center_error_a2',
#   'ancillary/rg_eg_mpfit_maxiters',
#   'geolocation/height_lastbin',
#   'rx_processing/pgap_theta_a3',
#   'rx_processing/algorithmrun_flag_a1',
#   'rx_processing/pgap_theta_error_a1',
#   'surface_flag',
#   'geolocation/height_bin0',
#   'rossg',
#   'rx_processing/rx_energy_a3',
#   'pai_z',
#   'beam',
#   'rx_processing/rx_energy_a2',
#   'ancillary/maxheight_cuttoff',
#   'rx_processing/pgap_theta_a6',
#   'rx_processing/rg_eg_chisq_a3',
#   'rx_processing/rg_error_a6',
#   'rx_processing/rg_eg_chisq_a2',
#   'geolocation/local_beam_azimuth',
#   'rh100',
#   'rx_processing/pgap_theta_a5',
#   'rx_processing/rg_eg_gamma_error_a3',
#   'rx_processing/algorithmrun_flag_a6',
#   'rx_processing/rg_eg_sigma_a5',
#   'rx_processing/rg_a1',
#   'rx_processing/rg_eg_niter_a6',
#   'pgap_theta',
#   'rx_processing/rg_eg_center_a4',
#   'rx_processing/rg_eg_amplitude_a1',
#   'geolocation/latitude_lastbin_error',
#   'rx_processing/rg_eg_niter_a2',
#   'rx_processing/rg_eg_amplitude_error_a6',
#   'rx_processing/pgap_theta_a2',
#   'cover_z',
#   'rx_processing/rg_eg_amplitude_error_a1',
#   'rx_processing/rg_eg_sigma_error_a4',
#   'ancillary/l2a_alg_count',
#   'master_int',
#   'pai',
#   'rx_processing/rg_a3',
#   'land_cover_data/urban_proportion',
#   'rx_processing/rg_eg_gamma_error_a6',
#   'rx_processing/rg_eg_sigma_a4',
#   'geolocation/elevation_lastbin',
#   'geolocation/longitude_bin0',
#   'sensitivity',
#   'rx_processing/rg_eg_sigma_a2',
#   'stale_return_flag',
#   'rx_processing/rg_eg_chisq_a6',
#   'land_cover_data/urban_focal_window_size',
#   'rx_processing/rg_eg_niter_a4',
#   'rg',
#   'pgap_theta_error',
#   'rx_processing/rg_eg_sigma_error_a3',
#   'geolocation/degrade_flag',
#   'selected_l2a_algorithm',
#   'rx_processing/rg_eg_sigma_error_a1',
#   'geolocation/elev_lowestmode',
#   'geolocation/delta_time',
#   'rx_processing/rg_eg_amplitude_error_a3',
#   'selected_rg_algorithm',
#   'ancillary/signal_search_buff',
#   'rx_processing/rg_eg_chisq_a5',
#   'rx_processing/rg_eg_amplitude_a5',
#   'rx_processing/rg_eg_sigma_a6',
#   'geolocation/elevation_bin0',
#   'rx_processing/rg_eg_sigma_error_a6'],
#  'GEDI_L4A': ['agbd',
#   'agbd_pi_lower',
#   'agbd_pi_upper',
#   'agbd_se',
#   'agbd_t',
#   'agbd_t_se',
#   'algorithm_run_flag',
#   'beam',
#   'channel',
#   'degrade_flag',
#   'delta_time',
#   'elev_lowestmode',
#   'l2_quality_flag',
#   'l4_quality_flag',
#   'lat_lowestmode',
#   'lon_lowestmode',
#   'master_frac',
#   'master_int',
#   'predict_stratum',
#   'predictor_limit_flag',
#   'response_limit_flag',
#   'selected_algorithm',
#   'selected_mode',
#   'selected_mode_flag',
#   'sensitivity',
#   'shot_number',
#   'solar_elevation',
#   'surface_flag',
#   'xvar',
#   'geolocation/elev_lowestmode_aN',
#   'geolocation/lat_lowestmode_aN',
#   'geolocation/lon_lowestmode_aN',
#   'geolocation/sensitivity_aN',
#   'geolocation/shot_number',
#   'geolocation/stale_return_flag',
#   'agbd_prediction/agbd_aN',
#   'agbd_prediction/agbd_pi_lower_aN',
#   'agbd_prediction/agbd_pi_upper_aN',
#   'agbd_prediction/agbd_se_aN',
#   'agbd_prediction/agbd_t_aN',
#   'agbd_prediction/agbd_t_pi_lower_aN',
#   'agbd_prediction/agbd_t_pi_upper_aN',
#   'agbd_prediction/agbd_t_se_aN',
#   'agbd_prediction/algorithm_run_flag_aN',
#   'agbd_prediction/l2_quality_flag_aN',
#   'agbd_prediction/l4_quality_flag_aN',
#   'agbd_prediction/predictor_limit_flag_aN',
#   'agbd_prediction/response_limit_flag_aN',
#   'agbd_prediction/selected_mode_aN',
#   'agbd_prediction/selected_mode_flag_aN',
#   'agbd_prediction/shot_number',
#   'agbd_prediction/xvar_aN',
#   'land_cover_data/landsat_treecover',
#   'land_cover_data/landsat_water_persistence',
#   'land_cover_data/leaf_off_doy',
#   'land_cover_data/leaf_off_flag',
#   'land_cover_data/leaf_on_cycle',
#   'land_cover_data/leaf_on_doy',
#   'land_cover_data/pft_class',
#   'land_cover_data/region_class',
#   'land_cover_data/shot_number',
#   'land_cover_data/urban_focal_window_size',
#   'land_cover_data/urban_proportion',
#   'ancillary/model_data/predict_stratum',
#   'ancillary/model_data/model_group',
#   'ancillary/model_data/model_name',
#   'ancillary/model_data/model_id',
#   'ancillary/model_data/bias_correction_name',
#   'ancillary/model_data/bias_correction_value',
#   'ancillary/model_data/dof',
#   'ancillary/model_data/fit_stratum',
#   'ancillary/model_data/par',
#   'ancillary/model_data/npar',
#   'ancillary/model_data/predictor_id',
#   'ancillary/model_data/predictor_max_value',
#   'ancillary/model_data/response_max_value',
#   'ancillary/model_data/rh_index',
#   'ancillary/model_data/rse',
#   'ancillary/model_data/vcov',
#   'ancillary/model_data/x_transform',
#   'ancillary/model_data/y_transform',
#   'ancillary/pft_lut/pft_class',
#   'ancillary/pft_lut/pft_name',
#   'ancillary/region_lut/region_class',
#   'ancillary/region_lut/region_name']}

# %%
# print only the dictionary fo avaible GEDI 2 B products to explore
gedi_l2b = append_dict.get('GEDI_L2B', {})

# Step 4: Print items under 'GEDI_L2B'
print("Items under 'GEDI_L2B':")
for item in gedi_l2b:
    print(item)
# Out:
# Items under 'GEDI_L2B':
# rx_processing/rg_eg_flag_a4
# rx_processing/rg_eg_gamma_error_a5
# rx_processing/rg_eg_gamma_error_a1
# rx_processing/rg_error_a3
# rx_processing/rg_eg_amplitude_a2
# geolocation/local_beam_elevation
# ancillary/rg_eg_constraint_center_buffer
# rx_processing/rx_energy_a6
# ancillary/tx_noise_stddev_multiplier
# pgap_theta_z
# rx_processing/rg_eg_center_error_a5
# rx_processing/pgap_theta_a4
# land_cover_data/modis_nonvegetated
# geolocation/longitude_bin0_error
# rx_processing/rg_error_a1
# geolocation/elev_highestreturn
# land_cover_data/landsat_water_persistence
# land_cover_data/leaf_on_doy
# rx_processing/algorithmrun_flag_a5
# geolocation/lon_lowestmode
# rx_processing/rx_energy_a4
# geolocation/digital_elevation_model
# rhov
# rx_processing/rg_a5
# rx_processing/rg_error_a2
# geolocation/longitude_lastbin_error
# rx_processing/rg_a6
# rx_processing/rg_eg_gamma_a1
# l2b_quality_flag
# rx_processing/rg_eg_amplitude_error_a4
# rx_processing/rg_eg_amplitude_a3
# rx_processing/pgap_theta_error_a3
# land_cover_data/leaf_off_flag
# rx_processing/rv_a2
# geolocation/lon_highestreturn
# ancillary/dz
# master_frac
# rx_processing/rg_eg_niter_a1
# l2a_quality_flag
# rx_sample_count
# rx_processing/rg_a4
# pavd_z
# geolocation/lat_highestreturn
# land_cover_data/modis_treecover_sd
# rx_processing/rg_eg_amplitude_error_a2
# rx_processing/rg_eg_center_a2
# rx_processing/rg_eg_center_error_a6
# geolocation/solar_azimuth
# rv
# rx_processing/shot_number
# rx_processing/rg_eg_sigma_a3
# rx_processing/rg_eg_center_a1
# rx_processing/rg_eg_sigma_error_a5
# rx_processing/rg_eg_flag_a6
# rx_processing/rg_eg_flag_a1
# rx_sample_start_index
# rx_processing/pgap_theta_a1
# rx_processing/rg_a2
# omega
# rx_processing/pgap_theta_error_a5
# rx_processing/pgap_theta_error_a4
# land_cover_data/leaf_on_cycle
# rx_processing/rg_eg_niter_a5
# ancillary/rg_eg_mpfit_max_func_evals
# rx_processing/rg_eg_center_error_a4
# rx_processing/rg_eg_gamma_a2
# num_detectedmodes
# rhov_error
# rx_processing/pgap_theta_error_a6
# rx_processing/rg_eg_center_error_a3
# rhog_error
# rx_processing/rg_eg_gamma_a5
# shot_number
# geolocation/latitude_bin0_error
# rx_processing/rg_eg_center_a5
# rx_processing/rg_eg_flag_a3
# fhd_normal
# rx_processing/rg_error_a4
# rx_processing/rg_eg_sigma_error_a2
# rx_processing/algorithmrun_flag_a3
# land_cover_data/modis_treecover
# channel
# rx_processing/rg_eg_gamma_error_a2
# cover
# geolocation/lat_lowestmode
# rx_processing/rg_eg_chisq_a4
# rx_processing/rg_eg_flag_a5
# rx_range_highestreturn
# geolocation/longitude_lastbin
# rx_processing/rg_eg_sigma_a1
# land_cover_data/modis_nonvegetated_sd
# land_cover_data/landsat_treecover
# rx_processing/rg_eg_gamma_error_a4
# rx_processing/rg_eg_amplitude_error_a5
# rx_processing/rg_eg_gamma_a3
# rx_processing/algorithmrun_flag_a2
# geolocation/latitude_lastbin
# rx_processing/rg_error_a5
# geolocation/elevation_bin0_error
# land_cover_data/leaf_off_doy
# rx_processing/rv_a4
# rx_processing/rv_a6
# rx_processing/rx_energy_a1
# rhog
# geolocation/shot_number
# geolocation/solar_elevation
# land_cover_data/region_class
# rx_processing/rv_a3
# rx_processing/rg_eg_amplitude_a4
# rx_processing/rg_eg_gamma_a6
# rx_processing/rx_energy_a5
# rx_processing/algorithmrun_flag_a4
# rx_processing/rg_eg_gamma_a4
# geolocation/latitude_bin0
# selected_mode
# geolocation/elevation_lastbin_error
# rx_processing/rv_a5
# rx_processing/pgap_theta_error_a2
# rx_processing/rv_a1
# rx_processing/rg_eg_niter_a3
# rx_processing/rg_eg_flag_a2
# selected_mode_flag
# land_cover_data/pft_class
# rx_processing/rg_eg_chisq_a1
# rx_processing/rg_eg_center_a3
# rx_processing/rg_eg_center_a6
# ancillary/rg_eg_mpfit_tolerance
# rx_processing/rg_eg_amplitude_a6
# rx_processing/rg_eg_center_error_a1
# algorithmrun_flag
# rx_processing/rg_eg_center_error_a2
# ancillary/rg_eg_mpfit_maxiters
# geolocation/height_lastbin
# rx_processing/pgap_theta_a3
# rx_processing/algorithmrun_flag_a1
# rx_processing/pgap_theta_error_a1
# surface_flag
# geolocation/height_bin0
# rossg
# rx_processing/rx_energy_a3
# pai_z
# beam
# rx_processing/rx_energy_a2
# ancillary/maxheight_cuttoff
# rx_processing/pgap_theta_a6
# rx_processing/rg_eg_chisq_a3
# rx_processing/rg_error_a6
# rx_processing/rg_eg_chisq_a2
# geolocation/local_beam_azimuth
# rh100
# rx_processing/pgap_theta_a5
# rx_processing/rg_eg_gamma_error_a3
# rx_processing/algorithmrun_flag_a6
# rx_processing/rg_eg_sigma_a5
# rx_processing/rg_a1
# rx_processing/rg_eg_niter_a6
# pgap_theta
# rx_processing/rg_eg_center_a4
# rx_processing/rg_eg_amplitude_a1
# geolocation/latitude_lastbin_error
# rx_processing/rg_eg_niter_a2
# rx_processing/rg_eg_amplitude_error_a6
# rx_processing/pgap_theta_a2
# cover_z
# rx_processing/rg_eg_amplitude_error_a1
# rx_processing/rg_eg_sigma_error_a4
# ancillary/l2a_alg_count
# master_int
# pai
# rx_processing/rg_a3
# land_cover_data/urban_proportion
# rx_processing/rg_eg_gamma_error_a6
# rx_processing/rg_eg_sigma_a4
# geolocation/elevation_lastbin
# geolocation/longitude_bin0
# sensitivity
# rx_processing/rg_eg_sigma_a2
# stale_return_flag
# rx_processing/rg_eg_chisq_a6
# land_cover_data/urban_focal_window_size
# rx_processing/rg_eg_niter_a4
# rg
# pgap_theta_error
# rx_processing/rg_eg_sigma_error_a3
# geolocation/degrade_flag
# selected_l2a_algorithm
# rx_processing/rg_eg_sigma_error_a1
# geolocation/elev_lowestmode
# geolocation/delta_time
# rx_processing/rg_eg_amplitude_error_a3
# selected_rg_algorithm
# ancillary/signal_search_buff
# rx_processing/rg_eg_chisq_a5
# rx_processing/rg_eg_amplitude_a5
# rx_processing/rg_eg_sigma_a6
# geolocation/elevation_bin0
# rx_processing/rg_eg_sigma_error_a6

# %% [markdown]
# Select your variables of intrest

# %%
#Selecting the 'GEDI02_B' of intrest to then be downloaded
#subset_L2B = ['geolocation/lat_lowestmode', 'geolocation/lon_lowestmode', 'geolocation/degrade_flag', 'geolocation/digital_elevation_model','geolocation/elev_lowestmode','geolocation/elev_highestreturn','l2b_quality_flag','rh100','fhd_normal','cover','cover_z','pai','pai_z','pavd_z','rhov','omega','land_cover_data/pft_class']


# #Selecting the 'GEDI02_B' of intrest to then be downloaded
# subset_L2B = ['geolocation/lat_lowestmode', 'geolocation/lon_lowestmode', 'geolocation/degrade_flag', 'geolocation/digital_elevation_model','geolocation/elev_lowestmode','geolocation/elev_highestreturn','l2b_quality_flag','rh100','fhd_normal','pai'] #'cover','cover_z','pai','pai_z','pavd_z','rhov','omega','land_cover_data/pft_class']


subset_L2B =  ['geolocation/lat_lowestmode','geolocation/lon_lowestmode','geolocation/solar_elevation','geolocation/local_beam_elevation','selected_l2a_algorithm','geolocation/degrade_flag','l2b_quality_flag','geolocation/digital_elevation_model','geolocation/elev_lowestmode','geolocation/elev_highestreturn', 'rh100','num_detectedmodes', 'sensitivity','land_cover_data/leaf_off_flag','/geolocation/solar_elevation','pgap_theta_z', 'pai', 'pai_z', 'fhd_normal', 'pavd_z', 'cover','cover_z','pgap_theta','pgap_theta_error','rhov','rhov_error','rhog', 'rhog_error']

# %%
subset_L2B
# Out:
# ['geolocation/lat_lowestmode',
#  'geolocation/lon_lowestmode',
#  'geolocation/solar_elevation',
#  'geolocation/local_beam_elevation',
#  'selected_l2a_algorithm',
#  'geolocation/degrade_flag',
#  'l2b_quality_flag',
#  'geolocation/digital_elevation_model',
#  'geolocation/elev_lowestmode',
#  'geolocation/elev_highestreturn',
#  'rh100',
#  'num_detectedmodes',
#  'sensitivity',
#  'land_cover_data/leaf_off_flag',
#  '/geolocation/solar_elevation',
#  'pgap_theta_z',
#  'pai',
#  'pai_z',
#  'fhd_normal',
#  'pavd_z',
#  'cover',
#  'cover_z',
#  'pgap_theta',
#  'pgap_theta_error',
#  'rhov',
#  'rhov_error',
#  'rhog',
#  'rhog_error']

# %%
### filter those varibales ofintrest out of the larger list
selected_L2B = []
for s in subset_L2B:
    my_var = [v for v in gedi_l2b if v.endswith(f'{s}')]
    if len(my_var) == 1:
        selected_L2B.append(my_var[0])

    elif len(my_var) > 1:
        my_var = [v for v in my_var if v.startswith(f'{s}')]

        for l in my_var:
            if l not in selected_L2B:
                selected_L2B.append(l)

selected_L2B
# Out:
# ['geolocation/lat_lowestmode',
#  'geolocation/lon_lowestmode',
#  'geolocation/solar_elevation',
#  'geolocation/local_beam_elevation',
#  'selected_l2a_algorithm',
#  'geolocation/degrade_flag',
#  'l2b_quality_flag',
#  'geolocation/digital_elevation_model',
#  'geolocation/elev_lowestmode',
#  'geolocation/elev_highestreturn',
#  'rh100',
#  'num_detectedmodes',
#  'sensitivity',
#  'land_cover_data/leaf_off_flag',
#  'pgap_theta_z',
#  'pai',
#  'pai_z',
#  'fhd_normal',
#  'pavd_z',
#  'cover',
#  'cover_z',
#  'pgap_theta',
#  'pgap_theta_error',
#  'rhov',
#  'rhov_error',
#  'rhog',
#  'rhog_error']

# %% [markdown]
# Select the subset of your desired beams. For instance, you can only select Full Power beams ('BEAM0101', 'BEAM0110', 'BEAM1000', 'BEAM1011').

# %%
#Selecting a few beams: ['BEAM0000', 'BEAM0001', 'BEAM0010', 'BEAM0011', 'BEAM0101', 'BEAM0110', 'BEAM1000', 'BEAM1011']
beams = ['BEAM0101', 'BEAM0110', 'BEAM1000', 'BEAM1011']

# %%
#Append our beams of intrest to our variables of intrest
#the subset list will then be used throughout
subset = []
for b in beams:
    beam_subset = [f'/{b}/{layer}' for layer in selected_L2B]
    [subset.append(i) for i in beam_subset]
subset
# Out:
# ['/BEAM0101/geolocation/lat_lowestmode',
#  '/BEAM0101/geolocation/lon_lowestmode',
#  '/BEAM0101/geolocation/solar_elevation',
#  '/BEAM0101/geolocation/local_beam_elevation',
#  '/BEAM0101/selected_l2a_algorithm',
#  '/BEAM0101/geolocation/degrade_flag',
#  '/BEAM0101/l2b_quality_flag',
#  '/BEAM0101/geolocation/digital_elevation_model',
#  '/BEAM0101/geolocation/elev_lowestmode',
#  '/BEAM0101/geolocation/elev_highestreturn',
#  '/BEAM0101/rh100',
#  '/BEAM0101/num_detectedmodes',
#  '/BEAM0101/sensitivity',
#  '/BEAM0101/land_cover_data/leaf_off_flag',
#  '/BEAM0101/pgap_theta_z',
#  '/BEAM0101/pai',
#  '/BEAM0101/pai_z',
#  '/BEAM0101/fhd_normal',
#  '/BEAM0101/pavd_z',
#  '/BEAM0101/cover',
#  '/BEAM0101/cover_z',
#  '/BEAM0101/pgap_theta',
#  '/BEAM0101/pgap_theta_error',
#  '/BEAM0101/rhov',
#  '/BEAM0101/rhov_error',
#  '/BEAM0101/rhog',
#  '/BEAM0101/rhog_error',
#  '/BEAM0110/geolocation/lat_lowestmode',
#  '/BEAM0110/geolocation/lon_lowestmode',
#  '/BEAM0110/geolocation/solar_elevation',
#  '/BEAM0110/geolocation/local_beam_elevation',
#  '/BEAM0110/selected_l2a_algorithm',
#  '/BEAM0110/geolocation/degrade_flag',
#  '/BEAM0110/l2b_quality_flag',
#  '/BEAM0110/geolocation/digital_elevation_model',
#  '/BEAM0110/geolocation/elev_lowestmode',
#  '/BEAM0110/geolocation/elev_highestreturn',
#  '/BEAM0110/rh100',
#  '/BEAM0110/num_detectedmodes',
#  '/BEAM0110/sensitivity',
#  '/BEAM0110/land_cover_data/leaf_off_flag',
#  '/BEAM0110/pgap_theta_z',
#  '/BEAM0110/pai',
#  '/BEAM0110/pai_z',
#  '/BEAM0110/fhd_normal',
#  '/BEAM0110/pavd_z',
#  '/BEAM0110/cover',
#  '/BEAM0110/cover_z',
#  '/BEAM0110/pgap_theta',
#  '/BEAM0110/pgap_theta_error',
#  '/BEAM0110/rhov',
#  '/BEAM0110/rhov_error',
#  '/BEAM0110/rhog',
#  '/BEAM0110/rhog_error',
#  '/BEAM1000/geolocation/lat_lowestmode',
#  '/BEAM1000/geolocation/lon_lowestmode',
#  '/BEAM1000/geolocation/solar_elevation',
#  '/BEAM1000/geolocation/local_beam_elevation',
#  '/BEAM1000/selected_l2a_algorithm',
#  '/BEAM1000/geolocation/degrade_flag',
#  '/BEAM1000/l2b_quality_flag',
#  '/BEAM1000/geolocation/digital_elevation_model',
#  '/BEAM1000/geolocation/elev_lowestmode',
#  '/BEAM1000/geolocation/elev_highestreturn',
#  '/BEAM1000/rh100',
#  '/BEAM1000/num_detectedmodes',
#  '/BEAM1000/sensitivity',
#  '/BEAM1000/land_cover_data/leaf_off_flag',
#  '/BEAM1000/pgap_theta_z',
#  '/BEAM1000/pai',
#  '/BEAM1000/pai_z',
#  '/BEAM1000/fhd_normal',
#  '/BEAM1000/pavd_z',
#  '/BEAM1000/cover',
#  '/BEAM1000/cover_z',
#  '/BEAM1000/pgap_theta',
#  '/BEAM1000/pgap_theta_error',
#  '/BEAM1000/rhov',
#  '/BEAM1000/rhov_error',
#  '/BEAM1000/rhog',
#  '/BEAM1000/rhog_error',
#  '/BEAM1011/geolocation/lat_lowestmode',
#  '/BEAM1011/geolocation/lon_lowestmode',
#  '/BEAM1011/geolocation/solar_elevation',
#  '/BEAM1011/geolocation/local_beam_elevation',
#  '/BEAM1011/selected_l2a_algorithm',
#  '/BEAM1011/geolocation/degrade_flag',
#  '/BEAM1011/l2b_quality_flag',
#  '/BEAM1011/geolocation/digital_elevation_model',
#  '/BEAM1011/geolocation/elev_lowestmode',
#  '/BEAM1011/geolocation/elev_highestreturn',
#  '/BEAM1011/rh100',
#  '/BEAM1011/num_detectedmodes',
#  '/BEAM1011/sensitivity',
#  '/BEAM1011/land_cover_data/leaf_off_flag',
#  '/BEAM1011/pgap_theta_z',
#  '/BEAM1011/pai',
#  '/BEAM1011/pai_z',
#  '/BEAM1011/fhd_normal',
#  '/BEAM1011/pavd_z',
#  '/BEAM1011/cover',
#  '/BEAM1011/cover_z',
#  '/BEAM1011/pgap_theta',
#  '/BEAM1011/pgap_theta_error',
#  '/BEAM1011/rhov',
#  '/BEAM1011/rhov_error',
#  '/BEAM1011/rhog',
#  '/BEAM1011/rhog_error']

# %% [markdown]
# # Create Request Task and download spatially and vairable subseted H5 Files

# %% [markdown]
# These code block creates request tasks via harmony and downloads them to the set directories.
# The AOI, time period, and subset variables are used to create the the request

# %%
# # Define temporal range
# temporal_range = {'start': datetime(2019, 4, 1),
#                   'stop': datetime(2024, 12, 30)}

# %%
# # Corresponding output directories
# output_dirs = [
#     # '/content/Module_2_GEDI_L2b/SPB_AOI',
#     # '/content/Module_2_GEDI_L2b/Prescribed_Burn_AOI',
#     # '/content/Module_2_GEDI_L2b/PaintRock_AOI',
#     # '/content/Module_2_GEDI_L2b/Sewanee_Domain'
#     '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target'
# ]

# %%
# # Loop through paired spatial ROIs and directories
# for (spatial, out_dir) in zip(bbox_dict.keys(), output_dirs):
#     print(f"\nSubmitting request for: {out_dir}")

#     request = Request(
#         collection=Collection(id=concept_id),
#         spatial=bbox_dict[spatial],  # Use the corresponding BBox from the dictionary
#         temporal=temporal_range,
#         variables=subset
#     )

#     print("Check if the request payload is valid:", request.is_valid())
#     print(request.__dict__)

#     task = harmony_client.submit(request)
#     print(f'Harmony request ID: {task}')

#     print('Processing your Harmony request:')
#     task_json = harmony_client.result_json(task, show_progress=True)

#     results = harmony_client.download_all(task, directory=out_dir, overwrite=True)
#     file_names = [f.result() for f in results]

#     print(f"Download completed for {out_dir}")

# %% [markdown]
# dev loop the harmoy api request

# %%
from datetime import datetime, timedelta
import os
from harmony import BBox, Request, Collection

# --- CONFIG ---
num_chunks = 10
beams = ['BEAM0101', 'BEAM0110', 'BEAM1000', 'BEAM1011']

# Define temporal range
start_date = datetime(2019, 4, 1)
end_date = datetime(2024, 12, 30)
total_days = (end_date - start_date).days
chunk_size = total_days // num_chunks

# Loop through each AOI and its output directory
for (spatial, out_dir) in zip(bbox_dict.keys(), output_dirs):
    print(f"\n🔹 Starting downloads for AOI: {spatial}")

    # Loop through each beam
    for beam in beams:
        print(f"\n➡️ Beam: {beam}")

        # Filter your subset list for the current beam
        subset_beam = [v for v in subset if f"/{beam}/" in v]

        # Make sure we have output folders for this beam
        beam_out_dir = os.path.join(out_dir, beam)
        os.makedirs(beam_out_dir, exist_ok=True)

        # Split time range into N chunks
        for i in range(num_chunks):
            chunk_start = start_date + timedelta(days=i * chunk_size)
            chunk_end = start_date + timedelta(days=(i + 1) * chunk_size)
            if chunk_end > end_date:
                chunk_end = end_date

            temporal_chunk = {'start': chunk_start, 'stop': chunk_end}

            # Create a subfolder per chunk for better organization
            chunk_folder_name = f"{beam}_chunk_{i+1:02d}_{chunk_start.date()}_{chunk_end.date()}"
            chunk_out_dir = os.path.join(beam_out_dir, chunk_folder_name)
            os.makedirs(chunk_out_dir, exist_ok=True)

            print(f"\n🕒 {beam} | Chunk {i+1}/{num_chunks}: {chunk_start.date()} → {chunk_end.date()}")

            try:
                request = Request(
                    collection=Collection(id=concept_id),
                    spatial=bbox_dict[spatial],
                    temporal=temporal_chunk,
                    variables=subset_beam
                )

                if not request.is_valid():
                    print(f"⚠️ Skipping invalid request for {beam} chunk {i+1}")
                    continue

                print(f"Submitting Harmony request for {beam} chunk {i+1}")
                task = harmony_client.submit(request)

                print("⏳ Waiting for Harmony task to complete...")
                task_json = harmony_client.result_json(task, show_progress=True)

                print(f"⬇️ Downloading results to: {chunk_out_dir}")
                results = harmony_client.download_all(task, directory=chunk_out_dir, overwrite=True)

                file_names = [f.result() for f in results]
                print(f"✅ Download completed for {beam} chunk {i+1}")

            except Exception as e:
                print(f"❌ Error with {beam} chunk {i+1}: {e}")
# Out:
# 🔹 Starting downloads for AOI: Sewanee_Domain_roi
#
# ➡️ Beam: BEAM0101
#
# 🕒 BEAM0101 | Chunk 1/10: 2019-04-01 → 2019-10-28
# Submitting Harmony request for BEAM0101 chunk 1
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_01_2019-04-01_2019-10-28
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_01_2019-04-01_2019-10-28/118361193_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_01_2019-04-01_2019-10-28/118361194_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_01_2019-04-01_2019-10-28/118361195_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM0101 chunk 1
#
# 🕒 BEAM0101 | Chunk 2/10: 2019-10-28 → 2020-05-25
# Submitting Harmony request for BEAM0101 chunk 2
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_02_2019-10-28_2020-05-25
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_02_2019-10-28_2020-05-25/118361419_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_02_2019-10-28_2020-05-25/118361420_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM0101 chunk 2
#
# 🕒 BEAM0101 | Chunk 3/10: 2020-05-25 → 2020-12-21
# Submitting Harmony request for BEAM0101 chunk 3
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_03_2020-05-25_2020-12-21
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_03_2020-05-25_2020-12-21/118361549_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_03_2020-05-25_2020-12-21/118361550_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM0101 chunk 3
#
# 🕒 BEAM0101 | Chunk 4/10: 2020-12-21 → 2021-07-19
# Submitting Harmony request for BEAM0101 chunk 4
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_04_2020-12-21_2021-07-19
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_04_2020-12-21_2021-07-19/118361792_GEDI02_B_2021131101046_O13658_03_T04580_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_04_2020-12-21_2021-07-19/118361793_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_04_2020-12-21_2021-07-19/118361794_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM0101 chunk 4
#
# 🕒 BEAM0101 | Chunk 5/10: 2021-07-19 → 2022-02-14
# Submitting Harmony request for BEAM0101 chunk 5
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362066_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362069_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362070_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362068_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362071_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM0101 chunk 5
#
# 🕒 BEAM0101 | Chunk 6/10: 2022-02-14 → 2022-09-12
# Submitting Harmony request for BEAM0101 chunk 6
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362198_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362201_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362197_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362199_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362200_GEDI02_B_2022139064237_O19438_03_T04580_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM0101 chunk 6
#
# 🕒 BEAM0101 | Chunk 7/10: 2022-09-12 → 2023-04-10
# Submitting Harmony request for BEAM0101 chunk 7
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_07_2022-09-12_2023-04-10
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_07_2022-09-12_2023-04-10/118362389_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_07_2022-09-12_2023-04-10/118362387_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_07_2022-09-12_2023-04-10/118362390_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_07_2022-09-12_2023-04-10/118362391_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM0101 chunk 7
#
# 🕒 BEAM0101 | Chunk 8/10: 2023-04-10 → 2023-11-06
# Submitting Harmony request for BEAM0101 chunk 8
# ❌ Error with BEAM0101 chunk 8: ('Bad Request', 'Error: No matching granules found.')
#
# 🕒 BEAM0101 | Chunk 9/10: 2023-11-06 → 2024-06-03
# Submitting Harmony request for BEAM0101 chunk 9
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_09_2023-11-06_2024-06-03
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_09_2023-11-06_2024-06-03/118362492_GEDI02_B_2024150175955_O30938_02_T05264_02_004_01_V002_subsetted.h5
# ✅ Download completed for BEAM0101 chunk 9
#
# 🕒 BEAM0101 | Chunk 10/10: 2024-06-03 → 2024-12-30
# Submitting Harmony request for BEAM0101 chunk 10
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_10_2024-06-03_2024-12-30
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_10_2024-06-03_2024-12-30/118362605_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_10_2024-06-03_2024-12-30/118362606_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_10_2024-06-03_2024-12-30/118362607_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5
# ✅ Download completed for BEAM0101 chunk 10
#
# ➡️ Beam: BEAM0110
#
# 🕒 BEAM0110 | Chunk 1/10: 2019-04-01 → 2019-10-28
# Submitting Harmony request for BEAM0110 chunk 1
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_01_2019-04-01_2019-10-28
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_01_2019-04-01_2019-10-28/118362695_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_01_2019-04-01_2019-10-28/118362693_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_01_2019-04-01_2019-10-28/118362694_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM0110 chunk 1
#
# 🕒 BEAM0110 | Chunk 2/10: 2019-10-28 → 2020-05-25
# Submitting Harmony request for BEAM0110 chunk 2
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_02_2019-10-28_2020-05-25
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_02_2019-10-28_2020-05-25/118362879_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_02_2019-10-28_2020-05-25/118362880_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM0110 chunk 2
#
# 🕒 BEAM0110 | Chunk 3/10: 2020-05-25 → 2020-12-21
# Submitting Harmony request for BEAM0110 chunk 3
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_03_2020-05-25_2020-12-21
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_03_2020-05-25_2020-12-21/118363109_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_03_2020-05-25_2020-12-21/118363110_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM0110 chunk 3
#
# 🕒 BEAM0110 | Chunk 4/10: 2020-12-21 → 2021-07-19
# Submitting Harmony request for BEAM0110 chunk 4
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_04_2020-12-21_2021-07-19
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_04_2020-12-21_2021-07-19/118363287_GEDI02_B_2021131101046_O13658_03_T04580_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_04_2020-12-21_2021-07-19/118363288_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_04_2020-12-21_2021-07-19/118363289_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM0110 chunk 4
#
# 🕒 BEAM0110 | Chunk 5/10: 2021-07-19 → 2022-02-14
# Submitting Harmony request for BEAM0110 chunk 5
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363532_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363534_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363535_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363536_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363537_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM0110 chunk 5
#
# 🕒 BEAM0110 | Chunk 6/10: 2022-02-14 → 2022-09-12
# Submitting Harmony request for BEAM0110 chunk 6
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363754_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363755_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363756_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363757_GEDI02_B_2022139064237_O19438_03_T04580_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363758_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5
# ✅ Download completed for BEAM0110 chunk 6
#
# 🕒 BEAM0110 | Chunk 7/10: 2022-09-12 → 2023-04-10
# Submitting Harmony request for BEAM0110 chunk 7
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_07_2022-09-12_2023-04-10
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_07_2022-09-12_2023-04-10/118364210_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_07_2022-09-12_2023-04-10/118364212_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_07_2022-09-12_2023-04-10/118364213_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_07_2022-09-12_2023-04-10/118364214_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM0110 chunk 7
#
# 🕒 BEAM0110 | Chunk 8/10: 2023-04-10 → 2023-11-06
# Submitting Harmony request for BEAM0110 chunk 8
# ❌ Error with BEAM0110 chunk 8: ('Bad Request', 'Error: No matching granules found.')
#
# 🕒 BEAM0110 | Chunk 9/10: 2023-11-06 → 2024-06-03
# Submitting Harmony request for BEAM0110 chunk 9
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_09_2023-11-06_2024-06-03
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_09_2023-11-06_2024-06-03/118364469_GEDI02_B_2024150175955_O30938_02_T05264_02_004_01_V002_subsetted.h5
# ✅ Download completed for BEAM0110 chunk 9
#
# 🕒 BEAM0110 | Chunk 10/10: 2024-06-03 → 2024-12-30
# Submitting Harmony request for BEAM0110 chunk 10
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_10_2024-06-03_2024-12-30
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_10_2024-06-03_2024-12-30/118364580_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_10_2024-06-03_2024-12-30/118364581_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_10_2024-06-03_2024-12-30/118364582_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5
# ✅ Download completed for BEAM0110 chunk 10
#
# ➡️ Beam: BEAM1000
#
# 🕒 BEAM1000 | Chunk 1/10: 2019-04-01 → 2019-10-28
# Submitting Harmony request for BEAM1000 chunk 1
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_01_2019-04-01_2019-10-28
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_01_2019-04-01_2019-10-28/118364834_GEDI02_B_2019122150008_O02186_03_T04733_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_01_2019-04-01_2019-10-28/118364835_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_01_2019-04-01_2019-10-28/118364836_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_01_2019-04-01_2019-10-28/118364837_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM1000 chunk 1
#
# 🕒 BEAM1000 | Chunk 2/10: 2019-10-28 → 2020-05-25
# Submitting Harmony request for BEAM1000 chunk 2
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_02_2019-10-28_2020-05-25
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_02_2019-10-28_2020-05-25/118365105_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_02_2019-10-28_2020-05-25/118365106_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM1000 chunk 2
#
# 🕒 BEAM1000 | Chunk 3/10: 2020-05-25 → 2020-12-21
# Submitting Harmony request for BEAM1000 chunk 3
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_03_2020-05-25_2020-12-21
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_03_2020-05-25_2020-12-21/118365255_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_03_2020-05-25_2020-12-21/118365256_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM1000 chunk 3
#
# 🕒 BEAM1000 | Chunk 4/10: 2020-12-21 → 2021-07-19
# Submitting Harmony request for BEAM1000 chunk 4
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_04_2020-12-21_2021-07-19
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_04_2020-12-21_2021-07-19/118365411_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_04_2020-12-21_2021-07-19/118365412_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM1000 chunk 4
#
# 🕒 BEAM1000 | Chunk 5/10: 2021-07-19 → 2022-02-14
# Submitting Harmony request for BEAM1000 chunk 5
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365635_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365637_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365639_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365638_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365640_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM1000 chunk 5
#
# 🕒 BEAM1000 | Chunk 6/10: 2022-02-14 → 2022-09-12
# Submitting Harmony request for BEAM1000 chunk 6
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_06_2022-02-14_2022-09-12
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_06_2022-02-14_2022-09-12/118366034_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_06_2022-02-14_2022-09-12/118366035_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_06_2022-02-14_2022-09-12/118366036_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_06_2022-02-14_2022-09-12/118366038_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5
# ✅ Download completed for BEAM1000 chunk 6
#
# 🕒 BEAM1000 | Chunk 7/10: 2022-09-12 → 2023-04-10
# Submitting Harmony request for BEAM1000 chunk 7
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_07_2022-09-12_2023-04-10
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_07_2022-09-12_2023-04-10/118366450_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_07_2022-09-12_2023-04-10/118366452_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_07_2022-09-12_2023-04-10/118366453_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_07_2022-09-12_2023-04-10/118366454_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM1000 chunk 7
#
# 🕒 BEAM1000 | Chunk 8/10: 2023-04-10 → 2023-11-06
# Submitting Harmony request for BEAM1000 chunk 8
# ❌ Error with BEAM1000 chunk 8: ('Bad Request', 'Error: No matching granules found.')
#
# 🕒 BEAM1000 | Chunk 9/10: 2023-11-06 → 2024-06-03
# Submitting Harmony request for BEAM1000 chunk 9
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_09_2023-11-06_2024-06-03
# There is no file to download.
#
# Job status is successful with message: WorkItem warned: sds/trajectory-subsetter:0.3.8: No data found to process.
# ✅ Download completed for BEAM1000 chunk 9
#
# 🕒 BEAM1000 | Chunk 10/10: 2024-06-03 → 2024-12-30
# Submitting Harmony request for BEAM1000 chunk 10
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_10_2024-06-03_2024-12-30
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_10_2024-06-03_2024-12-30/118366863_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_10_2024-06-03_2024-12-30/118366864_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_10_2024-06-03_2024-12-30/118366865_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5
# ✅ Download completed for BEAM1000 chunk 10
#
# ➡️ Beam: BEAM1011
#
# 🕒 BEAM1011 | Chunk 1/10: 2019-04-01 → 2019-10-28
# Submitting Harmony request for BEAM1011 chunk 1
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_01_2019-04-01_2019-10-28
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_01_2019-04-01_2019-10-28/118367097_GEDI02_B_2019122150008_O02186_03_T04733_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_01_2019-04-01_2019-10-28/118367098_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_01_2019-04-01_2019-10-28/118367099_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_01_2019-04-01_2019-10-28/118367100_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM1011 chunk 1
#
# 🕒 BEAM1011 | Chunk 2/10: 2019-10-28 → 2020-05-25
# Submitting Harmony request for BEAM1011 chunk 2
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_02_2019-10-28_2020-05-25
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_02_2019-10-28_2020-05-25/118367327_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM1011 chunk 2
#
# 🕒 BEAM1011 | Chunk 3/10: 2020-05-25 → 2020-12-21
# Submitting Harmony request for BEAM1011 chunk 3
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_03_2020-05-25_2020-12-21
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_03_2020-05-25_2020-12-21/118367423_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_03_2020-05-25_2020-12-21/118367424_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM1011 chunk 3
#
# 🕒 BEAM1011 | Chunk 4/10: 2020-12-21 → 2021-07-19
# Submitting Harmony request for BEAM1011 chunk 4
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_04_2020-12-21_2021-07-19
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_04_2020-12-21_2021-07-19/118367527_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_04_2020-12-21_2021-07-19/118367528_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM1011 chunk 4
#
# 🕒 BEAM1011 | Chunk 5/10: 2021-07-19 → 2022-02-14
# Submitting Harmony request for BEAM1011 chunk 5
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367749_GEDI02_B_2021238154634_O15320_03_T07579_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367750_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367751_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367752_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367753_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM1011 chunk 5
#
# 🕒 BEAM1011 | Chunk 6/10: 2022-02-14 → 2022-09-12
# Submitting Harmony request for BEAM1011 chunk 6
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_06_2022-02-14_2022-09-12
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_06_2022-02-14_2022-09-12/118368100_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_06_2022-02-14_2022-09-12/118368101_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_06_2022-02-14_2022-09-12/118368102_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_06_2022-02-14_2022-09-12/118368104_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5
# ✅ Download completed for BEAM1011 chunk 6
#
# 🕒 BEAM1011 | Chunk 7/10: 2022-09-12 → 2023-04-10
# Submitting Harmony request for BEAM1011 chunk 7
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_07_2022-09-12_2023-04-10
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_07_2022-09-12_2023-04-10/118368784_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_07_2022-09-12_2023-04-10/118368786_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_07_2022-09-12_2023-04-10/118368787_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_07_2022-09-12_2023-04-10/118368788_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5
# ✅ Download completed for BEAM1011 chunk 7
#
# 🕒 BEAM1011 | Chunk 8/10: 2023-04-10 → 2023-11-06
# Submitting Harmony request for BEAM1011 chunk 8
# ❌ Error with BEAM1011 chunk 8: ('Bad Request', 'Error: No matching granules found.')
#
# 🕒 BEAM1011 | Chunk 9/10: 2023-11-06 → 2024-06-03
# Submitting Harmony request for BEAM1011 chunk 9
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_09_2023-11-06_2024-06-03
# There is no file to download.
#
# Job status is successful with message: WorkItem warned: sds/trajectory-subsetter:0.3.8: No data found to process.
# ✅ Download completed for BEAM1011 chunk 9
#
# 🕒 BEAM1011 | Chunk 10/10: 2024-06-03 → 2024-12-30
# Submitting Harmony request for BEAM1011 chunk 10
# ⏳ Waiting for Harmony task to complete...
#  [ Processing: 100% ] |###################################################| [|]
# ⬇️ Downloading results to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_10_2024-06-03_2024-12-30
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_10_2024-06-03_2024-12-30/118369233_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_10_2024-06-03_2024-12-30/118369234_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5
# /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_10_2024-06-03_2024-12-30/118369235_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5
# ✅ Download completed for BEAM1011 chunk 10

# %%
## confirm files are in the right spots
# !find /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target
# Out:
# find: ‘/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target’: No such file or directory

# %% [markdown]
# filter list: https://docs.google.com/document/d/1nm0qn_E6_dGM2g5_mu4utRip6VzC0QUF3Z_lmtxP4Ow/edit?tab=t.0

# %%
import h5py
import os
import glob
import pandas as pd
import numpy as np
from geopy.distance import geodesic

# =========================================
# CONFIG
# =========================================
data_dir = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target'
output_dir = os.path.join(data_dir, 'filtered_csvs')
os.makedirs(output_dir, exist_ok=True)

beam_groups = ['BEAM0101', 'BEAM0110', 'BEAM1000', 'BEAM1011']

variables = [
    'geolocation/lat_lowestmode', 'geolocation/lon_lowestmode', 'geolocation/solar_elevation',
    'geolocation/local_beam_elevation', 'selected_l2a_algorithm', 'geolocation/degrade_flag',
    'l2a_quality_flag', 'l2b_quality_flag', 'geolocation/digital_elevation_model',
    'geolocation/elev_lowestmode', 'geolocation/elev_highestreturn', 'rh100', 'num_detectedmodes',
    'sensitivity', 'land_cover_data/leaf_off_flag', 'pgap_theta_z', 'pai', 'pai_z', 'fhd_normal',
    'pavd_z', 'cover', 'cover_z', 'pgap_theta', 'pgap_theta_error', 'rhov', 'rhov_error',
    'rhog', 'rhog_error'
]

resample_distance = 25

# =========================================
# FUNCTIONS
# =========================================
def resample_25m(df):
    if df.empty:
        return df
    selected_rows = [df.iloc[0]]
    last_coord = (df.iloc[0]['lat'], df.iloc[0]['lon'])

    for _, row in df.iterrows():
        current_coord = (row['lat'], row['lon'])
        dist = geodesic(last_coord, current_coord).meters
        if dist >= resample_distance:
            selected_rows.append(row)
            last_coord = current_coord

    return pd.DataFrame(selected_rows)


def apply_complex_filters_with_logs(df, beam):
    logs = {}
    total = len(df)
    logs['initial'] = total

    df.replace(-9999, np.nan, inplace=True)

    # Core quality filters
    df_qc = df[
        (df.get('l2a_quality_flag', 1) == 1) &
        (df.get('l2b_quality_flag', 1) == 1) &
        (df.get('degrade_flag', 0) == 0)
    ]
    logs['after_qc'] = len(df_qc)

    # Solar elevation
    if 'solar_elevation' in df_qc.columns:
        df_solar = df_qc[df_qc['solar_elevation'] < 0]
    else:
        df_solar = df_qc
    logs['after_solar'] = len(df_solar)

    # Phenology / leaf-on
    if 'leaf_off_flag' in df_solar.columns:
        df_leaf = df_solar[df_solar['leaf_off_flag'] == 0]
    else:
        df_leaf = df_solar
    logs['after_leaf_on'] = len(df_leaf)

    # Signal penetration
    if 'sensitivity' in df_leaf.columns:
        df_sens = df_leaf[df_leaf['sensitivity'] >= 0.95]
    else:
        df_sens = df_leaf
    logs['after_sensitivity'] = len(df_sens)

    # Topography filter
    if all(col in df_sens.columns for col in ['digital_elevation_model', 'elev_lowestmode']):
        df_sens['dem_diff'] = df_sens['elev_lowestmode'] - df_sens['digital_elevation_model']
        df_topo = df_sens[df_sens['dem_diff'].between(-20, 20)]
    else:
        df_topo = df_sens
    logs['after_topography'] = len(df_topo)

    # Elevation sanity
    if all(col in df_topo.columns for col in ['elev_highestreturn', 'elev_lowestmode']):
        df_elev = df_topo[(df_topo['elev_highestreturn'] - df_topo['elev_lowestmode']).between(0, 100)]
    else:
        df_elev = df_topo
    logs['after_elevation'] = len(df_elev)

    # Final cleaning
    if 'num_detectedmodes' in df_elev.columns:
        df_final = df_elev[df_elev['num_detectedmodes'] > 0]
    else:
        df_final = df_elev
    logs['after_num_detectedmodes'] = len(df_final)

    return df_final, logs


# =========================================
# MAIN LOOP
# =========================================
h5_files = [os.path.join(root, file)
            for root, _, files in os.walk(data_dir)
            for file in files if file.endswith('.h5')]

print(f"Found {len(h5_files)} GEDI files to process.\n")

for h5_file in h5_files:
    print(f"Processing {h5_file}")
    with h5py.File(h5_file, 'r') as f:
        for beam in beam_groups:
            if beam not in f:
                continue

            beam_data = {}
            for var in variables:
                try:
                    data = f[beam][var][:]
                    if data.ndim > 1:
                        data = data.mean(axis=1)
                    beam_data[var.split('/')[-1]] = data
                except KeyError:
                    continue

            if 'lat_lowestmode' not in beam_data or 'lon_lowestmode' not in beam_data:
                print(f"⚠️ Skipping {beam} — missing coordinates.")
                continue

            main_len = len(beam_data['lat_lowestmode'])
            beam_data_filtered = {k: v for k, v in beam_data.items() if len(v) == main_len}

            df = pd.DataFrame(beam_data_filtered)
            df.rename(columns={'lat_lowestmode': 'lat', 'lon_lowestmode': 'lon'}, inplace=True)

            df_filtered, filter_logs = apply_complex_filters_with_logs(df, beam)

            # Log shot counts per filter
            print(f"Beam {beam} filter counts: {filter_logs}")

            df_resampled = resample_25m(df_filtered)

            if not df_resampled.empty:
                base_name = os.path.splitext(os.path.basename(h5_file))[0]
                out_path = os.path.join(output_dir, f"{base_name}_{beam}_filtered.csv")
                df_resampled.to_csv(out_path, index=False)
                print(f"✅ Saved: {out_path} ({len(df_resampled)} shots)\n")
            else:
                print(f"⚠️ No valid data left for {beam} in {os.path.basename(h5_file)}.\n")
# Out:
# Found 107 GEDI files to process.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_01_2019-04-01_2019-10-28/118361193_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 247, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361193_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_01_2019-04-01_2019-10-28/118361194_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 276, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361194_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_01_2019-04-01_2019-10-28/118361195_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 279, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361195_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_02_2019-10-28_2020-05-25/118361419_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 53, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361419_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_02_2019-10-28_2020-05-25/118361420_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 137, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361420_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_03_2020-05-25_2020-12-21/118361549_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 177, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361549_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_03_2020-05-25_2020-12-21/118361550_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 63, 'after_qc': 63, 'after_solar': 63, 'after_leaf_on': 63, 'after_sensitivity': 63, 'after_topography': 45, 'after_elevation': 45, 'after_num_detectedmodes': 45}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118361550_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted_BEAM0101_filtered.csv (45 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_04_2020-12-21_2021-07-19/118361792_GEDI02_B_2021131101046_O13658_03_T04580_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 53, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361792_GEDI02_B_2021131101046_O13658_03_T04580_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_04_2020-12-21_2021-07-19/118361793_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 204, 'after_qc': 196, 'after_solar': 196, 'after_leaf_on': 127, 'after_sensitivity': 127, 'after_topography': 91, 'after_elevation': 91, 'after_num_detectedmodes': 91}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118361793_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted_BEAM0101_filtered.csv (91 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_04_2020-12-21_2021-07-19/118361794_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 255, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361794_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362066_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 66, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362066_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362069_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 66, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362069_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362070_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 111, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362070_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362068_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 191, 'after_qc': 167, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362068_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362071_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 130, 'after_qc': 130, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362071_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362198_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 194, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362198_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362201_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 63, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362201_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362197_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 67, 'after_qc': 61, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362197_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362199_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 125, 'after_qc': 123, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362199_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362200_GEDI02_B_2022139064237_O19438_03_T04580_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 48, 'after_qc': 48, 'after_solar': 48, 'after_leaf_on': 48, 'after_sensitivity': 48, 'after_topography': 43, 'after_elevation': 43, 'after_num_detectedmodes': 43}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118362200_GEDI02_B_2022139064237_O19438_03_T04580_02_003_01_V002_subsetted_BEAM0101_filtered.csv (43 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_07_2022-09-12_2023-04-10/118362389_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 117, 'after_qc': 117, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362389_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_07_2022-09-12_2023-04-10/118362387_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 196, 'after_qc': 13, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362387_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_07_2022-09-12_2023-04-10/118362390_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 264, 'after_qc': 249, 'after_solar': 249, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362390_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_07_2022-09-12_2023-04-10/118362391_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 131, 'after_qc': 131, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362391_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_09_2023-11-06_2024-06-03/118362492_GEDI02_B_2024150175955_O30938_02_T05264_02_004_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 260, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362492_GEDI02_B_2024150175955_O30938_02_T05264_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_10_2024-06-03_2024-12-30/118362605_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 63, 'after_qc': 54, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362605_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_10_2024-06-03_2024-12-30/118362606_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 76, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362606_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_10_2024-06-03_2024-12-30/118362607_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 190, 'after_qc': 178, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362607_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_01_2019-04-01_2019-10-28/118362695_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 257, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118362695_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_01_2019-04-01_2019-10-28/118362693_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 225, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118362693_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_01_2019-04-01_2019-10-28/118362694_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 287, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118362694_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_02_2019-10-28_2020-05-25/118362879_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 30, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118362879_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_02_2019-10-28_2020-05-25/118362880_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 159, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118362880_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_03_2020-05-25_2020-12-21/118363109_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 165, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363109_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_03_2020-05-25_2020-12-21/118363110_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 84, 'after_qc': 84, 'after_solar': 84, 'after_leaf_on': 84, 'after_sensitivity': 84, 'after_topography': 73, 'after_elevation': 73, 'after_num_detectedmodes': 73}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118363110_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted_BEAM0110_filtered.csv (73 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_04_2020-12-21_2021-07-19/118363287_GEDI02_B_2021131101046_O13658_03_T04580_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 30, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363287_GEDI02_B_2021131101046_O13658_03_T04580_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_04_2020-12-21_2021-07-19/118363288_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 224, 'after_qc': 216, 'after_solar': 216, 'after_leaf_on': 187, 'after_sensitivity': 187, 'after_topography': 154, 'after_elevation': 154, 'after_num_detectedmodes': 154}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118363288_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted_BEAM0110_filtered.csv (154 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_04_2020-12-21_2021-07-19/118363289_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 229, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363289_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363532_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 44, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363532_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363534_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 167, 'after_qc': 165, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363534_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363535_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 90, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363535_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363536_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 92, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363536_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363537_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 151, 'after_qc': 151, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363537_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363754_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 89, 'after_qc': 85, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363754_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363755_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 218, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363755_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363756_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 102, 'after_qc': 102, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363756_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363757_GEDI02_B_2022139064237_O19438_03_T04580_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 29, 'after_qc': 29, 'after_solar': 29, 'after_leaf_on': 29, 'after_sensitivity': 29, 'after_topography': 23, 'after_elevation': 23, 'after_num_detectedmodes': 23}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118363757_GEDI02_B_2022139064237_O19438_03_T04580_02_003_01_V002_subsetted_BEAM0110_filtered.csv (23 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363758_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 72, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363758_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_07_2022-09-12_2023-04-10/118364210_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 173, 'after_qc': 12, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364210_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_07_2022-09-12_2023-04-10/118364212_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 98, 'after_qc': 98, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364212_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_07_2022-09-12_2023-04-10/118364213_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 284, 'after_qc': 277, 'after_solar': 277, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364213_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_07_2022-09-12_2023-04-10/118364214_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 151, 'after_qc': 151, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364214_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_09_2023-11-06_2024-06-03/118364469_GEDI02_B_2024150175955_O30938_02_T05264_02_004_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 280, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364469_GEDI02_B_2024150175955_O30938_02_T05264_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_10_2024-06-03_2024-12-30/118364580_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 83, 'after_qc': 67, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364580_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_10_2024-06-03_2024-12-30/118364581_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 97, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364581_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_10_2024-06-03_2024-12-30/118364582_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 209, 'after_qc': 194, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364582_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_01_2019-04-01_2019-10-28/118364834_GEDI02_B_2019122150008_O02186_03_T04733_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 27, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118364834_GEDI02_B_2019122150008_O02186_03_T04733_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_01_2019-04-01_2019-10-28/118364835_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 201, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118364835_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_01_2019-04-01_2019-10-28/118364836_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 268, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118364836_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_01_2019-04-01_2019-10-28/118364837_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 231, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118364837_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_02_2019-10-28_2020-05-25/118365105_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 7, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365105_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_02_2019-10-28_2020-05-25/118365106_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 186, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365106_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_03_2020-05-25_2020-12-21/118365255_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 129, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365255_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_03_2020-05-25_2020-12-21/118365256_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 110, 'after_qc': 110, 'after_solar': 110, 'after_leaf_on': 110, 'after_sensitivity': 110, 'after_topography': 79, 'after_elevation': 79, 'after_num_detectedmodes': 79}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118365256_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted_BEAM1000_filtered.csv (79 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_04_2020-12-21_2021-07-19/118365411_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 256, 'after_qc': 254, 'after_solar': 254, 'after_leaf_on': 178, 'after_sensitivity': 178, 'after_topography': 127, 'after_elevation': 127, 'after_num_detectedmodes': 127}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118365411_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted_BEAM1000_filtered.csv (127 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_04_2020-12-21_2021-07-19/118365412_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 192, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365412_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365635_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 22, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365635_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365637_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 148, 'after_qc': 141, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365637_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365639_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 60, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365639_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365638_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 120, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365638_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365640_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 175, 'after_qc': 172, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365640_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_06_2022-02-14_2022-09-12/118366034_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 119, 'after_qc': 111, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366034_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_06_2022-02-14_2022-09-12/118366035_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 243, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366035_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_06_2022-02-14_2022-09-12/118366036_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 79, 'after_qc': 79, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366036_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_06_2022-02-14_2022-09-12/118366038_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 114, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366038_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_07_2022-09-12_2023-04-10/118366450_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 149, 'after_qc': 22, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366450_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_07_2022-09-12_2023-04-10/118366452_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 68, 'after_qc': 67, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366452_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_07_2022-09-12_2023-04-10/118366453_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 284, 'after_qc': 269, 'after_solar': 269, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366453_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_07_2022-09-12_2023-04-10/118366454_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 178, 'after_qc': 175, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366454_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_10_2024-06-03_2024-12-30/118366863_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 109, 'after_qc': 91, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366863_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_10_2024-06-03_2024-12-30/118366864_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 127, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366864_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_10_2024-06-03_2024-12-30/118366865_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 236, 'after_qc': 232, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366865_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_01_2019-04-01_2019-10-28/118367097_GEDI02_B_2019122150008_O02186_03_T04733_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 47, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367097_GEDI02_B_2019122150008_O02186_03_T04733_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_01_2019-04-01_2019-10-28/118367098_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 180, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367098_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_01_2019-04-01_2019-10-28/118367099_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 248, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367099_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_01_2019-04-01_2019-10-28/118367100_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 210, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367100_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_02_2019-10-28_2020-05-25/118367327_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 209, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367327_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_03_2020-05-25_2020-12-21/118367423_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 109, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367423_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_03_2020-05-25_2020-12-21/118367424_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 134, 'after_qc': 134, 'after_solar': 134, 'after_leaf_on': 123, 'after_sensitivity': 123, 'after_topography': 102, 'after_elevation': 102, 'after_num_detectedmodes': 102}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118367424_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted_BEAM1011_filtered.csv (102 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_04_2020-12-21_2021-07-19/118367527_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 280, 'after_qc': 274, 'after_solar': 274, 'after_leaf_on': 206, 'after_sensitivity': 206, 'after_topography': 135, 'after_elevation': 135, 'after_num_detectedmodes': 135}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118367527_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted_BEAM1011_filtered.csv (135 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_04_2020-12-21_2021-07-19/118367528_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 176, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367528_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367749_GEDI02_B_2021238154634_O15320_03_T07579_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 4, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367749_GEDI02_B_2021238154634_O15320_03_T07579_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367750_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 124, 'after_qc': 120, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367750_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367751_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 140, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367751_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367752_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 42, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367752_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367753_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 195, 'after_qc': 194, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367753_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_06_2022-02-14_2022-09-12/118368100_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 137, 'after_qc': 131, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368100_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_06_2022-02-14_2022-09-12/118368101_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 262, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368101_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_06_2022-02-14_2022-09-12/118368102_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 58, 'after_qc': 54, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368102_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_06_2022-02-14_2022-09-12/118368104_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 124, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368104_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_07_2022-09-12_2023-04-10/118368784_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 129, 'after_qc': 41, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368784_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_07_2022-09-12_2023-04-10/118368786_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 48, 'after_qc': 48, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368786_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_07_2022-09-12_2023-04-10/118368787_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 265, 'after_qc': 264, 'after_solar': 264, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368787_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_07_2022-09-12_2023-04-10/118368788_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 199, 'after_qc': 195, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368788_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_10_2024-06-03_2024-12-30/118369233_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 128, 'after_qc': 117, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118369233_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_10_2024-06-03_2024-12-30/118369234_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 145, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118369234_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_10_2024-06-03_2024-12-30/118369235_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 262, 'after_qc': 259, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118369235_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5.

# %% [markdown]
# dev

# %%
import h5py
import os
import glob
import pandas as pd
import numpy as np
from geopy.distance import geodesic

# =========================================
# CONFIG
# =========================================
data_dir = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target'
output_dir = os.path.join(data_dir, 'filtered_csvs')
os.makedirs(output_dir, exist_ok=True)

beam_groups = ['BEAM0101', 'BEAM0110', 'BEAM1000', 'BEAM1011']

variables = [
    'geolocation/lat_lowestmode', 'geolocation/lon_lowestmode', 'geolocation/solar_elevation',
    'geolocation/local_beam_elevation', 'selected_l2a_algorithm', 'geolocation/degrade_flag',
    'l2a_quality_flag', 'l2b_quality_flag', 'geolocation/digital_elevation_model',
    'geolocation/elev_lowestmode', 'geolocation/elev_highestreturn', 'rh100', 'num_detectedmodes',
    'sensitivity', 'land_cover_data/leaf_off_flag', 'pgap_theta_z', 'pai', 'pai_z', 'fhd_normal',
    'pavd_z', 'cover', 'cover_z', 'pgap_theta', 'pgap_theta_error', 'rhov', 'rhov_error',
    'rhog', 'rhog_error'
]

resample_distance = 25

# =========================================
# FUNCTIONS
# =========================================
def resample_25m(df):
    """Downsample points to ~25 m spacing along track."""
    if df.empty:
        return df
    selected_rows = [df.iloc[0]]
    last_coord = (df.iloc[0]['lat'], df.iloc[0]['lon'])

    for _, row in df.iterrows():
        current_coord = (row['lat'], row['lon'])
        dist = geodesic(last_coord, current_coord).meters
        if dist >= resample_distance:
            selected_rows.append(row)
            last_coord = current_coord

    return pd.DataFrame(selected_rows)


def apply_complex_filters_with_logs(df, beam):
    """Apply multi-step filters and record counts after each step."""
    logs = {}
    total = len(df)
    logs['initial'] = total

    df.replace(-9999, np.nan, inplace=True)

    # Core quality filters
    df_qc = df[
        (df.get('l2a_quality_flag', 1) == 1) &
        (df.get('l2b_quality_flag', 1) == 1) &
        (df.get('degrade_flag', 0) == 0)
    ]
    logs['after_qc'] = len(df_qc)

    # Solar elevation
    df_solar = df_qc[df_qc['solar_elevation'] < 0] if 'solar_elevation' in df_qc.columns else df_qc
    logs['after_solar'] = len(df_solar)

    # Phenology / leaf-on
    df_leaf = df_solar[df_solar['leaf_off_flag'] == 0] if 'leaf_off_flag' in df_solar.columns else df_solar
    logs['after_leaf_on'] = len(df_leaf)

    # Signal penetration
    df_sens = df_leaf[df_leaf['sensitivity'] >= 0.95] if 'sensitivity' in df_leaf.columns else df_leaf
    logs['after_sensitivity'] = len(df_sens)

    # Topography filter
    if all(col in df_sens.columns for col in ['digital_elevation_model', 'elev_lowestmode']):
        df_sens['dem_diff'] = df_sens['elev_lowestmode'] - df_sens['digital_elevation_model']
        df_topo = df_sens[df_sens['dem_diff'].between(-20, 20)]
    else:
        df_topo = df_sens
    logs['after_topography'] = len(df_topo)

    # Elevation sanity
    if all(col in df_topo.columns for col in ['elev_highestreturn', 'elev_lowestmode']):
        df_elev = df_topo[(df_topo['elev_highestreturn'] - df_topo['elev_lowestmode']).between(0, 100)]
    else:
        df_elev = df_topo
    logs['after_elevation'] = len(df_elev)

    # Final cleaning
    df_final = df_elev[df_elev['num_detectedmodes'] > 0] if 'num_detectedmodes' in df_elev.columns else df_elev
    logs['after_num_detectedmodes'] = len(df_final)

    return df_final, logs


# =========================================
# MAIN LOOP
# =========================================
h5_files = [os.path.join(root, file)
            for root, _, files in os.walk(data_dir)
            for file in files if file.endswith('.h5')]

print(f"Found {len(h5_files)} GEDI files to process.\n")

for h5_file in h5_files:
    print(f"Processing {h5_file}")
    with h5py.File(h5_file, 'r') as f:
        for beam in beam_groups:
            if beam not in f:
                continue

            beam_data = {}
            for var in variables:
                try:
                    data = f[beam][var][:]

                    # Keep full vertical profile for *_z variables
                    if data.ndim > 1 and var.split('/')[-1].endswith('_z'):
                        var_name = var.split('/')[-1]
                        for i in range(data.shape[1]):
                            beam_data[f"{var_name}_bin_{i}"] = data[:, i]
                        continue  # skip flattening
                    elif data.ndim > 1:
                        # For other multi-dim arrays, take mean per shot
                        data = data.mean(axis=1)

                    beam_data[var.split('/')[-1]] = data

                except KeyError:
                    continue

            # Skip if missing core coords
            if 'lat_lowestmode' not in beam_data or 'lon_lowestmode' not in beam_data:
                print(f"⚠️ Skipping {beam} — missing coordinates.")
                continue

            main_len = len(beam_data['lat_lowestmode'])
            beam_data_filtered = {k: v for k, v in beam_data.items() if len(v) == main_len}

            df = pd.DataFrame(beam_data_filtered)
            df.rename(columns={'lat_lowestmode': 'lat', 'lon_lowestmode': 'lon'}, inplace=True)

            # Apply filters
            df_filtered, filter_logs = apply_complex_filters_with_logs(df, beam)

            # Log shot counts per filter
            print(f"Beam {beam} filter counts: {filter_logs}")

            # Resample ~25m
            df_resampled = resample_25m(df_filtered)

            # Save
            if not df_resampled.empty:
                base_name = os.path.splitext(os.path.basename(h5_file))[0]
                out_path = os.path.join(output_dir, f"{base_name}_{beam}_filtered.csv")
                df_resampled.to_csv(out_path, index=False)
                print(f"✅ Saved: {out_path} ({len(df_resampled)} shots)\n")
            else:
                print(f"⚠️ No valid data left for {beam} in {os.path.basename(h5_file)}.\n")
# Out:
# Found 107 GEDI files to process.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_01_2019-04-01_2019-10-28/118361193_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 247, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361193_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_01_2019-04-01_2019-10-28/118361194_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 276, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361194_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_01_2019-04-01_2019-10-28/118361195_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 279, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361195_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_02_2019-10-28_2020-05-25/118361419_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 53, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361419_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_02_2019-10-28_2020-05-25/118361420_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 137, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361420_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_03_2020-05-25_2020-12-21/118361549_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 177, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361549_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_03_2020-05-25_2020-12-21/118361550_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 63, 'after_qc': 63, 'after_solar': 63, 'after_leaf_on': 63, 'after_sensitivity': 63, 'after_topography': 45, 'after_elevation': 45, 'after_num_detectedmodes': 45}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118361550_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted_BEAM0101_filtered.csv (45 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_04_2020-12-21_2021-07-19/118361792_GEDI02_B_2021131101046_O13658_03_T04580_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 53, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361792_GEDI02_B_2021131101046_O13658_03_T04580_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_04_2020-12-21_2021-07-19/118361793_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 204, 'after_qc': 196, 'after_solar': 196, 'after_leaf_on': 127, 'after_sensitivity': 127, 'after_topography': 91, 'after_elevation': 91, 'after_num_detectedmodes': 91}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118361793_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted_BEAM0101_filtered.csv (91 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_04_2020-12-21_2021-07-19/118361794_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 255, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118361794_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362066_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 66, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362066_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362069_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 66, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362069_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362070_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 111, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362070_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362068_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 191, 'after_qc': 167, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362068_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_05_2021-07-19_2022-02-14/118362071_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 130, 'after_qc': 130, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362071_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362198_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 194, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362198_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362201_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 63, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362201_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362197_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 67, 'after_qc': 61, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362197_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362199_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 125, 'after_qc': 123, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362199_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_06_2022-02-14_2022-09-12/118362200_GEDI02_B_2022139064237_O19438_03_T04580_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 48, 'after_qc': 48, 'after_solar': 48, 'after_leaf_on': 48, 'after_sensitivity': 48, 'after_topography': 43, 'after_elevation': 43, 'after_num_detectedmodes': 43}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118362200_GEDI02_B_2022139064237_O19438_03_T04580_02_003_01_V002_subsetted_BEAM0101_filtered.csv (43 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_07_2022-09-12_2023-04-10/118362389_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 117, 'after_qc': 117, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362389_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_07_2022-09-12_2023-04-10/118362387_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 196, 'after_qc': 13, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362387_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_07_2022-09-12_2023-04-10/118362390_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 264, 'after_qc': 249, 'after_solar': 249, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362390_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_07_2022-09-12_2023-04-10/118362391_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 131, 'after_qc': 131, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362391_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_09_2023-11-06_2024-06-03/118362492_GEDI02_B_2024150175955_O30938_02_T05264_02_004_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 260, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362492_GEDI02_B_2024150175955_O30938_02_T05264_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_10_2024-06-03_2024-12-30/118362605_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 63, 'after_qc': 54, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362605_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_10_2024-06-03_2024-12-30/118362606_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 76, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362606_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0101/BEAM0101_chunk_10_2024-06-03_2024-12-30/118362607_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5
# Beam BEAM0101 filter counts: {'initial': 190, 'after_qc': 178, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0101 in 118362607_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_01_2019-04-01_2019-10-28/118362695_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 257, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118362695_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_01_2019-04-01_2019-10-28/118362693_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 225, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118362693_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_01_2019-04-01_2019-10-28/118362694_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 287, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118362694_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_02_2019-10-28_2020-05-25/118362879_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 30, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118362879_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_02_2019-10-28_2020-05-25/118362880_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 159, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118362880_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_03_2020-05-25_2020-12-21/118363109_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 165, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363109_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_03_2020-05-25_2020-12-21/118363110_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 84, 'after_qc': 84, 'after_solar': 84, 'after_leaf_on': 84, 'after_sensitivity': 84, 'after_topography': 73, 'after_elevation': 73, 'after_num_detectedmodes': 73}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118363110_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted_BEAM0110_filtered.csv (73 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_04_2020-12-21_2021-07-19/118363287_GEDI02_B_2021131101046_O13658_03_T04580_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 30, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363287_GEDI02_B_2021131101046_O13658_03_T04580_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_04_2020-12-21_2021-07-19/118363288_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 224, 'after_qc': 216, 'after_solar': 216, 'after_leaf_on': 187, 'after_sensitivity': 187, 'after_topography': 154, 'after_elevation': 154, 'after_num_detectedmodes': 154}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118363288_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted_BEAM0110_filtered.csv (154 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_04_2020-12-21_2021-07-19/118363289_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 229, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363289_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363532_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 44, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363532_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363534_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 167, 'after_qc': 165, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363534_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363535_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 90, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363535_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363536_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 92, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363536_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_05_2021-07-19_2022-02-14/118363537_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 151, 'after_qc': 151, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363537_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363754_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 89, 'after_qc': 85, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363754_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363755_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 218, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363755_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363756_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 102, 'after_qc': 102, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363756_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363757_GEDI02_B_2022139064237_O19438_03_T04580_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 29, 'after_qc': 29, 'after_solar': 29, 'after_leaf_on': 29, 'after_sensitivity': 29, 'after_topography': 23, 'after_elevation': 23, 'after_num_detectedmodes': 23}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118363757_GEDI02_B_2022139064237_O19438_03_T04580_02_003_01_V002_subsetted_BEAM0110_filtered.csv (23 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_06_2022-02-14_2022-09-12/118363758_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 72, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118363758_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_07_2022-09-12_2023-04-10/118364210_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 173, 'after_qc': 12, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364210_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_07_2022-09-12_2023-04-10/118364212_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 98, 'after_qc': 98, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364212_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_07_2022-09-12_2023-04-10/118364213_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 284, 'after_qc': 277, 'after_solar': 277, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364213_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_07_2022-09-12_2023-04-10/118364214_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 151, 'after_qc': 151, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364214_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_09_2023-11-06_2024-06-03/118364469_GEDI02_B_2024150175955_O30938_02_T05264_02_004_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 280, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364469_GEDI02_B_2024150175955_O30938_02_T05264_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_10_2024-06-03_2024-12-30/118364580_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 83, 'after_qc': 67, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364580_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_10_2024-06-03_2024-12-30/118364581_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 97, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364581_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM0110/BEAM0110_chunk_10_2024-06-03_2024-12-30/118364582_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5
# Beam BEAM0110 filter counts: {'initial': 209, 'after_qc': 194, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM0110 in 118364582_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_01_2019-04-01_2019-10-28/118364834_GEDI02_B_2019122150008_O02186_03_T04733_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 27, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118364834_GEDI02_B_2019122150008_O02186_03_T04733_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_01_2019-04-01_2019-10-28/118364835_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 201, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118364835_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_01_2019-04-01_2019-10-28/118364836_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 268, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118364836_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_01_2019-04-01_2019-10-28/118364837_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 231, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118364837_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_02_2019-10-28_2020-05-25/118365105_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 7, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365105_GEDI02_B_2019312044317_O05128_02_T02571_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_02_2019-10-28_2020-05-25/118365106_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 186, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365106_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_03_2020-05-25_2020-12-21/118365255_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 129, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365255_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_03_2020-05-25_2020-12-21/118365256_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 110, 'after_qc': 110, 'after_solar': 110, 'after_leaf_on': 110, 'after_sensitivity': 110, 'after_topography': 79, 'after_elevation': 79, 'after_num_detectedmodes': 79}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118365256_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted_BEAM1000_filtered.csv (79 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_04_2020-12-21_2021-07-19/118365411_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 256, 'after_qc': 254, 'after_solar': 254, 'after_leaf_on': 178, 'after_sensitivity': 178, 'after_topography': 127, 'after_elevation': 127, 'after_num_detectedmodes': 127}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118365411_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted_BEAM1000_filtered.csv (127 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_04_2020-12-21_2021-07-19/118365412_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 192, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365412_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365635_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 22, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365635_GEDI02_B_2021232110553_O15224_02_T11109_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365637_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 148, 'after_qc': 141, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365637_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365639_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 60, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365639_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365638_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 120, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365638_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_05_2021-07-19_2022-02-14/118365640_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 175, 'after_qc': 172, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118365640_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_06_2022-02-14_2022-09-12/118366034_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 119, 'after_qc': 111, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366034_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_06_2022-02-14_2022-09-12/118366035_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 243, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366035_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_06_2022-02-14_2022-09-12/118366036_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 79, 'after_qc': 79, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366036_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_06_2022-02-14_2022-09-12/118366038_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 114, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366038_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_07_2022-09-12_2023-04-10/118366450_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 149, 'after_qc': 22, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366450_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_07_2022-09-12_2023-04-10/118366452_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 68, 'after_qc': 67, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366452_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_07_2022-09-12_2023-04-10/118366453_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 284, 'after_qc': 269, 'after_solar': 269, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366453_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_07_2022-09-12_2023-04-10/118366454_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 178, 'after_qc': 175, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366454_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_10_2024-06-03_2024-12-30/118366863_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 109, 'after_qc': 91, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366863_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_10_2024-06-03_2024-12-30/118366864_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 127, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366864_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1000/BEAM1000_chunk_10_2024-06-03_2024-12-30/118366865_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5
# Beam BEAM1000 filter counts: {'initial': 236, 'after_qc': 232, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1000 in 118366865_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_01_2019-04-01_2019-10-28/118367097_GEDI02_B_2019122150008_O02186_03_T04733_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 47, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367097_GEDI02_B_2019122150008_O02186_03_T04733_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_01_2019-04-01_2019-10-28/118367098_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 180, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367098_GEDI02_B_2019138014405_O02426_02_T03841_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_01_2019-04-01_2019-10-28/118367099_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 248, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367099_GEDI02_B_2019209043943_O03530_03_T03157_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_01_2019-04-01_2019-10-28/118367100_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 210, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367100_GEDI02_B_2019210205202_O03556_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_02_2019-10-28_2020-05-25/118367327_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 209, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367327_GEDI02_B_2019337015939_O05514_03_T01887_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_03_2020-05-25_2020-12-21/118367423_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 109, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367423_GEDI02_B_2020182144232_O08778_03_T00311_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_03_2020-05-25_2020-12-21/118367424_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 134, 'after_qc': 134, 'after_solar': 134, 'after_leaf_on': 123, 'after_sensitivity': 123, 'after_topography': 102, 'after_elevation': 102, 'after_num_detectedmodes': 102}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118367424_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted_BEAM1011_filtered.csv (102 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_04_2020-12-21_2021-07-19/118367527_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 280, 'after_qc': 274, 'after_solar': 274, 'after_leaf_on': 206, 'after_sensitivity': 206, 'after_topography': 135, 'after_elevation': 135, 'after_num_detectedmodes': 135}
# ✅ Saved: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/118367527_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted_BEAM1011_filtered.csv (135 shots)
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_04_2020-12-21_2021-07-19/118367528_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 176, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367528_GEDI02_B_2021139070445_O13780_03_T06003_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367749_GEDI02_B_2021238154634_O15320_03_T07579_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 4, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367749_GEDI02_B_2021238154634_O15320_03_T07579_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367750_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 124, 'after_qc': 120, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367750_GEDI02_B_2021288125533_O16093_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367751_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 140, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367751_GEDI02_B_2021298160332_O16250_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367752_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 42, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367752_GEDI02_B_2022016072349_O17531_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_05_2021-07-19_2022-02-14/118367753_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 195, 'after_qc': 194, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118367753_GEDI02_B_2022025202812_O17679_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_06_2022-02-14_2022-09-12/118368100_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 137, 'after_qc': 131, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368100_GEDI02_B_2022062130418_O18248_03_T10425_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_06_2022-02-14_2022-09-12/118368101_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 262, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368101_GEDI02_B_2022068034341_O18335_02_T00995_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_06_2022-02-14_2022-09-12/118368102_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 58, 'after_qc': 54, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368102_GEDI02_B_2022110105831_O18991_02_T02571_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_06_2022-02-14_2022-09-12/118368104_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 124, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368104_GEDI02_B_2022177153027_O20033_03_T01887_02_003_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_07_2022-09-12_2023-04-10/118368784_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 129, 'after_qc': 41, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368784_GEDI02_B_2022289120454_O21768_02_T09533_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_07_2022-09-12_2023-04-10/118368786_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 48, 'after_qc': 48, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368786_GEDI02_B_2022352181058_O22749_03_T07426_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_07_2022-09-12_2023-04-10/118368787_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 265, 'after_qc': 264, 'after_solar': 264, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368787_GEDI02_B_2022358084911_O22836_02_T06687_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_07_2022-09-12_2023-04-10/118368788_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 199, 'after_qc': 195, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118368788_GEDI02_B_2023023204458_O23309_02_T08110_02_003_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_10_2024-06-03_2024-12-30/118369233_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 128, 'after_qc': 117, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118369233_GEDI02_B_2024169103448_O31228_02_T05264_02_004_01_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_10_2024-06-03_2024-12-30/118369234_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 145, 'after_qc': 0, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118369234_GEDI02_B_2024206031011_O31797_03_T04733_02_004_02_V002_subsetted.h5.
#
# Processing /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/BEAM1011/BEAM1011_chunk_10_2024-06-03_2024-12-30/118369235_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5
# Beam BEAM1011 filter counts: {'initial': 262, 'after_qc': 259, 'after_solar': 0, 'after_leaf_on': 0, 'after_sensitivity': 0, 'after_topography': 0, 'after_elevation': 0, 'after_num_detectedmodes': 0}
# ⚠️ No valid data left for BEAM1011 in 118369235_GEDI02_B_2024294160731_O33170_03_T08849_02_004_01_V002_subsetted.h5.

# %% [markdown]
# this block a sa recursive issue dont use

# %%
# import os
# import glob
# import pandas as pd

# # Path to the directory with all filtered CSVs
# csv_dir = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs'
# output_csv = os.path.join(csv_dir, 'GEDI_filtered_merged.csv')

# # Recursively get all CSV files in csv_dir and its subdirectories
# csv_files = glob.glob(os.path.join(csv_dir, '**', '*.csv'), recursive=True)

# print(f"Found {len(csv_files)} filtered CSVs to merge.")

# # List to hold DataFrames
# df_list = []

# for idx, file in enumerate(csv_files, 1):
#     df = pd.read_csv(file)
#     if df.empty:
#         print(f"⚠️ Skipping empty file: {file}")
#         continue

#     filename = os.path.basename(file)
#     # Extract beam ID: assumes last three elements of filename split by '_'
#     beam_id = filename.split('_')[-3]

#     df['beam'] = beam_id
#     df['source_file'] = filename

#     df_list.append(df)

#     if idx % 20 == 0:
#         print(f"Merged {idx}/{len(csv_files)} files...")

# # Combine all into one DataFrame
# merged_df = pd.concat(df_list, ignore_index=True)

# # Reorder columns so 'beam' and 'source_file' appear first
# cols = ['beam', 'source_file'] + [c for c in merged_df.columns if c not in ['beam', 'source_file']]
# merged_df = merged_df[cols]

# # Save merged CSV
# merged_df.to_csv(output_csv, index=False)
# print(f"✅ Merged CSV saved to: {output_csv}")
# Out:
# Found 12 filtered CSVs to merge.
# ✅ Merged CSV saved to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/GEDI_filtered_merged.csv

# %%
import os
import pandas as pd

# Directory containing the filtered GEDI CSVs
csv_dir = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs'

# Explicit list of files to merge
file_list = [
    "118367527_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted_BEAM1011_filtered.csv",
    "118367424_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted_BEAM1011_filtered.csv",
    "118365411_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted_BEAM1000_filtered.csv",
    "118365256_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted_BEAM1000_filtered.csv",
    "118363757_GEDI02_B_2022139064237_O19438_03_T04580_02_003_01_V002_subsetted_BEAM0110_filtered.csv",
    "118363288_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted_BEAM0110_filtered.csv",
    "118363110_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted_BEAM0110_filtered.csv",
    "118362200_GEDI02_B_2022139064237_O19438_03_T04580_02_003_01_V002_subsetted_BEAM0101_filtered.csv",
    "118361793_GEDI02_B_2021135083748_O13719_03_T08849_02_003_01_V002_subsetted_BEAM0101_filtered.csv",
    "118361550_GEDI02_B_2020196021509_O08987_02_T05264_02_003_01_V002_subsetted_BEAM0101_filtered.csv"
]

# Output file (stored outside the input folder)
output_csv = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/GEDI_filtered_merged.csv'

df_list = []

for filename in file_list:
    file_path = os.path.join(csv_dir, filename)

    if not os.path.exists(file_path):
        print(f"⚠️ File not found, skipping: {filename}")
        continue

    df = pd.read_csv(file_path)

    if df.empty:
        print(f"⚠️ Skipping empty file: {filename}")
        continue

    # Extract beam ID from filename (e.g., BEAM1011, etc.)
    beam_id = filename.split('_')[-3]

    df['beam'] = beam_id
    df['source_file'] = filename

    df_list.append(df)

# Merge all data
merged_df = pd.concat(df_list, ignore_index=True)

# Move beam + source_file to the front
cols = ['beam', 'source_file'] + [c for c in merged_df.columns if c not in ['beam', 'source_file']]
merged_df = merged_df[cols]

# Save result
merged_df.to_csv(output_csv, index=False)

print(f"✅ Successfully merged {len(df_list)} files.")
print(f"📁 Output saved to: {output_csv}")
# Out:
# ✅ Successfully merged 10 files.
# 📁 Output saved to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/GEDI_filtered_merged.csv

# %%
l2b_path =  '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/GEDI_filtered_merged.csv'
l2b = pd.read_csv(l2b_path)
l2b
# Out:
#           beam                                        source_file    lat  \
# 0    subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.234
# 1    subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.232
# 2    subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.232
# 3    subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.229
# 4    subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.228
# 5    subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.227
# 6    subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.227
# 7    subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.226
# 8    subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.226
# 9    subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.225
# 10   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.225
# 11   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.225
# 12   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.224
# 13   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.224
# 14   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.224
# 15   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.223
# 16   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.223
# 17   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.223
# 18   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.222
# 19   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.222
# 20   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.222
# 21   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.221
# 22   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.221
# 23   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.221
# 24   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.212
# 25   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.211
# 26   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.211
# 27   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.210
# 28   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.210
# 29   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.210
# 30   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.209
# 31   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.209
# 32   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.208
# 33   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.208
# 34   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.207
# 35   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.206
# 36   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.205
# 37   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.205
# 38   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.203
# 39   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.203
# 40   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.202
# 41   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.202
# 42   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.201
# 43   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.201
# 44   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.200
# 45   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.200
# 46   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.199
# 47   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.197
# 48   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.196
# 49   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.196
# 50   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.195
# 51   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.195
# 52   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.195
# 53   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.194
# 54   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.194
# 55   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.193
# 56   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.193
# 57   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.193
# 58   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.191
# 59   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.190
# 60   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.190
# 61   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.190
# 62   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.189
# 63   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.189
# 64   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.189
# 65   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.188
# 66   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.182
# 67   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.181
# 68   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.180
# 69   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.180
# 70   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.179
# 71   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.178
# 72   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.178
# 73   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.177
# 74   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.177
# 75   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.177
# 76   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.176
# 77   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.175
# 78   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.175
# 79   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.175
# 80   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.174
# 81   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.174
# 82   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.173
# 83   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.173
# 84   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.172
# 85   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.172
# 86   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.171
# 87   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.170
# 88   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.170
# 89   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.169
# 90   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.169
# 91   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.168
# 92   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.168
# 93   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.167
# 94   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.165
# 95   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.164
# 96   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.164
# 97   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.164
# 98   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.163
# 99   subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.163
# 100  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.163
# 101  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.162
# 102  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.162
# 103  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.162
# 104  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.161
# 105  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.161
# 106  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.160
# 107  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.160
# 108  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.159
# 109  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.159
# 110  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.158
# 111  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.158
# 112  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.157
# 113  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.157
# 114  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.157
# 115  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.156
# 116  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.156
# 117  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.156
# 118  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.155
# 119  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.155
# 120  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.155
# 121  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.154
# 122  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.154
# 123  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.143
# 124  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.142
# 125  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.141
# 126  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.141
# 127  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.141
# 128  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.140
# 129  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.140
# 130  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.140
# 131  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.139
# 132  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.139
# 133  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.139
# 134  subsetted  118367527_GEDI02_B_2021135083748_O13719_03_T08... 35.138
# 135  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.189
# 136  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.190
# 137  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.190
# 138  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.190
# 139  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.191
# 140  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.191
# 141  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.191
# 142  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.192
# 143  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.192
# 144  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.192
# 145  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.193
# 146  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.193
# 147  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.193
# 148  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.194
# 149  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.194
# 150  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.195
# 151  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.195
# 152  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.196
# 153  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.196
# 154  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.197
# 155  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.197
# 156  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.197
# 157  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.198
# 158  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.198
# 159  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.198
# 160  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.199
# 161  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.199
# 162  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.199
# 163  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.200
# 164  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.200
# 165  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.201
# 166  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.201
# 167  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.201
# 168  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.202
# 169  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.202
# 170  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.203
# 171  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.203
# 172  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.203
# 173  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.204
# 174  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.204
# 175  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.205
# 176  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.205
# 177  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.205
# 178  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.206
# 179  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.206
# 180  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.207
# 181  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.207
# 182  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.207
# 183  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.208
# 184  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.208
# 185  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.208
# 186  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.209
# 187  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.210
# 188  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.210
# 189  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.211
# 190  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.211
# 191  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.212
# 192  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.213
# 193  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.213
# 194  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.213
# 195  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.214
# 196  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.214
# 197  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.214
# 198  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.215
# 199  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.215
# 200  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.215
# 201  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.216
# 202  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.216
# 203  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.216
# 204  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.217
# 205  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.217
# 206  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.218
# 207  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.218
# 208  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.218
# 209  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.219
# 210  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.219
# 211  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.220
# 212  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.220
# 213  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.220
# 214  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.221
# 215  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.221
# 216  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.221
# 217  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.222
# 218  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.222
# 219  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.222
# 220  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.223
# 221  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.223
# 222  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.224
# 223  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.224
# 224  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.225
# 225  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.225
# 226  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.226
# 227  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.226
# 228  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.227
# 229  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.227
# 230  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.228
# 231  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.228
# 232  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.228
# 233  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.229
# 234  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.229
# 235  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.230
# 236  subsetted  118367424_GEDI02_B_2020196021509_O08987_02_T05... 35.230
# 237  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.236
# 238  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.235
# 239  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.234
# 240  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.234
# 241  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.234
# 242  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.233
# 243  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.232
# 244  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.231
# 245  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.229
# 246  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.229
# 247  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.228
# 248  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.227
# 249  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.227
# 250  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.227
# 251  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.226
# 252  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.226
# 253  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.226
# 254  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.225
# 255  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.224
# 256  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.222
# 257  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.221
# 258  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.221
# 259  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.219
# 260  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.218
# 261  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.218
# 262  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.218
# 263  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.217
# 264  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.217
# 265  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.217
# 266  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.216
# 267  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.216
# 268  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.215
# 269  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.215
# 270  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.215
# 271  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.214
# 272  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.214
# 273  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.213
# 274  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.213
# 275  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.212
# 276  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.212
# 277  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.212
# 278  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.211
# 279  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.211
# 280  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.210
# 281  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.210
# 282  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.209
# 283  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.209
# 284  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.208
# 285  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.208
# 286  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.207
# 287  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.206
# 288  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.206
# 289  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.204
# 290  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.203
# 291  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.203
# 292  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.202
# 293  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.201
# 294  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.201
# 295  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.201
# 296  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.200
# 297  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.200
# 298  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.200
# 299  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.198
# 300  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.198
# 301  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.197
# 302  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.197
# 303  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.196
# 304  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.196
# 305  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.195
# 306  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.195
# 307  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.195
# 308  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.194
# 309  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.194
# 310  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.194
# 311  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.193
# 312  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.193
# 313  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.193
# 314  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.192
# 315  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.182
# 316  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.182
# 317  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.181
# 318  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.180
# 319  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.180
# 320  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.172
# 321  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.172
# 322  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.172
# 323  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.170
# 324  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.170
# 325  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.170
# 326  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.169
# 327  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.169
# 328  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.168
# 329  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.168
# 330  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.167
# 331  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.167
# 332  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.167
# 333  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.166
# 334  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.166
# 335  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.166
# 336  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.165
# 337  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.165
# 338  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.164
# 339  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.164
# 340  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.164
# 341  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.163
# 342  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.163
# 343  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.162
# 344  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.162
# 345  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.161
# 346  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.161
# 347  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.160
# 348  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.160
# 349  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.160
# 350  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.159
# 351  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.159
# 352  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.159
# 353  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.158
# 354  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.158
# 355  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.157
# 356  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.157
# 357  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.156
# 358  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.156
# 359  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.155
# 360  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.155
# 361  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.155
# 362  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.154
# 363  subsetted  118365411_GEDI02_B_2021135083748_O13719_03_T08... 35.153
# 364  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.197
# 365  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.197
# 366  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.198
# 367  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.198
# 368  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.198
# 369  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.199
# 370  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.199
# 371  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.199
# 372  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.200
# 373  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.200
# 374  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.200
# 375  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.201
# 376  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.201
# 377  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.201
# 378  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.202
# 379  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.202
# 380  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.202
# 381  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.203
# 382  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.203
# 383  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.204
# 384  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.204
# 385  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.204
# 386  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.205
# 387  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.205
# 388  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.205
# 389  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.206
# 390  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.206
# 391  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.206
# 392  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.207
# 393  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.207
# 394  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.207
# 395  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.208
# 396  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.208
# 397  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.208
# 398  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.209
# 399  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.209
# 400  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.210
# 401  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.210
# 402  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.210
# 403  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.211
# 404  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.211
# 405  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.212
# 406  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.212
# 407  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.212
# 408  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.213
# 409  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.214
# 410  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.214
# 411  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.214
# 412  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.215
# 413  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.215
# 414  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.216
# 415  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.216
# 416  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.216
# 417  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.217
# 418  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.217
# 419  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.217
# 420  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.218
# 421  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.218
# 422  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.221
# 423  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.222
# 424  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.224
# 425  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.225
# 426  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.227
# 427  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.228
# 428  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.228
# 429  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.229
# 430  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.229
# 431  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.229
# 432  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.230
# 433  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.230
# 434  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.230
# 435  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.231
# 436  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.231
# 437  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.232
# 438  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.232
# 439  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.233
# 440  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.234
# 441  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.235
# 442  subsetted  118365256_GEDI02_B_2020196021509_O08987_02_T05... 35.236
# 443  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.137
# 444  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.137
# 445  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.136
# 446  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.136
# 447  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.136
# 448  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.135
# 449  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.135
# 450  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.135
# 451  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.134
# 452  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.133
# 453  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.133
# 454  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.132
# 455  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.132
# 456  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.132
# 457  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.131
# 458  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.130
# 459  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.130
# 460  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.130
# 461  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.129
# 462  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.129
# 463  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.129
# 464  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.128
# 465  subsetted  118363757_GEDI02_B_2022139064237_O19438_03_T04... 35.128
# 466  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.235
# 467  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.235
# 468  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.235
# 469  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.234
# 470  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.234
# 471  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.234
# 472  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.233
# 473  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.233
# 474  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.233
# 475  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.232
# 476  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.232
# 477  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.231
# 478  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.231
# 479  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.229
# 480  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.225
# 481  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.224
# 482  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.224
# 483  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.224
# 484  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.222
# 485  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.221
# 486  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.221
# 487  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.221
# 488  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.220
# 489  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.220
# 490  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.219
# 491  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.219
# 492  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.219
# 493  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.218
# 494  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.218
# 495  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.218
# 496  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.217
# 497  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.217
# 498  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.217
# 499  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.216
# 500  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.216
# 501  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.216
# 502  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.215
# 503  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.215
# 504  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.215
# 505  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.214
# 506  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.214
# 507  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.213
# 508  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.213
# 509  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.213
# 510  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.212
# 511  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.212
# 512  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.212
# 513  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.211
# 514  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.211
# 515  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.211
# 516  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.210
# 517  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.210
# 518  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.210
# 519  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.209
# 520  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.209
# 521  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.208
# 522  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.208
# 523  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.208
# 524  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.207
# 525  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.207
# 526  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.201
# 527  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.201
# 528  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.200
# 529  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.200
# 530  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.199
# 531  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.199
# 532  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.198
# 533  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.198
# 534  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.198
# 535  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.197
# 536  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.197
# 537  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.197
# 538  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.196
# 539  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.196
# 540  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.196
# 541  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.195
# 542  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.195
# 543  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.195
# 544  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.194
# 545  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.194
# 546  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.194
# 547  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.193
# 548  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.193
# 549  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.193
# 550  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.192
# 551  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.192
# 552  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.191
# 553  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.190
# 554  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.190
# 555  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.190
# 556  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.189
# 557  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.189
# 558  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.189
# 559  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.188
# 560  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.188
# 561  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.188
# 562  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.187
# 563  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.187
# 564  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.187
# 565  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.186
# 566  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.186
# 567  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.186
# 568  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.185
# 569  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.185
# 570  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.185
# 571  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.184
# 572  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.184
# 573  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.183
# 574  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.182
# 575  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.181
# 576  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.180
# 577  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.180
# 578  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.179
# 579  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.179
# 580  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.178
# 581  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.178
# 582  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.177
# 583  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.177
# 584  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.176
# 585  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.176
# 586  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.176
# 587  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.175
# 588  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.175
# 589  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.175
# 590  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.174
# 591  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.174
# 592  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.174
# 593  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.173
# 594  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.173
# 595  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.167
# 596  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.167
# 597  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.167
# 598  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.166
# 599  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.166
# 600  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.165
# 601  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.165
# 602  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.164
# 603  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.164
# 604  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.163
# 605  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.163
# 606  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.162
# 607  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.161
# 608  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.161
# 609  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.160
# 610  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.160
# 611  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.160
# 612  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.159
# 613  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.159
# 614  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.159
# 615  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.158
# 616  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.158
# 617  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.158
# 618  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.157
# 619  subsetted  118363288_GEDI02_B_2021135083748_O13719_03_T08... 35.157
# 620  subsetted  118363110_GEDI02_B_2020196021509_O08987_02_T05... 35.207
# 621  subsetted  118363110_GEDI02_B_2020196021509_O08987_02_T05... 35.207
# 622  subsetted  118363110_GEDI02_B_2020196021509_O08987_02_T05... 35.208
# 623  subsetted  118363110_GEDI02_B_2020196021509_O08987_02_T05... 35.208
# 624  subsetted  118363110_GEDI02_B_2020196021509_O08987_02_T05... 35.208
# 625  subsetted  118363110_GEDI02_B_2020196021509_O08987_02_T05... 35.209
# 626  subsetted  118363110_GEDI02_B_2020196021509_O08987_02_T05... 35.209
# 627  subsetted  118363110_GEDI02_B_2020196021509_O08987_02_T05... 35.209
# 628  subsetted  118363110_GEDI02_B_2020196021509_O08987_02_T05... 35.210
# 629  subsetted  118363110_GEDI02_B_2020196021509_O08987_02_T05... 35.210
# ...
# 644             0.004 0.600         NaN 0.400         NaN    -8.062
# 645             0.002 0.600         NaN 0.400         NaN    -1.891
# 646             0.004 0.600         NaN 0.400         NaN   -17.534
# 647             0.001 0.600         NaN 0.400         NaN   -16.759
# 648             0.002 0.600         NaN 0.400         NaN   -17.274
# 649             0.005 0.600         NaN 0.400         NaN   -18.436
# 650             0.005 0.600         NaN 0.400         NaN   -14.894
# 651             0.004 0.600         NaN 0.400         NaN   -14.720
# 652             0.004 0.600         NaN 0.400         NaN    -9.564
# 653             0.021 0.600         NaN 0.400         NaN    -9.978
# 654             0.004 0.600         NaN 0.400         NaN    -4.539
# 655             0.004 0.600         NaN 0.400         NaN   -11.370
# 656             0.005 0.600         NaN 0.400         NaN   -19.817
# 657             0.005 0.600         NaN 0.400         NaN   -15.430
# 658             0.004 0.600         NaN 0.400         NaN   -15.988
# 659             0.004 0.600         NaN 0.400         NaN   -14.324
# 660             0.005 0.600         NaN 0.400         NaN   -18.961
# 661             0.004 0.600         NaN 0.400         NaN   -15.191
# 662             0.004 0.600         NaN 0.400         NaN   -17.446
# 663             0.005 0.600         NaN 0.400         NaN   -16.249
# 664             0.004 0.600         NaN 0.400         NaN   -17.571
# 665             0.004 0.600         NaN 0.400         NaN   -19.381
# 666             0.005 0.600         NaN 0.400         NaN   -16.820
# 667             0.005 0.600         NaN 0.400         NaN   -18.879
# 668             0.004 0.600         NaN 0.400         NaN   -19.342
# 669             0.005 0.600         NaN 0.400         NaN   -18.685
# 670             0.005 0.600         NaN 0.400         NaN   -16.315
# 671             0.004 0.600         NaN 0.400         NaN   -13.322
# 672             0.006 0.600         NaN 0.400         NaN   -18.061
# 673             0.005 0.600         NaN 0.400         NaN   -13.878
# 674             0.005 0.600         NaN 0.400         NaN   -13.611
# 675             0.005 0.600         NaN 0.400         NaN   -18.251
# 676             0.004 0.600         NaN 0.400         NaN    -6.614
# 677             0.001 0.600         NaN 0.400         NaN     5.785
# 678             0.002 0.600         NaN 0.400         NaN    -4.192
# 679             0.006 0.600         NaN 0.400         NaN   -11.015
# 680             0.006 0.600         NaN 0.400         NaN   -11.309
# 681             0.008 0.600         NaN 0.400         NaN   -12.601
# 682             0.005 0.600         NaN 0.400         NaN   -19.232
# 683             0.006 0.600         NaN 0.400         NaN   -12.846
# 684             0.006 0.600         NaN 0.400         NaN   -10.254
# 685             0.004 0.600         NaN 0.400         NaN   -14.325
# 686             0.001 0.600         NaN 0.400         NaN     5.069
# 687             0.005 0.600         NaN 0.400         NaN   -18.076
# 688             0.005 0.600         NaN 0.400         NaN   -10.894
# 689             0.005 0.600         NaN 0.400         NaN   -19.335
# 690             0.007 0.600         NaN 0.400         NaN    -0.125
# 691             0.006 0.600         NaN 0.400         NaN    -9.464
# 692             0.005 0.600         NaN 0.400         NaN    -6.015
# 693             0.008 0.600         NaN 0.400         NaN    -0.298
# 694             0.007 0.600         NaN 0.400         NaN    -5.807
# 695             0.007 0.600         NaN 0.400         NaN   -16.944
# 696             0.006 0.600         NaN 0.400         NaN    -9.822
# 697             0.006 0.600         NaN 0.400         NaN   -19.223
# 698             0.007 0.600         NaN 0.400         NaN   -13.394
# 699             0.008 0.600         NaN 0.400         NaN    -3.683
# 700             0.009 0.600         NaN 0.400         NaN   -18.218
# 701             0.005 0.600         NaN 0.400         NaN    -2.574
# 702             0.009 0.600         NaN 0.400         NaN   -15.368
# 703             0.005 0.600         NaN 0.400         NaN   -11.136
# 704             0.006 0.600         NaN 0.400         NaN    -9.648
# 705             0.006 0.600         NaN 0.400         NaN   -14.906
# 706             0.008 0.600         NaN 0.400         NaN   -15.856
# 707             0.006 0.600         NaN 0.400         NaN    -6.899
# 708             0.007 0.600         NaN 0.400         NaN   -13.856
# 709             0.005 0.600         NaN 0.400         NaN   -10.958
# 710             0.007 0.600         NaN 0.400         NaN     0.264
# 711             0.006 0.600         NaN 0.400         NaN    -0.411
# 712             0.006 0.600         NaN 0.400         NaN   -13.581
# 713             0.007 0.600         NaN 0.400         NaN   -17.094
# 714             0.005 0.600         NaN 0.400         NaN   -12.958
# 715             0.010 0.600         NaN 0.400         NaN    -9.550
# 716             0.006 0.600         NaN 0.400         NaN    -9.206
# 717             0.005 0.600         NaN 0.400         NaN   -12.182
# 718             0.005 0.600         NaN 0.400         NaN   -18.407
# 719             0.007 0.600         NaN 0.400         NaN   -18.911
# 720             0.007 0.600         NaN 0.400         NaN   -17.807
# 721             0.006 0.600         NaN 0.400         NaN   -13.713
# 722             0.005 0.600         NaN 0.400         NaN   -13.989
# 723             0.006 0.600         NaN 0.400         NaN    -8.236
# 724             0.008 0.600         NaN 0.400         NaN   -17.404
# 725             0.006 0.600         NaN 0.400         NaN   -18.219
# 726             0.007 0.600         NaN 0.400         NaN   -16.544
# 727             0.008 0.600         NaN 0.400         NaN   -16.689
# 728             0.005 0.600         NaN 0.400         NaN   -16.274
# 729             0.005 0.600         NaN 0.400         NaN   -13.998
# 730             0.008 0.600         NaN 0.400         NaN   -12.445
# 731             0.005 0.600         NaN 0.400         NaN   -14.335
# 732             0.006 0.600         NaN 0.400         NaN   -13.844
# 733             0.007 0.600         NaN 0.400         NaN   -14.268
# 734             0.010 0.600         NaN 0.400         NaN   -12.427
# 735             0.008 0.600         NaN 0.400         NaN   -16.562
# 736             0.005 0.600         NaN 0.400         NaN    -9.829
# 737             0.005 0.600         NaN 0.400         NaN   -12.269
# 738             0.005 0.600         NaN 0.400         NaN   -10.855
# 739             0.006 0.600         NaN 0.400         NaN   -16.216
# 740             0.005 0.600         NaN 0.400         NaN   -13.318
# 741             0.005 0.600         NaN 0.400         NaN   -16.917
# 742             0.005 0.600         NaN 0.400         NaN   -16.472
# 743             0.004 0.600         NaN 0.400         NaN   -11.101
# 744             0.004 0.600         NaN 0.400         NaN    -9.747
# 745             0.005 0.600         NaN 0.400         NaN   -12.995
# 746             0.008 0.600         NaN 0.400         NaN   -17.558
# 747             0.003 0.600         NaN 0.400         NaN   -11.355
# 748             0.005 0.600         NaN 0.400         NaN   -16.851
# 749             0.006 0.600         NaN 0.400         NaN    -9.684
# 750             0.006 0.600         NaN 0.400         NaN   -14.953
# 751             0.005 0.600         NaN 0.400         NaN   -10.150
# 752             0.005 0.600         NaN 0.400         NaN   -12.205
# 753             0.006 0.600         NaN 0.400         NaN   -13.182
# 754             0.005 0.600         NaN 0.400         NaN   -18.364
# 755             0.005 0.600         NaN 0.400         NaN   -18.443
# 756             0.005 0.600         NaN 0.400         NaN   -14.980
# 757             0.005 0.600         NaN 0.400         NaN   -13.005
# 758             0.006 0.600         NaN 0.400         NaN   -13.210
# 759             0.006 0.600         NaN 0.400         NaN   -12.437
# 760             0.005 0.600         NaN 0.400         NaN   -14.875
# 761             0.005 0.600         NaN 0.400         NaN   -12.502
# 762             0.006 0.600         NaN 0.400         NaN   -11.322
# 763             0.005 0.600         NaN 0.400         NaN   -16.789
# 764             0.005 0.600         NaN 0.400         NaN   -14.379
# 765             0.005 0.600         NaN 0.400         NaN   -17.902
# 766             0.006 0.600         NaN 0.400         NaN   -18.530
# 767             0.005 0.600         NaN 0.400         NaN   -16.580
# 768             0.004 0.600         NaN 0.400         NaN   -11.681
# 769             0.002 0.600         NaN 0.400         NaN   -11.702
# 770             0.004 0.600         NaN 0.400         NaN   -10.878
# 771             0.001 0.600         NaN 0.400         NaN    -7.961
# 772             0.004 0.600         NaN 0.400         NaN   -11.973
# 773             0.005 0.600         NaN 0.400         NaN   -16.867
# 774             0.008 0.600         NaN 0.400         NaN   -13.629
# 775             0.004 0.600         NaN 0.400         NaN   -19.085
# 776             0.005 0.600         NaN 0.400         NaN   -12.916
# 777             0.004 0.600         NaN 0.400         NaN   -12.025
# 778             0.005 0.600         NaN 0.400         NaN   -19.062
# 779             0.006 0.600         NaN 0.400         NaN   -13.739
# 780             0.005 0.600         NaN 0.400         NaN   -12.820
# 781             0.006 0.600         NaN 0.400         NaN   -14.540
# 782             0.006 0.600         NaN 0.400         NaN   -17.660
# 783             0.005 0.600         NaN 0.400         NaN   -16.182
# 784             0.005 0.600         NaN 0.400         NaN   -17.067
# 785             0.005 0.600         NaN 0.400         NaN   -16.578
# 786             0.006 0.600         NaN 0.400         NaN   -11.279
# 787             0.004 0.600         NaN 0.400         NaN    -7.480
# 788             0.005 0.600         NaN 0.400         NaN   -14.608
# 789             0.000 0.600         NaN 0.400         NaN    -4.257
# 790             0.004 0.600         NaN 0.400         NaN   -13.631
# 791             0.006 0.600         NaN 0.400         NaN   -13.902
# 792             0.005 0.600         NaN 0.400         NaN   -14.991
# 793             0.005 0.600         NaN 0.400         NaN   -10.182
# 794             0.008 0.600         NaN 0.400         NaN   -16.516
# 795             0.006 0.600         NaN 0.400         NaN   -14.408
# 796             0.005 0.600         NaN 0.400         NaN   -14.440
# 797             0.009 0.600         NaN 0.400         NaN   -18.397
# 798             0.009 0.600         NaN 0.400         NaN   -19.518
# 799             0.005 0.600         NaN 0.400         NaN   -17.662
# 800             0.005 0.600         NaN 0.400         NaN   -15.058
# 801             0.004 0.600         NaN 0.400         NaN   -16.443
# 802             0.005 0.600         NaN 0.400         NaN   -19.598
# 803             0.005 0.600         NaN 0.400         NaN   -17.047
# 804             0.005 0.600         NaN 0.400         NaN   -19.801
# 805             0.005 0.600         NaN 0.400         NaN   -16.333
# 806             0.005 0.600         NaN 0.400         NaN   -15.625
# 807             0.005 0.600         NaN 0.400         NaN   -16.934
# 808             0.004 0.600         NaN 0.400         NaN   -18.538
# 809             0.005 0.600         NaN 0.400         NaN   -18.214
# 810             0.010 0.600         NaN 0.400         NaN   -18.527
# 811             0.006 0.600         NaN 0.400         NaN   -16.510
# 812             0.005 0.600         NaN 0.400         NaN   -17.576
# 813             0.005 0.600         NaN 0.400         NaN   -18.413
# 814             0.005 0.600         NaN 0.400         NaN   -16.624
# 815             0.005 0.600         NaN 0.400         NaN   -14.462
# 816             0.005 0.600         NaN 0.400         NaN   -16.414
# 817             0.005 0.600         NaN 0.400         NaN   -17.294
# 818             0.005 0.600         NaN 0.400         NaN   -14.892
# 819             0.006 0.600         NaN 0.400         NaN   -16.916
# 820             0.007 0.600         NaN 0.400         NaN   -17.798
# 821             0.005 0.600         NaN 0.400         NaN   -16.867
# 822             0.004 0.600         NaN 0.400         NaN   -19.812
# 823             0.005 0.600         NaN 0.400         NaN   -15.334
# 824             0.002 0.600         NaN 0.400         NaN   -18.127
# 825             0.004 0.600         NaN 0.400         NaN    -9.679
# 826             0.005 0.600         NaN 0.400         NaN    -9.802
# 827             0.004 0.600         NaN 0.400         NaN   -14.845
# 828             0.006 0.600         NaN 0.400         NaN    -8.127
# 829             0.007 0.600         NaN 0.400         NaN    -5.938
# 830             0.007 0.600         NaN 0.400         NaN    -6.328
# 831             0.004 0.600         NaN 0.400         NaN   -11.269
# 832             0.006 0.600         NaN 0.400         NaN    -8.036
# 833             0.005 0.600         NaN 0.400         NaN   -12.794
# 834             0.005 0.600         NaN 0.400         NaN   -16.119
# 835             0.006 0.600         NaN 0.400         NaN   -13.014
# 836             0.006 0.600         NaN 0.400         NaN   -12.574
# 837             0.006 0.600         NaN 0.400         NaN   -12.248
# 838             0.007 0.600         NaN 0.400         NaN    -6.214
# 839             0.006 0.600         NaN 0.400         NaN    -8.232
# 840             0.005 0.600         NaN 0.400         NaN    -8.042
# 841             0.005 0.600         NaN 0.400         NaN   -19.164
# 842             0.006 0.600         NaN 0.400         NaN    -6.890
# 843             0.005 0.600         NaN 0.400         NaN    -5.293
# 844             0.006 0.600         NaN 0.400         NaN   -17.299
# 845             0.004 0.600         NaN 0.400         NaN   -15.959
# 846             0.005 0.600         NaN 0.400         NaN   -12.508
# 847             0.000 0.600         NaN 0.400         NaN   -15.889
# 848             0.004 0.600         NaN 0.400         NaN   -14.688
# 849             0.002 0.600         NaN 0.400         NaN   -15.548
# 850             0.005 0.600         NaN 0.400         NaN   -15.206
# 851             0.004 0.600         NaN 0.400         NaN   -16.572
# 852             0.000 0.600         NaN 0.400         NaN   -15.930
# 853             0.006 0.600         NaN 0.400         NaN   -19.749
# 854             0.007 0.600         NaN 0.400         NaN   -19.817
# 855             0.006 0.600         NaN 0.400         NaN   -19.953
# 856             0.004 0.600         NaN 0.400         NaN   -12.357
# 857             0.006 0.600         NaN 0.400         NaN    -3.814
# 858             0.000 0.600         NaN 0.400         NaN    -5.984
# 859             0.006 0.600         NaN 0.400         NaN     0.468
# 860             0.006 0.600         NaN 0.400         NaN    -8.168
# 861             0.007 0.600         NaN 0.400         NaN    -9.252
# 862             0.002 0.600         NaN 0.400         NaN    -7.523
# 863             0.004 0.600         NaN 0.400         NaN    -5.983
# 864             0.006 0.600         NaN 0.400         NaN    -4.885
# 865             0.006 0.600         NaN 0.400         NaN   -17.540
# 866             0.004 0.600         NaN 0.400         NaN   -16.923
# 867             0.006 0.600         NaN 0.400         NaN   -15.541
# 868             0.006 0.600         NaN 0.400         NaN   -17.501
# 869             0.008 0.600         NaN 0.400         NaN     0.739
# 870             0.008 0.600         NaN 0.400         NaN   -11.172
# 871             0.006 0.600         NaN 0.400         NaN    -6.730
#
# [872 rows x 116 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load merged CSV
csv_path = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/GEDI_filtered_merged.csv'
df = pd.read_csv(csv_path)

# # Preview columns
# print("Columns available:", df.columns.tolist())

# # Automatically select all numeric columns
# numeric_cols = df.select_dtypes(include=['number']).columns.tolist()
# print(f"Numeric columns selected for plotting: {numeric_cols}")

# # Drop rows with missing or NaN values in numeric columns
# df_clean = df[numeric_cols].dropna()

# Pair plot
sns.pairplot(df, corner=True, plot_kws={'alpha': 0.3})
plt.suptitle('GEDI Observation Pair Plot', y=1.02)
plt.show()

# %%
df.columns.tolist()
# Out:
# ['beam',
#  'source_file',
#  'lat',
#  'lon',
#  'solar_elevation',
#  'local_beam_elevation',
#  'selected_l2a_algorithm',
#  'degrade_flag',
#  'l2b_quality_flag',
#  'digital_elevation_model',
#  'elev_lowestmode',
#  'elev_highestreturn',
#  'rh100',
#  'num_detectedmodes',
#  'sensitivity',
#  'leaf_off_flag',
#  'pai',
#  'pai_z_bin_0',
#  'pai_z_bin_1',
#  'pai_z_bin_2',
#  'pai_z_bin_3',
#  'pai_z_bin_4',
#  'pai_z_bin_5',
#  'pai_z_bin_6',
#  'pai_z_bin_7',
#  'pai_z_bin_8',
#  'pai_z_bin_9',
#  'pai_z_bin_10',
#  'pai_z_bin_11',
#  'pai_z_bin_12',
#  'pai_z_bin_13',
#  'pai_z_bin_14',
#  'pai_z_bin_15',
#  'pai_z_bin_16',
#  'pai_z_bin_17',
#  'pai_z_bin_18',
#  'pai_z_bin_19',
#  'pai_z_bin_20',
#  'pai_z_bin_21',
#  'pai_z_bin_22',
#  'pai_z_bin_23',
#  'pai_z_bin_24',
#  'pai_z_bin_25',
#  'pai_z_bin_26',
#  'pai_z_bin_27',
#  'pai_z_bin_28',
#  'pai_z_bin_29',
#  'fhd_normal',
#  'pavd_z_bin_0',
#  'pavd_z_bin_1',
#  'pavd_z_bin_2',
#  'pavd_z_bin_3',
#  'pavd_z_bin_4',
#  'pavd_z_bin_5',
#  'pavd_z_bin_6',
#  'pavd_z_bin_7',
#  'pavd_z_bin_8',
#  'pavd_z_bin_9',
#  'pavd_z_bin_10',
#  'pavd_z_bin_11',
#  'pavd_z_bin_12',
#  'pavd_z_bin_13',
#  'pavd_z_bin_14',
#  'pavd_z_bin_15',
#  'pavd_z_bin_16',
#  'pavd_z_bin_17',
#  'pavd_z_bin_18',
#  'pavd_z_bin_19',
#  'pavd_z_bin_20',
#  'pavd_z_bin_21',
#  'pavd_z_bin_22',
#  'pavd_z_bin_23',
#  'pavd_z_bin_24',
#  'pavd_z_bin_25',
#  'pavd_z_bin_26',
#  'pavd_z_bin_27',
#  'pavd_z_bin_28',
#  'pavd_z_bin_29',
#  'cover',
#  'cover_z_bin_0',
#  'cover_z_bin_1',
#  'cover_z_bin_2',
#  'cover_z_bin_3',
#  'cover_z_bin_4',
#  'cover_z_bin_5',
#  'cover_z_bin_6',
#  'cover_z_bin_7',
#  'cover_z_bin_8',
#  'cover_z_bin_9',
#  'cover_z_bin_10',
#  'cover_z_bin_11',
#  'cover_z_bin_12',
#  'cover_z_bin_13',
#  'cover_z_bin_14',
#  'cover_z_bin_15',
#  'cover_z_bin_16',
#  'cover_z_bin_17',
#  'cover_z_bin_18',
#  'cover_z_bin_19',
#  'cover_z_bin_20',
#  'cover_z_bin_21',
#  'cover_z_bin_22',
#  'cover_z_bin_23',
#  'cover_z_bin_24',
#  'cover_z_bin_25',
#  'cover_z_bin_26',
#  'cover_z_bin_27',
#  'cover_z_bin_28',
#  'cover_z_bin_29',
#  'pgap_theta',
#  'pgap_theta_error',
#  'rhov',
#  'rhov_error',
#  'rhog',
#  'rhog_error',
#  'dem_diff',
#  'pai_z',
#  'pavd_z',
#  'cover_z',
#  'Unnamed: 0',
#  'count',
#  'nans',
#  'mean',
#  'min',
#  'max',
#  'std',
#  'num_-9999']

# %%
df
# Out:
#            beam                                        source_file        lat  \
# 0     subsetted  118362200_GEDI02_B_2022139064237_O19438_03_T04...  35.143790
# 1     subsetted  118362200_GEDI02_B_2022139064237_O19438_03_T04...  35.143436
# 2     subsetted  118362200_GEDI02_B_2022139064237_O19438_03_T04...  35.143084
# 3     subsetted  118362200_GEDI02_B_2022139064237_O19438_03_T04...  35.142734
# 4     subsetted  118362200_GEDI02_B_2022139064237_O19438_03_T04...  35.142380
# ...         ...                                                ...        ...
# 1766   filtered                   GEDI_filtered_merged_summary.csv        NaN
# 1767   filtered                   GEDI_filtered_merged_summary.csv        NaN
# 1768   filtered                   GEDI_filtered_merged_summary.csv        NaN
# 1769   filtered                   GEDI_filtered_merged_summary.csv        NaN
# 1770   filtered                   GEDI_filtered_merged_summary.csv        NaN
#
#             lon  solar_elevation  local_beam_elevation  \
# 0    -85.989702       -28.266678              1.473616
# 1    -85.989238       -28.266764              1.473616
# 2    -85.988777       -28.266850              1.473616
# 3    -85.988317       -28.266935              1.473616
# 4    -85.987853       -28.267021              1.473616
# ...         ...              ...                   ...
# 1766        NaN              NaN                   NaN
# 1767        NaN              NaN                   NaN
# 1768        NaN              NaN                   NaN
# 1769        NaN              NaN                   NaN
# 1770        NaN              NaN                   NaN
#
#       selected_l2a_algorithm  degrade_flag  l2b_quality_flag  \
# 0                        2.0           0.0               1.0
# 1                        2.0           0.0               1.0
# 2                        2.0           0.0               1.0
# 3                        2.0           0.0               1.0
# 4                        2.0           0.0               1.0
# ...                      ...           ...               ...
# 1766                     NaN           NaN               NaN
# 1767                     NaN           NaN               NaN
# 1768                     NaN           NaN               NaN
# 1769                     NaN           NaN               NaN
# 1770                     NaN           NaN               NaN
#
#       digital_elevation_model  ...  pavd_z  cover_z        Unnamed: 0  count  \
# 0                  421.361786  ...     NaN      NaN               NaN    NaN
# 1                  433.982147  ...     NaN      NaN               NaN    NaN
# 2                  447.244324  ...     NaN      NaN               NaN    NaN
# 3                  440.506836  ...     NaN      NaN               NaN    NaN
# 4                  456.909363  ...     NaN      NaN               NaN    NaN
# ...                       ...  ...     ...      ...               ...    ...
# 1766                      NaN  ...     NaN      NaN        pgap_theta  872.0
# 1767                      NaN  ...     NaN      NaN              rhov  872.0
# 1768                      NaN  ...     NaN      NaN  pgap_theta_error  872.0
# 1769                      NaN  ...     NaN      NaN              rhog  872.0
# 1770                      NaN  ...     NaN      NaN          dem_diff  872.0
#
#       nans       mean        min        max       std  num_-9999
# 0      NaN        NaN        NaN        NaN       NaN        NaN
# 1      NaN        NaN        NaN        NaN       NaN        NaN
# 2      NaN        NaN        NaN        NaN       NaN        NaN
# 3      NaN        NaN        NaN        NaN       NaN        NaN
# 4      NaN        NaN        NaN        NaN       NaN        NaN
# ...    ...        ...        ...        ...       ...        ...
# 1766   0.0   0.246156   0.022257   0.999161  0.249604        0.0
# 1767   0.0   0.600000   0.600000   0.600000  0.000000        0.0
# 1768   0.0   0.004714   0.000003   0.021198  0.002032        0.0
# 1769   0.0   0.400000   0.400000   0.400000  0.000000        0.0
# 1770   0.0 -12.553175 -19.999817  11.555786  5.891255        0.0
#
# [1771 rows x 127 columns]

# %%
import pandas as pd
import numpy as np

# Load your merged filtered GEDI CSV
csv_path = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/GEDI_filtered_merged.csv'
df = pd.read_csv(csv_path)

# Replace strings or whitespace column names just in case
df.columns = df.columns.str.strip()

# Convert obvious fill values (-9999 etc.) to NaN
df.replace([-9999, -9999.0, -9998.999], np.nan, inplace=True)

# Select numeric columns only
numeric_df = df.select_dtypes(include=[np.number])

# Build summary table
summary = pd.DataFrame({
    'count': numeric_df.count(),
    'nans': numeric_df.isna().sum(),
    'mean': numeric_df.mean(),
    'min': numeric_df.min(),
    'max': numeric_df.max(),
    'std': numeric_df.std(),
})

# Add count of fill values (before conversion)
df_raw = pd.read_csv(csv_path)  # reload to count raw -9999 values
for col in numeric_df.columns:
    summary.loc[col, 'num_-9999'] = (df_raw[col] == -9999).sum() if col in df_raw.columns else 0

# Sort by number of missing values for easy QA
summary = summary.sort_values(by='nans', ascending=False)

# Display full table in Colab
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', '{:.3f}'.format)
display(summary)

# Optional: Save to CSV
summary_path = csv_path.replace('.csv', '_summary.csv')
summary.to_csv(summary_path)
print(f"✅ Summary saved to: {summary_path}")
# Out:
#                          count  nans     mean     min      max     std  \
# rhog_error                   0   872      NaN     NaN      NaN     NaN
# rhov_error                   0   872      NaN     NaN      NaN     NaN
# solar_elevation            872     0  -15.878 -28.275  -12.481   4.618
# local_beam_elevation       872     0    1.521   1.458    1.564   0.048
# selected_l2a_algorithm     872     0    1.497   1.000    2.000   0.500
# degrade_flag               872     0    0.000   0.000    0.000   0.000
# l2b_quality_flag           872     0    1.000   1.000    1.000   0.000
# digital_elevation_model    872     0  516.292 278.918  580.497  71.094
# elev_lowestmode            872     0  503.739 279.369  564.376  69.428
# elev_highestreturn         872     0  530.667 286.926  593.197  70.267
# rh100                      872     0 2691.800 344.000 5229.000 704.535
# num_detectedmodes          872     0    4.648   1.000   17.000   2.680
# sensitivity                872     0    0.982   0.957    0.995   0.009
# leaf_off_flag              872     0    0.000   0.000    0.000   0.000
# pai                        872     0    3.494   0.002    7.610   1.551
# pai_z_bin_0                872     0    3.491   0.001    7.610   1.550
# lat                        872     0   35.197  35.127   35.236   0.029
# lon                        872     0  -85.938 -85.990  -85.858   0.038
# pai_z_bin_3                872     0    1.594  -0.000    3.903   0.931
# pai_z_bin_4                872     0    0.807  -0.000    3.085   0.676
# pai_z_bin_5                872     0    0.219  -0.000    2.035   0.337
# pai_z_bin_6                872     0    0.035  -0.000    1.039   0.120
# pai_z_bin_7                872     0    0.005  -0.000    0.388   0.029
# pai_z_bin_8                872     0    0.001  -0.000    0.184   0.009
# pai_z_bin_9                872     0    0.000  -0.000    0.061   0.002
# pai_z_bin_10               872     0    0.000  -0.000    0.026   0.001
# pai_z_bin_11               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_12               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_13               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_14               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_15               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_16               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_17               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_18               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_19               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_20               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_21               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_22               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_23               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_24               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_25               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_26               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_27               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_28               872     0    0.000  -0.000   -0.000   0.000
# pai_z_bin_29               872     0    0.000  -0.000   -0.000   0.000
# fhd_normal                 872     0    3.034   0.813    3.373   0.416
# pavd_z_bin_0               872     0    0.083   0.000    0.532   0.060
# pavd_z_bin_1               872     0    0.113   0.000    0.443   0.067
# pai_z_bin_1                872     0    3.077  -0.000    5.998   1.373
# pai_z_bin_2                872     0    2.366  -0.000    4.727   1.140
# pavd_z_bin_3               872     0    0.156  -0.000    0.372   0.076
# pavd_z_bin_2               872     0    0.148  -0.000    0.423   0.078
# pavd_z_bin_4               872     0    0.138  -0.000    0.328   0.076
# pavd_z_bin_5               872     0    0.077  -0.000    0.249   0.063
# pavd_z_bin_8               872     0    0.000  -0.000    0.037   0.003
# pavd_z_bin_9               872     0    0.000  -0.000    0.018   0.001
# pavd_z_bin_6               872     0    0.021  -0.000    0.186   0.032
# pavd_z_bin_7               872     0    0.003  -0.000    0.102   0.012
# pavd_z_bin_12              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_13              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_14              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_15              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_16              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_17              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_10              872     0    0.000  -0.000    0.006   0.000
# pavd_z_bin_11              872     0    0.000  -0.000    0.003   0.000
# pavd_z_bin_20              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_21              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_22              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_23              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_24              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_25              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_26              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_27              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_28              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_29              872     0    0.000  -0.000   -0.000   0.000
# cover                      872     0    0.752   0.001    0.978   0.249
# cover_z_bin_0              872     0    0.752   0.001    0.978   0.249
# cover_z_bin_1              872     0    0.716   0.000    0.948   0.251
# cover_z_bin_2              872     0    0.633   0.000    0.906   0.245
# pavd_z_bin_18              872     0    0.000  -0.000   -0.000   0.000
# pavd_z_bin_19              872     0    0.000  -0.000   -0.000   0.000
# cover_z_bin_4              872     0    0.296   0.000    0.786   0.214
# cover_z_bin_3              872     0    0.497   0.000    0.858   0.239
# cover_z_bin_5              872     0    0.092   0.000    0.638   0.128
# cover_z_bin_6              872     0    0.016   0.000    0.405   0.051
# cover_z_bin_9              872     0    0.000   0.000    0.030   0.001
# cover_z_bin_10             872     0    0.000   0.000    0.013   0.000
# cover_z_bin_7              872     0    0.002   0.000    0.176   0.014
# cover_z_bin_8              872     0    0.000   0.000    0.088   0.004
# cover_z_bin_13             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_14             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_15             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_16             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_17             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_18             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_11             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_12             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_20             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_19             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_21             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_22             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_25             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_26             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_23             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_24             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_28             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_27             872     0    0.000   0.000    0.000   0.000
# cover_z_bin_29             872     0    0.000   0.000    0.000   0.000
# pgap_theta                 872     0    0.246   0.022    0.999   0.250
# rhov                       872     0    0.600   0.600    0.600   0.000
# pgap_theta_error           872     0    0.005   0.000    0.021   0.002
# rhog                       872     0    0.400   0.400    0.400   0.000
# dem_diff                   872     0  -12.553 -20.000   11.556   5.891
#
#                          num_-9999
# rhog_error                   0.000
# rhov_error                   0.000
# solar_elevation              0.000
# local_beam_elevation         0.000
# selected_l2a_algorithm       0.000
# degrade_flag                 0.000
# l2b_quality_flag             0.000
# digital_elevation_model      0.000
# elev_lowestmode              0.000
# elev_highestreturn           0.000
# rh100                        0.000
# num_detectedmodes            0.000
# sensitivity                  0.000
# leaf_off_flag                0.000
# pai                          0.000
# pai_z_bin_0                  0.000
# lat                          0.000
# lon                          0.000
# pai_z_bin_3                  0.000
# pai_z_bin_4                  0.000
# pai_z_bin_5                  0.000
# pai_z_bin_6                  0.000
# pai_z_bin_7                  0.000
# pai_z_bin_8                  0.000
# pai_z_bin_9                  0.000
# pai_z_bin_10                 0.000
# pai_z_bin_11                 0.000
# pai_z_bin_12                 0.000
# pai_z_bin_13                 0.000
# pai_z_bin_14                 0.000
# pai_z_bin_15                 0.000
# pai_z_bin_16                 0.000
# pai_z_bin_17                 0.000
# pai_z_bin_18                 0.000
# pai_z_bin_19                 0.000
# pai_z_bin_20                 0.000
# pai_z_bin_21                 0.000
# pai_z_bin_22                 0.000
# pai_z_bin_23                 0.000
# pai_z_bin_24                 0.000
# pai_z_bin_25                 0.000
# pai_z_bin_26                 0.000
# pai_z_bin_27                 0.000
# pai_z_bin_28                 0.000
# pai_z_bin_29                 0.000
# fhd_normal                   0.000
# pavd_z_bin_0                 0.000
# pavd_z_bin_1                 0.000
# pai_z_bin_1                  0.000
# pai_z_bin_2                  0.000
# pavd_z_bin_3                 0.000
# pavd_z_bin_2                 0.000
# pavd_z_bin_4                 0.000
# pavd_z_bin_5                 0.000
# pavd_z_bin_8                 0.000
# pavd_z_bin_9                 0.000
# pavd_z_bin_6                 0.000
# pavd_z_bin_7                 0.000
# pavd_z_bin_12                0.000
# pavd_z_bin_13                0.000
# pavd_z_bin_14                0.000
# pavd_z_bin_15                0.000
# pavd_z_bin_16                0.000
# pavd_z_bin_17                0.000
# pavd_z_bin_10                0.000
# pavd_z_bin_11                0.000
# pavd_z_bin_20                0.000
# pavd_z_bin_21                0.000
# pavd_z_bin_22                0.000
# pavd_z_bin_23                0.000
# pavd_z_bin_24                0.000
# pavd_z_bin_25                0.000
# pavd_z_bin_26                0.000
# pavd_z_bin_27                0.000
# pavd_z_bin_28                0.000
# pavd_z_bin_29                0.000
# cover                        0.000
# cover_z_bin_0                0.000
# cover_z_bin_1                0.000
# cover_z_bin_2                0.000
# pavd_z_bin_18                0.000
# pavd_z_bin_19                0.000
# cover_z_bin_4                0.000
# cover_z_bin_3                0.000
# cover_z_bin_5                0.000
# cover_z_bin_6                0.000
# cover_z_bin_9                0.000
# cover_z_bin_10               0.000
# cover_z_bin_7                0.000
# cover_z_bin_8                0.000
# cover_z_bin_13               0.000
# cover_z_bin_14               0.000
# cover_z_bin_15               0.000
# cover_z_bin_16               0.000
# cover_z_bin_17               0.000
# cover_z_bin_18               0.000
# cover_z_bin_11               0.000
# cover_z_bin_12               0.000
# cover_z_bin_20               0.000
# cover_z_bin_19               0.000
# cover_z_bin_21               0.000
# cover_z_bin_22               0.000
# cover_z_bin_25               0.000
# cover_z_bin_26               0.000
# cover_z_bin_23               0.000
# cover_z_bin_24               0.000
# cover_z_bin_28               0.000
# cover_z_bin_27               0.000
# cover_z_bin_29               0.000
# pgap_theta                   0.000
# rhov                         0.000
# pgap_theta_error             0.000
# rhog                         0.000
# dem_diff                     0.000
# ✅ Summary saved to: /content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/GEDI_filtered_merged_summary.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Required for 3D projection
import matplotlib.colors as mcolors

# Load the merged filtered GEDI CSV
csv_path = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/GEDI_filtered_merged.csv'
df = pd.read_csv(csv_path)

# Check that lat/lon exist
for col in ['lat', 'lon']:
    if col not in df.columns:
        raise ValueError(f"Column '{col}' is missing from the CSV!")

# Automatically select numeric variables excluding lat/lon
numeric_cols = df.select_dtypes(include=['number']).columns.tolist()
variables_to_plot = [v for v in numeric_cols if v not in ['lat', 'lon']]

print(f"Variables to plot in 3D: {variables_to_plot}")

# If 'AOI' exists, group by AOI; otherwise treat as one group
if 'AOI' in df.columns:
    grouped_dfs = {aoi: group for aoi, group in df.groupby('AOI')}
else:
    grouped_dfs = {'All_Data': df}

num_vars = len(variables_to_plot)
fig = plt.figure(figsize=(6 * num_vars, 6))  # Dynamic sizing

for i, var in enumerate(variables_to_plot, start=1):
    # Compute global min/max for color normalization
    vmin = min(g[var].min() for g in grouped_dfs.values())
    vmax = max(g[var].max() for g in grouped_dfs.values())

    ax = fig.add_subplot(1, num_vars, i, projection='3d')

    # Plot each group (AOI) with a different marker/color if multiple groups exist
    for name, gdf in grouped_dfs.items():
        ax.scatter(
            gdf['lat'], gdf['lon'], gdf[var],
            s=5,
            c=gdf[var],
            cmap='viridis',
            vmin=vmin,
            vmax=vmax,
            label=name
        )

    ax.set_xlabel('Latitude')
    ax.set_ylabel('Longitude')
    ax.set_zlabel(var)
    ax.set_title(f"{var} (3D)")
    ax.set_zlim(vmin, vmax)
    if len(grouped_dfs) > 1:
        ax.legend()

# Shared colorbar
cbar_ax = fig.add_axes([0.92, 0.15, 0.015, 0.7])
norm = mcolors.Normalize(vmin=min(df[variables_to_plot].min()), vmax=max(df[variables_to_plot].max()))
cbar = plt.colorbar(plt.cm.ScalarMappable(norm=norm, cmap='viridis'), cax=cbar_ax)
cbar.set_label('Variable value')

plt.suptitle('3D Visualization of GEDI Variables (filtered)', fontsize=18)
plt.tight_layout(rect=[0, 0, 0.9, 0.95])
plt.show()
# Out:
# Variables to plot in 3D: ['solar_elevation', 'local_beam_elevation', 'selected_l2a_algorithm', 'degrade_flag', 'l2b_quality_flag', 'digital_elevation_model', 'elev_lowestmode', 'elev_highestreturn', 'rh100', 'num_detectedmodes', 'sensitivity', 'leaf_off_flag', 'pai', 'pai_z_bin_0', 'pai_z_bin_1', 'pai_z_bin_2', 'pai_z_bin_3', 'pai_z_bin_4', 'pai_z_bin_5', 'pai_z_bin_6', 'pai_z_bin_7', 'pai_z_bin_8', 'pai_z_bin_9', 'pai_z_bin_10', 'pai_z_bin_11', 'pai_z_bin_12', 'pai_z_bin_13', 'pai_z_bin_14', 'pai_z_bin_15', 'pai_z_bin_16', 'pai_z_bin_17', 'pai_z_bin_18', 'pai_z_bin_19', 'pai_z_bin_20', 'pai_z_bin_21', 'pai_z_bin_22', 'pai_z_bin_23', 'pai_z_bin_24', 'pai_z_bin_25', 'pai_z_bin_26', 'pai_z_bin_27', 'pai_z_bin_28', 'pai_z_bin_29', 'fhd_normal', 'pavd_z_bin_0', 'pavd_z_bin_1', 'pavd_z_bin_2', 'pavd_z_bin_3', 'pavd_z_bin_4', 'pavd_z_bin_5', 'pavd_z_bin_6', 'pavd_z_bin_7', 'pavd_z_bin_8', 'pavd_z_bin_9', 'pavd_z_bin_10', 'pavd_z_bin_11', 'pavd_z_bin_12', 'pavd_z_bin_13', 'pavd_z_bin_14', 'pavd_z_bin_15', 'pavd_z_bin_16', 'pavd_z_bin_17', 'pavd_z_bin_18', 'pavd_z_bin_19', 'pavd_z_bin_20', 'pavd_z_bin_21', 'pavd_z_bin_22', 'pavd_z_bin_23', 'pavd_z_bin_24', 'pavd_z_bin_25', 'pavd_z_bin_26', 'pavd_z_bin_27', 'pavd_z_bin_28', 'pavd_z_bin_29', 'cover', 'cover_z_bin_0', 'cover_z_bin_1', 'cover_z_bin_2', 'cover_z_bin_3', 'cover_z_bin_4', 'cover_z_bin_5', 'cover_z_bin_6', 'cover_z_bin_7', 'cover_z_bin_8', 'cover_z_bin_9', 'cover_z_bin_10', 'cover_z_bin_11', 'cover_z_bin_12', 'cover_z_bin_13', 'cover_z_bin_14', 'cover_z_bin_15', 'cover_z_bin_16', 'cover_z_bin_17', 'cover_z_bin_18', 'cover_z_bin_19', 'cover_z_bin_20', 'cover_z_bin_21', 'cover_z_bin_22', 'cover_z_bin_23', 'cover_z_bin_24', 'cover_z_bin_25', 'cover_z_bin_26', 'cover_z_bin_27', 'cover_z_bin_28', 'cover_z_bin_29', 'pgap_theta', 'pgap_theta_error', 'rhov', 'rhov_error', 'rhog', 'rhog_error', 'dem_diff']
# /tmp/ipython-input-1483504148.py:53: UserWarning: Attempting to set identical low and high zlims makes transformation singular; automatically expanding.
#   ax.set_zlim(vmin, vmax)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1483504148.py in <cell line: 0>()
#      51     ax.set_zlabel(var)
#      52     ax.set_title(f"{var} (3D)")
# ---> 53     ax.set_zlim(vmin, vmax)
#      54     if len(grouped_dfs) > 1:
#      55         ax.legend()
#
# /usr/local/lib/python3.12/dist-packages/mpl_toolkits/mplot3d/axes3d.py in set_zlim(self, bottom, top, emit, auto, view_margin, zmin, zmax)
#    1011         >>> set_zlim(5000, 0)
#    1012         """
# -> 1013         return self._set_lim3d(self.zaxis, bottom, top, emit=emit, auto=auto,
#    1014                                view_margin=view_margin, axmin=zmin, axmax=zmax)
#    1015
#
# /usr/local/lib/python3.12/dist-packages/mpl_toolkits/mplot3d/axes3d.py in _set_lim3d(self, axis, lower, upper, emit, auto, view_margin, axmin, axmax)
#     796         lower -= delta
#     797         upper += delta
# --> 798         return axis._set_lim(lower, upper, emit=emit, auto=auto)
#     799
#     800     def set_xlim(self, left=None, right=None, *, emit=True, auto=False,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in _set_lim(self, v0, v1, emit, auto)
#    1225
#    1226         self.axes._process_unit_info([(name, (v0, v1))], convert=False)
# -> 1227         v0 = self.axes._validate_converted_limits(v0, self.convert_units)
#    1228         v1 = self.axes._validate_converted_limits(v1, self.convert_units)
#    1229
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in _validate_converted_limits(self, limit, convert)
#    3702             if (isinstance(converted_limit, Real)
#    3703                     and not np.isfinite(converted_limit)):
# -> 3704                 raise ValueError("Axis limits cannot be NaN or Inf")
#    3705             return converted_limit
#    3706
#
# ValueError: Axis limits cannot be NaN or Inf
# Error in callback <function flush_figures at 0x7e2c338cd940> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.12/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure),
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182                 # force the figure dpi to 72), so we need to set it again here.
#    2183                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184                     result = print_method(
#    2185                         filename,
#    2186                         facecolor=facecolor,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2038                 "bbox_inches_restore"}
#    2039             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     479             *metadata*, including the default 'Software' key.
#     480         """
# --> 481         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     482
#     483     def print_to_buffer(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     427         *pil_kwargs* and *metadata* are forwarded).
#     428         """
# --> 429         FigureCanvasAgg.draw(self)
#     430         mpl.image.imsave(
#     431             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     380         with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381               else nullcontext()):
# --> 382             self.figure.draw(self.renderer)
#     383             # A GUI class may be need to update a window using this draw, so
#     384             # don't forget to call the superclass.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      92     @wraps(draw)
#      93     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94         result = draw(artist, renderer, *args, **kwargs)
#      95         if renderer._rasterizing:
#      96             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3255
#    3256                 self.patch.draw(renderer)
# -> 3257                 mimage._draw_list_compositing_images(
#    3258                     renderer, self, artists, self.suppressComposite)
#    3259
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.12/dist-packages/mpl_toolkits/mplot3d/axes3d.py in draw(self, renderer)
#     465             # Then axes, labels, text, and ticks
#     466             for axis in self._axis_map.values():
# --> 467                 axis.draw(renderer)
#     468
#     469         # Then rest
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.12/dist-packages/mpl_toolkits/mplot3d/axis3d.py in draw(self, renderer)
#     609
#     610             # Draw ticks
# --> 611             self._draw_ticks(renderer, edgep1, centers, deltas, highs,
#     612                              deltas_per_point, pos)
#     613
#
# /usr/local/lib/python3.12/dist-packages/mpl_toolkits/mplot3d/axis3d.py in _draw_ticks(self, renderer, edgep1, centers, deltas, highs, deltas_per_point, pos)
#     476             _tick_update_position(tick, (x1, x2), (y1, y2), (lx, ly))
#     477             tick.tick1line.set_linewidth(tick_lw[tick._major])
# --> 478             tick.draw(renderer)
#     479
#     480     def _draw_offset_text(self, renderer, edgep1, edgep2, labeldeltas, centers,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in draw(self, renderer)
#     274         for artist in [self.gridline, self.tick1line, self.tick2line,
#     275                        self.label1, self.label2]:
# --> 276             artist.draw(renderer)
#     277         renderer.close_group(self.__name__)
#     278         self.stale = False
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/lines.py in draw(self, renderer)
#     750
#     751         if self._invalidy or self._invalidx:
# --> 752             self.recache()
#     753         self.ind_offset = 0  # Needed for contains() method.
#     754         if self._subslice and self.axes:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/lines.py in recache(self, always)
#     686
#     687         self._subslice = False
# --> 688         if (self.axes
#     689                 and len(x) > self._subslice_optim_min_size
#     690                 and _path.is_sorted_and_has_non_nan(x)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in axes(self)
#     290         return ax.yaxis.convert_units(y)
#     291
# --> 292     @property
#     293     def axes(self):
#     294         """The `~.axes.Axes` instance the artist resides in, or *None*."""
#
# KeyboardInterrupt:

# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster
from IPython.display import display

# Load the filtered merged GEDI CSV
csv_path = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/GEDI_filtered_merged.csv'
df = pd.read_csv(csv_path)

# Clean data
df.replace([-9999, -9999.0], pd.NA, inplace=True)
df = df.dropna(subset=['lat', 'lon'])

# Choose variable to color points
color_var = 'fhd_normal'  # Can be changed to pai, rh100, etc.
df = df.dropna(subset=[color_var])

# Normalize color values for colormap
min_val, max_val = df[color_var].min(), df[color_var].max()
df['color_norm'] = ((df[color_var] - min_val) / (max_val - min_val) * 255).astype(int)

# Create map centered on the data
m = folium.Map(location=[df['lat'].mean(), df['lon'].mean()], zoom_start=12, tiles='CartoDB positron')

# Add marker cluster
marker_cluster = MarkerCluster().add_to(m)

# Add points
import matplotlib.cm as cm
import matplotlib.colors as colors

cmap = cm.viridis
norm = colors.Normalize(vmin=min_val, vmax=max_val)

for _, row in df.iterrows():
    color = colors.rgb2hex(cmap(norm(row[color_var])))
    folium.CircleMarker(
        location=[row['lat'], row['lon']],
        radius=3,
        color=color,
        fill=True,
        fill_opacity=0.7,
        popup=f"{color_var}: {row[color_var]:.2f}<br>Beam: {row.get('beam', 'N/A')}"
    ).add_to(marker_cluster)

# Display map in Colab
display(m)

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import cartopy.crs as ccrs
# import cartopy.feature as cfeature

# # Load filtered GEDI data
# csv_path = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/GEDI_filtered_merged.csv'
# df = pd.read_csv(csv_path)

# # Clean and filter data
# df.replace([-9999, -9999.0], pd.NA, inplace=True)
# df = df.dropna(subset=['lat', 'lon', 'pai', 'fhd_normal'])

# # Figure setup
# fig, axes = plt.subplots(
#     1, 2, figsize=(14, 6),
#     subplot_kw={'projection': ccrs.PlateCarree()}
# )

# # Common map features
# for ax in axes:
#     ax.add_feature(cfeature.COASTLINE, linewidth=0.3)
#     ax.add_feature(cfeature.BORDERS, linewidth=0.2)
#     ax.add_feature(cfeature.LAKES, alpha=0.2)
#     ax.add_feature(cfeature.RIVERS, alpha=0.2)
#     ax.add_feature(cfeature.STATES.with_scale('10m'), linewidth=0.2)
#     ax.set_extent([
#         df['lon'].min() - 0.01,
#         df['lon'].max() + 0.01,
#         df['lat'].min() - 0.01,
#         df['lat'].max() + 0.01
#     ])

# # --- Left Panel: PAI ---
# sc1 = axes[0].scatter(
#     df['lon'], df['lat'],
#     c=df['pai'], cmap='YlGn', s=15,
#     edgecolor='none', alpha=0.8, transform=ccrs.PlateCarree()
# )
# axes[0].set_title('Plant Area Index (PAI)', fontsize=12)
# cb1 = fig.colorbar(sc1, ax=axes[0], orientation='vertical', shrink=0.8)
# cb1.set_label('PAI', fontsize=10)

# # --- Right Panel: FHD ---
# sc2 = axes[1].scatter(
#     df['lon'], df['lat'],
#     c=df['fhd_normal'], cmap='viridis', s=15,
#     edgecolor='none', alpha=0.8, transform=ccrs.PlateCarree()
# )
# axes[1].set_title('Foliage Height Diversity (FHD)', fontsize=12)
# cb2 = fig.colorbar(sc2, ax=axes[1], orientation='vertical', shrink=0.8)
# cb2.set_label('FHD', fontsize=10)

# # Aesthetics
# for ax in axes:
#     ax.set_xlabel('Longitude', fontsize=10)
#     ax.set_ylabel('Latitude', fontsize=10)
#     ax.gridlines(draw_labels=True, linewidth=0.3, color='gray', alpha=0.5, linestyle='--')

# plt.suptitle('Spatial Distribution of GEDI L2B Metrics', fontsize=14, fontweight='bold')
# plt.tight_layout(rect=[0, 0, 1, 0.96])
# plt.show()

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import cartopy.crs as ccrs
# import cartopy.feature as cfeature
# from mpl_toolkits.mplot3d import Axes3D
# import matplotlib.colors as mcolors

# # === Load and Clean GEDI Data ===
# csv_path = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/GEDI_filtered_merged.csv'
# df = pd.read_csv(csv_path)

# # Replace invalids and drop NaNs
# df.replace([-9999, -9999.0], np.nan, inplace=True)
# df = df.dropna(subset=['lat', 'lon', 'pai', 'fhd_normal', 'digital_elevation_model'])

# # === Hillshade Function ===
# def hillshade(elevation, azimuth=315, angle_altitude=45):
#     """Compute simple hillshade illumination from DEM."""
#     x, y = np.gradient(elevation)
#     slope = np.pi/2. - np.arctan(np.sqrt(x*x + y*y))
#     aspect = np.arctan2(-x, y)
#     az_rad = np.deg2rad(azimuth)
#     alt_rad = np.deg2rad(angle_altitude)
#     shaded = np.sin(alt_rad) * np.sin(slope) + np.cos(alt_rad) * np.cos(slope) * np.cos(az_rad - aspect)
#     return 255 * (shaded + 1) / 2

# # Create a DEM grid for hillshade
# lat_bins = np.linspace(df['lat'].min(), df['lat'].max(), 200)
# lon_bins = np.linspace(df['lon'].min(), df['lon'].max(), 200)
# dem_grid = np.full((len(lat_bins), len(lon_bins)), np.nan)

# for i, lat in enumerate(lat_bins):
#     for j, lon in enumerate(lon_bins):
#         mask = (
#             (df['lat'] >= lat - 0.0005) & (df['lat'] < lat + 0.0005) &
#             (df['lon'] >= lon - 0.0005) & (df['lon'] < lon + 0.0005)
#         )
#         if mask.any():
#             dem_grid[i, j] = df.loc[mask, 'digital_elevation_model'].mean()

# hill = hillshade(np.nan_to_num(dem_grid))

# # === Plot Setup ===
# fig = plt.figure(figsize=(14, 10))
# gs = fig.add_gridspec(2, 2, wspace=0.15, hspace=0.25)
# proj = ccrs.PlateCarree()

# # === (A) PAI Map with Hillshade ===
# ax1 = fig.add_subplot(gs[0, 0], projection=proj)
# ax1.set_title('A) Plant Area Index (PAI) with Hillshade', fontsize=11, weight='bold')
# ax1.imshow(hill, extent=[lon_bins.min(), lon_bins.max(), lat_bins.min(), lat_bins.max()],
#            origin='lower', cmap='Greys', alpha=0.4, transform=proj)
# sc1 = ax1.scatter(df['lon'], df['lat'], c=df['pai'], cmap='YlGn', s=10,
#                   transform=proj, edgecolor='none', alpha=0.9)
# ax1.add_feature(cfeature.STATES.with_scale('10m'), linewidth=0.3)
# ax1.add_feature(cfeature.BORDERS, linewidth=0.2)
# ax1.gridlines(draw_labels=True, linewidth=0.3, color='gray', alpha=0.5, linestyle='--')
# cb1 = fig.colorbar(sc1, ax=ax1, orientation='vertical', shrink=0.8)
# cb1.set_label('PAI', fontsize=9)

# # === (B) PAI 3D Scatter ===
# ax2 = fig.add_subplot(gs[0, 1], projection='3d')
# ax2.scatter(df['lon'], df['lat'], df['pai'], c=df['pai'], cmap='YlGn', s=6)
# ax2.set_title('B) 3D View – PAI', fontsize=11, weight='bold')
# ax2.set_xlabel('Longitude')
# ax2.set_ylabel('Latitude')
# ax2.set_zlabel('PAI')

# # === (C) FHD Map with Hillshade ===
# ax3 = fig.add_subplot(gs[1, 0], projection=proj)
# ax3.set_title('C) Foliage Height Diversity (FHD) with Hillshade', fontsize=11, weight='bold')
# ax3.imshow(hill, extent=[lon_bins.min(), lon_bins.max(), lat_bins.min(), lat_bins.max()],
#            origin='lower', cmap='Greys', alpha=0.4, transform=proj)
# sc3 = ax3.scatter(df['lon'], df['lat'], c=df['fhd_normal'], cmap='viridis', s=10,
#                   transform=proj, edgecolor='none', alpha=0.9)
# ax3.add_feature(cfeature.STATES.with_scale('10m'), linewidth=0.3)
# ax3.add_feature(cfeature.BORDERS, linewidth=0.2)
# ax3.gridlines(draw_labels=True, linewidth=0.3, color='gray', alpha=0.5, linestyle='--')
# cb3 = fig.colorbar(sc3, ax=ax3, orientation='vertical', shrink=0.8)
# cb3.set_label('FHD', fontsize=9)

# # === (D) FHD 3D Scatter ===
# ax4 = fig.add_subplot(gs[1, 1], projection='3d')
# ax4.scatter(df['lon'], df['lat'], df['fhd_normal'], c=df['fhd_normal'], cmap='viridis', s=6)
# ax4.set_title('D) 3D View – FHD', fontsize=11, weight='bold')
# ax4.set_xlabel('Longitude')
# ax4.set_ylabel('Latitude')
# ax4.set_zlabel('FHD')

# # === Final Formatting ===
# plt.suptitle('Spatial and Structural Patterns of GEDI L2B Metrics (Filtered Observations)', fontsize=14, weight='bold')
# plt.tight_layout(rect=[0, 0, 1, 0.97])

# # === Save High-Resolution Output ===
# plt.savefig('/content/GEDI_PAI_FHD_panels.tif', dpi=600, bbox_inches='tight')
# plt.show()

# print("✅ Figure saved as 'GEDI_PAI_FHD_panels.tif' (600 DPI, publication-ready)")

# %%
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import cartopy.crs as ccrs
# import cartopy.io.img_tiles as cimgt
# from mpl_toolkits.mplot3d import Axes3D
# import matplotlib.colors as mcolors

# # === Load and Clean GEDI Data ===
# csv_path = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/GEDI_filtered_merged.csv'
# df = pd.read_csv(csv_path)

# # Replace invalids and drop NaNs
# df.replace([-9999, -9999.0], np.nan, inplace=True)
# df = df.dropna(subset=['lat', 'lon', 'pai', 'fhd_normal', 'digital_elevation_model'])

# # === Setup Figure ===
# fig = plt.figure(figsize=(14, 10))
# gs = fig.add_gridspec(2, 2, wspace=0.2, hspace=0.25)
# proj = ccrs.PlateCarree()

# # === Define Basemap (Terrain Imagery) ===
# terrain = cimgt.Stamen('terrain-background')

# # --------------------------------------------------------------------
# # PANEL A – PAI Map with Imagery Basemap
# # --------------------------------------------------------------------
# ax1 = fig.add_subplot(gs[0, 0], projection=proj)
# ax1.set_title('A) Plant Area Index (PAI)', fontsize=11, weight='bold')
# ax1.add_image(terrain, 12)
# sc1 = ax1.scatter(df['lon'], df['lat'], c=df['pai'], cmap='YlGn', s=10,
#                   transform=proj, edgecolor='none', alpha=0.9)
# # Remove top/right labels for cleaner look
# gl1 = ax1.gridlines(draw_labels=True, linewidth=0.3, color='gray', alpha=0.5, linestyle='--')
# gl1.top_labels = False
# gl1.right_labels = False
# cb1 = fig.colorbar(sc1, ax=ax1, orientation='vertical', shrink=0.8, pad=0.02)
# cb1.set_label('PAI', fontsize=9)

# # --------------------------------------------------------------------
# # PANEL B – FHD Map with Imagery Basemap
# # --------------------------------------------------------------------
# ax2 = fig.add_subplot(gs[0, 1], projection=proj)
# ax2.set_title('B) Foliage Height Diversity (FHD)', fontsize=11, weight='bold')
# ax2.add_image(terrain, 12)
# sc2 = ax2.scatter(df['lon'], df['lat'], c=df['fhd_normal'], cmap='viridis', s=10,
#                   transform=proj, edgecolor='none', alpha=0.9)
# gl2 = ax2.gridlines(draw_labels=True, linewidth=0.3, color='gray', alpha=0.5, linestyle='--')
# gl2.top_labels = False
# gl2.right_labels = False
# cb2 = fig.colorbar(sc2, ax=ax2, orientation='vertical', shrink=0.8, pad=0.02)
# cb2.set_label('FHD', fontsize=9)

# # --------------------------------------------------------------------
# # PANEL C – PAI 3D Scatter
# # --------------------------------------------------------------------
# ax3 = fig.add_subplot(gs[1, 0], projection='3d')
# sc3 = ax3.scatter(df['lon'], df['lat'], df['pai'], c=df['pai'], cmap='YlGn', s=6)
# ax3.set_title('C) 3D View – Plant Area Index (PAI)', fontsize=11, weight='bold')
# ax3.set_xlabel('Longitude')
# ax3.set_ylabel('Latitude')
# ax3.set_zlabel('PAI')
# # Fix colorbar cutoff
# cbar3 = plt.colorbar(sc3, ax=ax3, shrink=0.6, pad=0.1)
# cbar3.set_label('PAI')

# # --------------------------------------------------------------------
# # PANEL D – FHD 3D Scatter
# # --------------------------------------------------------------------
# ax4 = fig.add_subplot(gs[1, 1], projection='3d')
# sc4 = ax4.scatter(df['lon'], df['lat'], df['fhd_normal'], c=df['fhd_normal'], cmap='viridis', s=6)
# ax4.set_title('D) 3D View – Foliage Height Diversity (FHD)', fontsize=11, weight='bold')
# ax4.set_xlabel('Longitude')
# ax4.set_ylabel('Latitude')
# ax4.set_zlabel('FHD')
# # Fix colorbar cutoff
# cbar4 = plt.colorbar(sc4, ax=ax4, shrink=0.6, pad=0.1)
# cbar4.set_label('FHD')

# # === Final Formatting ===
# plt.suptitle('Spatial and Structural Patterns of GEDI L2B Metrics (Filtered Observations)', fontsize=14, weight='bold')
# plt.tight_layout(rect=[0, 0, 1, 0.96])

# # === Save High-Resolution Output ===
# plt.savefig('/content/GEDI_PAI_FHD_panels_v2.tif', dpi=600, bbox_inches='tight')
# plt.show()

# print("✅ Figure saved as 'GEDI_PAI_FHD_panels_v2.tif' (600 DPI, publication-ready)")

# %%
# !pip install Cartopy
# Out:
# Collecting Cartopy
#   Downloading cartopy-0.25.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from Cartopy) (2.0.2)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.12/dist-packages (from Cartopy) (3.10.0)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from Cartopy) (2.1.2)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from Cartopy) (25.0)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.12/dist-packages (from Cartopy) (3.0.2.post1)
# Requirement already satisfied: pyproj>=3.3.1 in /usr/local/lib/python3.12/dist-packages (from Cartopy) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->Cartopy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->Cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->Cartopy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->Cartopy) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->Cartopy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->Cartopy) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->Cartopy) (2.9.0.post0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj>=3.3.1->Cartopy) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->Cartopy) (1.17.0)
# Downloading cartopy-0.25.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 69.2 MB/s eta 0:00:00
# Installing collected packages: Cartopy
# Successfully installed Cartopy-0.25.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.io.img_tiles as cimgt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.colors as mcolors

# === Load and Clean GEDI Data ===
csv_path = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/GEDI_filtered_merged.csv'
df = pd.read_csv(csv_path)

# Replace invalids and drop NaNs
df.replace([-9999, -9999.0], np.nan, inplace=True)
df = df.dropna(subset=['lat', 'lon', 'pai', 'fhd_normal', 'digital_elevation_model'])

# === Setup Figure ===
fig = plt.figure(figsize=(14, 10))
gs = fig.add_gridspec(2, 2, wspace=0.2, hspace=0.25)
proj = ccrs.PlateCarree()

# === Define Basemap (OpenStreetMap) ===
osm_tiles = cimgt.OSM()  # OpenStreetMap tiles

# --------------------------------------------------------------------
# PANEL A – PAI Map with OSM Basemap
# --------------------------------------------------------------------
ax1 = fig.add_subplot(gs[0, 0], projection=proj)
ax1.set_title('A) Plant Area Index (PAI)', fontsize=11, weight='bold')
ax1.add_image(osm_tiles, 12)  # Zoom level 12
sc1 = ax1.scatter(df['lon'], df['lat'], c=df['pai'], cmap='YlGn', s=10,
                  transform=proj, edgecolor='none', alpha=0.9)
# Remove top/right labels
gl1 = ax1.gridlines(draw_labels=True, linewidth=0.3, color='gray', alpha=0.5, linestyle='--')
gl1.top_labels = False
gl1.right_labels = False
cb1 = fig.colorbar(sc1, ax=ax1, orientation='vertical', shrink=0.8, pad=0.02)
cb1.set_label('PAI', fontsize=9)

# --------------------------------------------------------------------
# PANEL B – FHD Map with OSM Basemap
# --------------------------------------------------------------------
ax2 = fig.add_subplot(gs[0, 1], projection=proj)
ax2.set_title('B) Foliage Height Diversity (FHD)', fontsize=11, weight='bold')
ax2.add_image(osm_tiles, 12)
sc2 = ax2.scatter(df['lon'], df['lat'], c=df['fhd_normal'], cmap='viridis', s=10,
                  transform=proj, edgecolor='none', alpha=0.9)
gl2 = ax2.gridlines(draw_labels=True, linewidth=0.3, color='gray', alpha=0.5, linestyle='--')
gl2.top_labels = False
gl2.right_labels = False
cb2 = fig.colorbar(sc2, ax=ax2, orientation='vertical', shrink=0.8, pad=0.02)
cb2.set_label('FHD', fontsize=9)

# --------------------------------------------------------------------
# PANEL C – PAI 3D Scatter
# --------------------------------------------------------------------
ax3 = fig.add_subplot(gs[1, 0], projection='3d')
sc3 = ax3.scatter(df['lon'], df['lat'], df['pai'], c=df['pai'], cmap='YlGn', s=6)
ax3.set_title('C) 3D View – Plant Area Index (PAI)', fontsize=11, weight='bold')
ax3.set_xlabel('Longitude')
ax3.set_ylabel('Latitude')
ax3.set_zlabel('PAI')
cbar3 = plt.colorbar(sc3, ax=ax3, shrink=0.6, pad=0.1)
cbar3.set_label('PAI')

# --------------------------------------------------------------------
# PANEL D – FHD 3D Scatter
# --------------------------------------------------------------------
ax4 = fig.add_subplot(gs[1, 1], projection='3d')
sc4 = ax4.scatter(df['lon'], df['lat'], df['fhd_normal'], c=df['fhd_normal'], cmap='viridis', s=6)
ax4.set_title('D) 3D View – Foliage Height Diversity (FHD)', fontsize=11, weight='bold')
ax4.set_xlabel('Longitude')
ax4.set_ylabel('Latitude')
ax4.set_zlabel('FHD')
cbar4 = plt.colorbar(sc4, ax=ax4, shrink=0.6, pad=0.1)
cbar4.set_label('FHD')

# === Final Formatting ===
plt.suptitle('Spatial and Structural Patterns of GEDI L2B Metrics (Filtered Observations)', fontsize=14, weight='bold')
plt.tight_layout(rect=[0, 0, 1, 0.96])

# === Save High-Resolution Output ===
plt.savefig('/content/GEDI_PAI_FHD_panels_OSM.png', dpi=600, bbox_inches='tight')
plt.show()

print("✅ Figure saved as 'GEDI_PAI_FHD_panels_OSM.tif' (600 DPI, publication-ready)")
# Out:
# /tmp/ipython-input-1428940091.py:80: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.96])
# ✅ Figure saved as 'GEDI_PAI_FHD_panels_OSM.tif' (600 DPI, publication-ready)

# %%
import h5py
import os
import numpy as np

data_dir = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target'
beam_groups = ['BEAM0101', 'BEAM0110', 'BEAM1000', 'BEAM1011']

# Count raw observations
raw_counts = 0
for root, _, files in os.walk(data_dir):
    for file in files:
        if file.endswith('.h5'):
            with h5py.File(os.path.join(root, file), 'r') as f:
                for beam in beam_groups:
                    if beam in f:
                        # Use lat_lowestmode as a proxy for number of shots
                        raw_counts += len(f[beam]['geolocation/lat_lowestmode'][:])

print(f"Total raw GEDI observations across all beams: {raw_counts}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4240617740.py in <cell line: 0>()
#      15                     if beam in f:
#      16                         # Use lat_lowestmode as a proxy for number of shots
# ---> 17                         raw_counts += len(f[beam]['geolocation/lat_lowestmode'][:])
#      18
#      19 print(f"Total raw GEDI observations across all beams: {raw_counts}")
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# /usr/local/lib/python3.12/dist-packages/h5py/_hl/group.py in __getitem__(self, name)
#     365                 raise ValueError("Invalid HDF5 object reference")
#     366         elif isinstance(name, (bytes, str)):
# --> 367             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     368         else:
#     369             raise TypeError("Accessing a group is done with bytes or str, "
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5o.pyx in h5py.h5o.open()
#
# KeyError: "Unable to synchronously open object (object 'lat_lowestmode' doesn't exist)"

# %%
import h5py
import os
import numpy as np

data_dir = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target'
beam_groups = ['BEAM0101', 'BEAM0110', 'BEAM1000', 'BEAM1011']

raw_counts = 0

for root, _, files in os.walk(data_dir):
    for file in files:
        if file.endswith('.h5'):
            with h5py.File(os.path.join(root, file), 'r') as f:
                for beam in beam_groups:
                    if beam in f:
                        geo = f[beam]['geolocation']
                        # Try both common dataset names
                        for name in ['lat_lowestmode', 'latitude_lowestmode', 'latitude']:
                            if name in geo:
                                raw_counts += len(geo[name][:])
                                break  # Stop if one works

print(f"Total raw GEDI observations across all beams: {raw_counts}")
# Out:
# Total raw GEDI observations across all beams: 15914

# %%
import pandas as pd

csv_path = '/content/drive/MyDrive/PhD_Main_Folder/Geo_Data/Sewanee_DL_Project/GEDI_target/filtered_csvs/GEDI_filtered_merged.csv'
df_filtered = pd.read_csv(csv_path)

print(f"Total filtered GEDI observations: {len(df_filtered)}")
# Out:
# Total filtered GEDI observations: 872
